# %%
import cv2
import numpy as np

# %%
video_path = "data/Data/kaniula1.avi"
cap = cv2.VideoCapture(video_path)

if not cap.isOpened():
    print("Error: Could not open the video file.")
    exit()

ret, first_frame = cap.read()

if not ret:
    print("Error: Could not read the first frame.")
    cap.release()
    exit()

cap.release()

cv2.imshow("First Frame", first_frame)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
def create_binary_image(input_frame, box_size=5, offset=10):
    gray_image = cv2.cvtColor(input_frame, cv2.COLOR_BGR2GRAY)

    binary_image = np.zeros_like(gray_image)

    for i in range(box_size, gray_image.shape[0] - box_size):
        for j in range(box_size, gray_image.shape[1] - box_size):
            box_mean = np.mean(gray_image[i - box_size : i + box_size + 1, j - box_size : j + box_size + 1])
            if gray_image[i, j] > box_mean + offset:
                binary_image[i, j] = 255

    # cv2.imshow("Binary Image", binary_image)
    # cv2.waitKey(0)
    # cv2.destroyAllWindows()

    return binary_image

# %%
#Zastosowanie maski

def apply_mask(input_array, border):
    height, width = input_array.shape

    mask = np.zeros((height, width), dtype=np.uint8)

    center_x = width // 2
    center_y = height // 2

    for i in range(-100, 100):
        mask[center_y + i, center_x + i:] = 255

    mask[:, :border] = 0
    mask[:, -border:] = 0

    result_array = cv2.bitwise_and(input_array, input_array, mask=mask)
    
    # cv2.imshow("Result Image", result_array)
    # cv2.waitKey(0)
    # cv2.destroyAllWindows()
    
    return result_array

# %%
#Przefiltrowanie plam które są za małe
def filter_blobs(input_array, area_threshold=50, aspect_ratio_threshold=1.0):
    contours, _ = cv2.findContours(input_array, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    mask = np.zeros_like(input_array)

    for contour in contours:
        x, y, w, h = cv2.boundingRect(contour)

        aspect_ratio = float(w) / h

        if cv2.contourArea(contour) >= area_threshold and aspect_ratio <= aspect_ratio_threshold:
            cv2.drawContours(mask, [contour], 0, 255, thickness=cv2.FILLED)

    result_array_filtered = cv2.bitwise_and(input_array, mask)

    # cv2.imshow('Filtered Result', result_array_filtered)
    # cv2.waitKey(0)
    # cv2.destroyAllWindows()

    return result_array_filtered

# %%
# Wypełnienie dziur w plamach

def fill_blobs(input_array):
    input_array = input_array.astype(np.uint8)

    contours, hierarchy = cv2.findContours(input_array, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    for contour in contours:
        cv2.drawContours(input_array, [contour], 0, 255, thickness=cv2.FILLED)
        
    # cv2.imshow('Filtered Result', result_array_filtered)
    # cv2.waitKey(0)
    # cv2.destroyAllWindows()
    return input_array

# %%
def detect_rightmost_blobs(binary_image, color_image, rect_width=20, rect_height=50, num_blobs=2):
    contours, _ = cv2.findContours(binary_image, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    if not contours:
        return None, None

    # Sort contours based on their x-coordinate
    contours = sorted(contours, key=lambda c: cv2.boundingRect(c)[0])

    rightmost_contours = contours[-num_blobs:]  # Get the rightmost N contours
    centroid_positions = []

    for contour in rightmost_contours:
        x, y, w, h = cv2.boundingRect(contour)
        cv2.rectangle(color_image, (x, y), (x + rect_width, y + rect_height), (0, 255, 0), 2)

        centroid_x = x + w // 2
        centroid_y = y + h // 2

        centroid_positions.append((centroid_x, centroid_y))

    return color_image, centroid_positions

# %%
import math

def euc_distance(point1, point2):
    x1, y1 = point1
    x2, y2 = point2
    distance = math.sqrt((x2 - x1)**2 + (y2 - y1)**2)
    return distance

# %%
def in_bounds(point1, point2):
    x1, y1 = point1
    x2, y2 = point2
    distance_hor = abs(x1-x2)
    distance_ver = abs(y1-y2)

    return distance_hor < 6 and distance_ver < 30

# %%
video_path = 'data/Data/kaniula1.avi'

cap = cv2.VideoCapture(video_path)

previous_centroid = (0.0, 0.0)
shift = 0
radius = 10

frame_counter = 0

while True:
    ret, frame = cap.read()

    if not ret:
        break

    frame_counter += 1

    binary_image = create_binary_image(frame)
    masked_image = apply_mask(binary_image, 125)
    filtered_image = filter_blobs(masked_image)
    filled_image = fill_blobs(filtered_image)
    result_image, centroid_positions = detect_rightmost_blobs(filled_image, frame)

    if(in_bounds(previous_centroid, centroid_positions[0])):
        print("Tracking the blob, frame number: ", frame_counter)
    elif(in_bounds(previous_centroid, centroid_positions[1])):
        shift -= 1
        print("Previous blob disappeared, shift = ", shift)
    elif(not in_bounds(previous_centroid, centroid_positions[0]) and euc_distance(centroid_positions[0], previous_centroid) < 100):
        shift += 1
        print("New rightmost blob detected, shift = ", shift)
        
    previous_centroid = centroid_positions[0]

    cv2.imshow("Binary Image", filled_image)
    cv2.imshow("Result Image", frame)
    cv2.waitKey(1)
# Out:
# Tracking the blob, frame number:  2
# Tracking the blob, frame number:  3
# Tracking the blob, frame number:  4
# Tracking the blob, frame number:  5
# Tracking the blob, frame number:  6
# Tracking the blob, frame number:  7
# Tracking the blob, frame number:  8
# Tracking the blob, frame number:  9
# Tracking the blob, frame number:  10
# Tracking the blob, frame number:  11
# Tracking the blob, frame number:  12
# Tracking the blob, frame number:  13
# Tracking the blob, frame number:  14
# Tracking the blob, frame number:  15
# Tracking the blob, frame number:  16
# Tracking the blob, frame number:  17
# Tracking the blob, frame number:  18
# Tracking the blob, frame number:  19
# Tracking the blob, frame number:  20
# Tracking the blob, frame number:  21
# Tracking the blob, frame number:  22
# Tracking the blob, frame number:  23
# Tracking the blob, frame number:  24
# Tracking the blob, frame number:  25
# Tracking the blob, frame number:  26
# Tracking the blob, frame number:  27
# Tracking the blob, frame number:  28
# Tracking the blob, frame number:  29
# Tracking the blob, frame number:  30
# Tracking the blob, frame number:  31
# Tracking the blob, frame number:  32
# Tracking the blob, frame number:  33
# Tracking the blob, frame number:  34
# Tracking the blob, frame number:  35
# Tracking the blob, frame number:  36
# Tracking the blob, frame number:  37
# Tracking the blob, frame number:  38
# Tracking the blob, frame number:  39
# Tracking the blob, frame number:  40
# Tracking the blob, frame number:  41
# Tracking the blob, frame number:  42
# Tracking the blob, frame number:  43
# Tracking the blob, frame number:  44
# Tracking the blob, frame number:  45
# Tracking the blob, frame number:  46
# Tracking the blob, frame number:  47
# Tracking the blob, frame number:  48
# Tracking the blob, frame number:  49
# Tracking the blob, frame number:  50
# Tracking the blob, frame number:  51
# Tracking the blob, frame number:  52
# Tracking the blob, frame number:  53
# Tracking the blob, frame number:  54
# Tracking the blob, frame number:  55
# Tracking the blob, frame number:  56
# Tracking the blob, frame number:  57
# Tracking the blob, frame number:  58
# Tracking the blob, frame number:  59
# Tracking the blob, frame number:  60
# Tracking the blob, frame number:  61
# Tracking the blob, frame number:  62
# Tracking the blob, frame number:  63
# Tracking the blob, frame number:  64
# Tracking the blob, frame number:  65
# Tracking the blob, frame number:  66
# Tracking the blob, frame number:  67
# Tracking the blob, frame number:  68
# Tracking the blob, frame number:  69
# Tracking the blob, frame number:  70
# Tracking the blob, frame number:  71
# Tracking the blob, frame number:  72
# Tracking the blob, frame number:  73
# Tracking the blob, frame number:  74
# Tracking the blob, frame number:  75
# Tracking the blob, frame number:  76
# Tracking the blob, frame number:  77
# Tracking the blob, frame number:  78
# Tracking the blob, frame number:  79
# Tracking the blob, frame number:  80
# Tracking the blob, frame number:  81
# Tracking the blob, frame number:  82
# Tracking the blob, frame number:  83
# Tracking the blob, frame number:  84
# Tracking the blob, frame number:  85
# Tracking the blob, frame number:  86
# Tracking the blob, frame number:  87
# Tracking the blob, frame number:  88
# Tracking the blob, frame number:  89
# Tracking the blob, frame number:  90
# Tracking the blob, frame number:  91
# Tracking the blob, frame number:  92
# Tracking the blob, frame number:  93
# Tracking the blob, frame number:  94
# Tracking the blob, frame number:  95
# Tracking the blob, frame number:  96
# Tracking the blob, frame number:  97
# Tracking the blob, frame number:  98
# Tracking the blob, frame number:  99
# Tracking the blob, frame number:  100
# Tracking the blob, frame number:  101
# Tracking the blob, frame number:  102
# Tracking the blob, frame number:  103
# Tracking the blob, frame number:  104
# Tracking the blob, frame number:  105
# Tracking the blob, frame number:  106
# Tracking the blob, frame number:  107
# Tracking the blob, frame number:  108
# Tracking the blob, frame number:  109
# Tracking the blob, frame number:  110
# Tracking the blob, frame number:  111
# Tracking the blob, frame number:  112
# Tracking the blob, frame number:  113
# Tracking the blob, frame number:  114
# Tracking the blob, frame number:  115
# Tracking the blob, frame number:  116
# Tracking the blob, frame number:  117
# Tracking the blob, frame number:  118
# Tracking the blob, frame number:  119
# Tracking the blob, frame number:  120
# Tracking the blob, frame number:  121
# Tracking the blob, frame number:  122
# Tracking the blob, frame number:  123
# Tracking the blob, frame number:  124
# Tracking the blob, frame number:  125
# Tracking the blob, frame number:  126
# Tracking the blob, frame number:  127
# Tracking the blob, frame number:  128
# Tracking the blob, frame number:  129
# Tracking the blob, frame number:  130
# Tracking the blob, frame number:  131
# Tracking the blob, frame number:  132
# Tracking the blob, frame number:  133
# New rightmost blob detected, shift =  1
# Tracking the blob, frame number:  135
# Tracking the blob, frame number:  136
# Tracking the blob, frame number:  137
# Tracking the blob, frame number:  138
# Tracking the blob, frame number:  139
# Tracking the blob, frame number:  140
# Tracking the blob, frame number:  141
# Tracking the blob, frame number:  142
# Tracking the blob, frame number:  143
# Tracking the blob, frame number:  144
# Tracking the blob, frame number:  145
# Tracking the blob, frame number:  146
# Tracking the blob, frame number:  147
# Tracking the blob, frame number:  148
# Tracking the blob, frame number:  149
# Tracking the blob, frame number:  150
# Tracking the blob, frame number:  151
# Tracking the blob, frame number:  152
# Tracking the blob, frame number:  153
# Tracking the blob, frame number:  154
# Tracking the blob, frame number:  155
# Tracking the blob, frame number:  156
# Tracking the blob, frame number:  157
# Tracking the blob, frame number:  158
# Tracking the blob, frame number:  159
# Tracking the blob, frame number:  160
# Tracking the blob, frame number:  161
# Tracking the blob, frame number:  162
# Tracking the blob, frame number:  163
# Tracking the blob, frame number:  164
# Tracking the blob, frame number:  165
# Tracking the blob, frame number:  166
# Tracking the blob, frame number:  167
# Tracking the blob, frame number:  168
# Tracking the blob, frame number:  169
# Tracking the blob, frame number:  170
# Tracking the blob, frame number:  171
# Tracking the blob, frame number:  172
# Tracking the blob, frame number:  173
# Tracking the blob, frame number:  174
# Tracking the blob, frame number:  175
# Tracking the blob, frame number:  176
# Tracking the blob, frame number:  177
# Tracking the blob, frame number:  178
# Tracking the blob, frame number:  179
# Tracking the blob, frame number:  180
# Tracking the blob, frame number:  181
# Tracking the blob, frame number:  182
# Tracking the blob, frame number:  183
# Tracking the blob, frame number:  184
# Tracking the blob, frame number:  185
# New rightmost blob detected, shift =  2
# Tracking the blob, frame number:  187
# Tracking the blob, frame number:  188
# Tracking the blob, frame number:  189
# Tracking the blob, frame number:  190
# Tracking the blob, frame number:  191
# Tracking the blob, frame number:  192
# Tracking the blob, frame number:  193
# Tracking the blob, frame number:  194
# Tracking the blob, frame number:  195
# Tracking the blob, frame number:  196
# Tracking the blob, frame number:  197
# Tracking the blob, frame number:  198
# Tracking the blob, frame number:  199
# Tracking the blob, frame number:  200
# Tracking the blob, frame number:  201
# Tracking the blob, frame number:  202
# Tracking the blob, frame number:  203
# Tracking the blob, frame number:  204
# Tracking the blob, frame number:  205
# Tracking the blob, frame number:  206
# Tracking the blob, frame number:  207
# Tracking the blob, frame number:  208
# Tracking the blob, frame number:  209
# Tracking the blob, frame number:  210
# Tracking the blob, frame number:  211
# Tracking the blob, frame number:  212
# Tracking the blob, frame number:  213
# Tracking the blob, frame number:  214
# Tracking the blob, frame number:  215
# Tracking the blob, frame number:  216
# Tracking the blob, frame number:  217
# Tracking the blob, frame number:  218
# Tracking the blob, frame number:  219
# Tracking the blob, frame number:  220
# Tracking the blob, frame number:  221
# Tracking the blob, frame number:  222
# New rightmost blob detected, shift =  3
# Tracking the blob, frame number:  224
# Tracking the blob, frame number:  225
# Tracking the blob, frame number:  226
# Tracking the blob, frame number:  227
# Tracking the blob, frame number:  228
# Tracking the blob, frame number:  229
# Tracking the blob, frame number:  230
# Tracking the blob, frame number:  231
# Tracking the blob, frame number:  232
# Tracking the blob, frame number:  233
# Tracking the blob, frame number:  234
# Tracking the blob, frame number:  235
# Tracking the blob, frame number:  236
# Tracking the blob, frame number:  237
# Tracking the blob, frame number:  238
# Tracking the blob, frame number:  239
# Tracking the blob, frame number:  240
# Tracking the blob, frame number:  241
# Tracking the blob, frame number:  242
# Tracking the blob, frame number:  243
# Tracking the blob, frame number:  244
# Tracking the blob, frame number:  245
# Tracking the blob, frame number:  246
# Tracking the blob, frame number:  247
# Tracking the blob, frame number:  248
# Tracking the blob, frame number:  249
# Tracking the blob, frame number:  250
# Tracking the blob, frame number:  251
# Tracking the blob, frame number:  252
# New rightmost blob detected, shift =  4
# Tracking the blob, frame number:  254
# Tracking the blob, frame number:  255
# Tracking the blob, frame number:  256
# Tracking the blob, frame number:  257
# Tracking the blob, frame number:  258
# Tracking the blob, frame number:  259
# Tracking the blob, frame number:  260
# Tracking the blob, frame number:  261
# Tracking the blob, frame number:  262
# Tracking the blob, frame number:  263
# Tracking the blob, frame number:  264
# Tracking the blob, frame number:  265
# Tracking the blob, frame number:  266
# Tracking the blob, frame number:  267
# Tracking the blob, frame number:  268
# Tracking the blob, frame number:  269
# Tracking the blob, frame number:  270
# Tracking the blob, frame number:  271
# Tracking the blob, frame number:  272
# Tracking the blob, frame number:  273
# Tracking the blob, frame number:  274
# Tracking the blob, frame number:  275
# Tracking the blob, frame number:  276
# Tracking the blob, frame number:  277
# Tracking the blob, frame number:  278
# Tracking the blob, frame number:  279
# Tracking the blob, frame number:  280
# Tracking the blob, frame number:  281
# Tracking the blob, frame number:  282
# Tracking the blob, frame number:  283
# Tracking the blob, frame number:  284
# Tracking the blob, frame number:  285
# Tracking the blob, frame number:  286
# Tracking the blob, frame number:  287
# Tracking the blob, frame number:  288
# Tracking the blob, frame number:  289
# Tracking the blob, frame number:  290
# Tracking the blob, frame number:  291
# Tracking the blob, frame number:  292
# New rightmost blob detected, shift =  5
# Tracking the blob, frame number:  294
# Tracking the blob, frame number:  295
# Tracking the blob, frame number:  296
# Tracking the blob, frame number:  297
# Tracking the blob, frame number:  298
# Tracking the blob, frame number:  299
# Tracking the blob, frame number:  300
# Tracking the blob, frame number:  301
# Tracking the blob, frame number:  302
# Tracking the blob, frame number:  303
# Tracking the blob, frame number:  304
# Tracking the blob, frame number:  305
# Tracking the blob, frame number:  306
# Tracking the blob, frame number:  307
# Tracking the blob, frame number:  308
# Tracking the blob, frame number:  309
# Tracking the blob, frame number:  310
# Tracking the blob, frame number:  311
# Tracking the blob, frame number:  312
# Tracking the blob, frame number:  313
# Tracking the blob, frame number:  314
# Tracking the blob, frame number:  315
# Tracking the blob, frame number:  316
# Tracking the blob, frame number:  317
# Tracking the blob, frame number:  318
# Tracking the blob, frame number:  319
# Tracking the blob, frame number:  320
# Tracking the blob, frame number:  321
# Tracking the blob, frame number:  322
# Tracking the blob, frame number:  323
# Tracking the blob, frame number:  324
# Tracking the blob, frame number:  325
# Tracking the blob, frame number:  326
# Tracking the blob, frame number:  327
# Tracking the blob, frame number:  328
# Tracking the blob, frame number:  329
# Tracking the blob, frame number:  330
# Tracking the blob, frame number:  331
# Tracking the blob, frame number:  332
# Tracking the blob, frame number:  333
# Tracking the blob, frame number:  334
# Tracking the blob, frame number:  335
# Tracking the blob, frame number:  336
# Tracking the blob, frame number:  337
# Tracking the blob, frame number:  338
# Tracking the blob, frame number:  339
# Tracking the blob, frame number:  340
# Tracking the blob, frame number:  341
# Tracking the blob, frame number:  342
# Tracking the blob, frame number:  343
# Tracking the blob, frame number:  344
# Tracking the blob, frame number:  345
# Tracking the blob, frame number:  346
# Tracking the blob, frame number:  347
# Tracking the blob, frame number:  348
# Tracking the blob, frame number:  349
# Tracking the blob, frame number:  350
# Tracking the blob, frame number:  351
# Tracking the blob, frame number:  352
# Tracking the blob, frame number:  353
# Tracking the blob, frame number:  354
# Tracking the blob, frame number:  355
# Tracking the blob, frame number:  356
# Tracking the blob, frame number:  357
# Tracking the blob, frame number:  358
# Tracking the blob, frame number:  359
# Tracking the blob, frame number:  360
# Tracking the blob, frame number:  361
# Tracking the blob, frame number:  362
# Tracking the blob, frame number:  363
# Tracking the blob, frame number:  364
# New rightmost blob detected, shift =  6
# Tracking the blob, frame number:  366
# Tracking the blob, frame number:  367
# Tracking the blob, frame number:  368
# Tracking the blob, frame number:  369
# Tracking the blob, frame number:  370
# Tracking the blob, frame number:  371
# Tracking the blob, frame number:  372
# Tracking the blob, frame number:  373
# Tracking the blob, frame number:  374
# Tracking the blob, frame number:  375
# Tracking the blob, frame number:  376
# Tracking the blob, frame number:  377
# Tracking the blob, frame number:  378
# Tracking the blob, frame number:  379
# Tracking the blob, frame number:  380
# Tracking the blob, frame number:  381
# Tracking the blob, frame number:  382
# Tracking the blob, frame number:  383
# Tracking the blob, frame number:  384
# Tracking the blob, frame number:  385
# Tracking the blob, frame number:  386
# Tracking the blob, frame number:  387
# Tracking the blob, frame number:  388
# Tracking the blob, frame number:  389
# Tracking the blob, frame number:  390
# Tracking the blob, frame number:  391
# Tracking the blob, frame number:  392
# Tracking the blob, frame number:  393
# Tracking the blob, frame number:  394
# Tracking the blob, frame number:  395
# Tracking the blob, frame number:  396
# Tracking the blob, frame number:  397
# Tracking the blob, frame number:  398
# Tracking the blob, frame number:  399
# Tracking the blob, frame number:  400
# New rightmost blob detected, shift =  7
# Tracking the blob, frame number:  402
# Tracking the blob, frame number:  403
# Tracking the blob, frame number:  404
# Tracking the blob, frame number:  405
# Tracking the blob, frame number:  406
# Tracking the blob, frame number:  407
# Tracking the blob, frame number:  408
# Tracking the blob, frame number:  409
# Tracking the blob, frame number:  410
# Tracking the blob, frame number:  411
# Tracking the blob, frame number:  412
# Tracking the blob, frame number:  413
# Tracking the blob, frame number:  414
# Tracking the blob, frame number:  415
# Tracking the blob, frame number:  416
# Tracking the blob, frame number:  417
# Tracking the blob, frame number:  418
# Tracking the blob, frame number:  419
# Tracking the blob, frame number:  420
# Tracking the blob, frame number:  421
# Tracking the blob, frame number:  422
# Tracking the blob, frame number:  423
# Tracking the blob, frame number:  424
# Tracking the blob, frame number:  425
# Tracking the blob, frame number:  426
# Tracking the blob, frame number:  427
# Tracking the blob, frame number:  428
# Tracking the blob, frame number:  429
# Tracking the blob, frame number:  430
# Tracking the blob, frame number:  431
# Tracking the blob, frame number:  432
# Tracking the blob, frame number:  433
# Tracking the blob, frame number:  434
# Tracking the blob, frame number:  435
# Tracking the blob, frame number:  436
# Tracking the blob, frame number:  437
# Tracking the blob, frame number:  438
# Tracking the blob, frame number:  439
# Tracking the blob, frame number:  440
# Tracking the blob, frame number:  441
# Tracking the blob, frame number:  442
# Tracking the blob, frame number:  443
# Tracking the blob, frame number:  444
# Tracking the blob, frame number:  445
# Tracking the blob, frame number:  446
# Tracking the blob, frame number:  447
# Tracking the blob, frame number:  448
# Tracking the blob, frame number:  449
# Tracking the blob, frame number:  450
# Tracking the blob, frame number:  451
# Tracking the blob, frame number:  452
# New rightmost blob detected, shift =  8
# Tracking the blob, frame number:  454
# Tracking the blob, frame number:  455
# Tracking the blob, frame number:  456
# Tracking the blob, frame number:  457
# Tracking the blob, frame number:  458
# Tracking the blob, frame number:  459
# Tracking the blob, frame number:  460
# Tracking the blob, frame number:  461
# Tracking the blob, frame number:  462
# Tracking the blob, frame number:  463
# Tracking the blob, frame number:  464
# Tracking the blob, frame number:  465
# Tracking the blob, frame number:  466
# Tracking the blob, frame number:  467
# Tracking the blob, frame number:  468
# New rightmost blob detected, shift =  9
# New rightmost blob detected, shift =  10
# Tracking the blob, frame number:  471
# Tracking the blob, frame number:  472
# Tracking the blob, frame number:  473
# Tracking the blob, frame number:  474
# Tracking the blob, frame number:  475
# Tracking the blob, frame number:  476
# Tracking the blob, frame number:  477
# Tracking the blob, frame number:  478
# Tracking the blob, frame number:  479
# Tracking the blob, frame number:  480
# Tracking the blob, frame number:  481
# Tracking the blob, frame number:  482
# Tracking the blob, frame number:  483
# Tracking the blob, frame number:  484
# Tracking the blob, frame number:  485
# Tracking the blob, frame number:  486
# Tracking the blob, frame number:  487
# Tracking the blob, frame number:  488
# Tracking the blob, frame number:  489
# Tracking the blob, frame number:  490
# Tracking the blob, frame number:  491
# Tracking the blob, frame number:  492
# Tracking the blob, frame number:  493
# Tracking the blob, frame number:  494
# Tracking the blob, frame number:  495
# Tracking the blob, frame number:  496
# Tracking the blob, frame number:  497
# New rightmost blob detected, shift =  11
# Tracking the blob, frame number:  499
# Tracking the blob, frame number:  500
# Tracking the blob, frame number:  501
# Tracking the blob, frame number:  502
# Tracking the blob, frame number:  503
# Tracking the blob, frame number:  504
# Tracking the blob, frame number:  505
# Tracking the blob, frame number:  506
# Tracking the blob, frame number:  507
# Tracking the blob, frame number:  508
# Tracking the blob, frame number:  509
# Tracking the blob, frame number:  510
# Tracking the blob, frame number:  511
# Tracking the blob, frame number:  512
# Tracking the blob, frame number:  513
# Tracking the blob, frame number:  514
# Tracking the blob, frame number:  515
# Tracking the blob, frame number:  516
# Tracking the blob, frame number:  517
# Tracking the blob, frame number:  518
# Tracking the blob, frame number:  519
# Tracking the blob, frame number:  520
# Tracking the blob, frame number:  521
# Tracking the blob, frame number:  522
# Tracking the blob, frame number:  523
# Tracking the blob, frame number:  524
# Tracking the blob, frame number:  525
# Tracking the blob, frame number:  526
# Tracking the blob, frame number:  527
# Tracking the blob, frame number:  528
# Tracking the blob, frame number:  529
# Tracking the blob, frame number:  530
# Tracking the blob, frame number:  531
# Tracking the blob, frame number:  532
# Tracking the blob, frame number:  533
# Tracking the blob, frame number:  534
# Tracking the blob, frame number:  535
# New rightmost blob detected, shift =  12
# Tracking the blob, frame number:  537
# New rightmost blob detected, shift =  13
# Tracking the blob, frame number:  539
# Tracking the blob, frame number:  540
# Tracking the blob, frame number:  541
# Tracking the blob, frame number:  542
# Tracking the blob, frame number:  543
# Tracking the blob, frame number:  544
# Tracking the blob, frame number:  545
# Tracking the blob, frame number:  546
# Tracking the blob, frame number:  547
# Tracking the blob, frame number:  548
# Tracking the blob, frame number:  549
# Tracking the blob, frame number:  550
# Tracking the blob, frame number:  551
# Tracking the blob, frame number:  552
# Tracking the blob, frame number:  553
# Tracking the blob, frame number:  554
# Tracking the blob, frame number:  555
# Tracking the blob, frame number:  556
# Tracking the blob, frame number:  557
# Tracking the blob, frame number:  558
# Tracking the blob, frame number:  559
# Tracking the blob, frame number:  560
# Tracking the blob, frame number:  561
# Tracking the blob, frame number:  562
# Tracking the blob, frame number:  563
# Tracking the blob, frame number:  564
# Tracking the blob, frame number:  565
# Tracking the blob, frame number:  566
# Tracking the blob, frame number:  567
# Tracking the blob, frame number:  568
# Tracking the blob, frame number:  569
# Tracking the blob, frame number:  570
# Tracking the blob, frame number:  571
# Tracking the blob, frame number:  572
# New rightmost blob detected, shift =  14
# Tracking the blob, frame number:  574
# Tracking the blob, frame number:  575
# New rightmost blob detected, shift =  15
# New rightmost blob detected, shift =  16
# Tracking the blob, frame number:  578
# Tracking the blob, frame number:  579
# Tracking the blob, frame number:  580
# Tracking the blob, frame number:  581
# Tracking the blob, frame number:  582
# Tracking the blob, frame number:  583
# Tracking the blob, frame number:  584
# Tracking the blob, frame number:  585
# Tracking the blob, frame number:  586
# Tracking the blob, frame number:  587
# Tracking the blob, frame number:  588
# Tracking the blob, frame number:  589
# Tracking the blob, frame number:  590
# Tracking the blob, frame number:  591
# Tracking the blob, frame number:  592
# Tracking the blob, frame number:  593
# Tracking the blob, frame number:  594
# Tracking the blob, frame number:  595
# Tracking the blob, frame number:  596
# Tracking the blob, frame number:  597
# Tracking the blob, frame number:  598
# Tracking the blob, frame number:  599
# Tracking the blob, frame number:  600
# Tracking the blob, frame number:  601
# Tracking the blob, frame number:  602
# Tracking the blob, frame number:  603
# Tracking the blob, frame number:  604
# Tracking the blob, frame number:  605
# Tracking the blob, frame number:  606
# Tracking the blob, frame number:  607
# Tracking the blob, frame number:  608
# Tracking the blob, frame number:  609
# Tracking the blob, frame number:  610
# Tracking the blob, frame number:  611
# Tracking the blob, frame number:  612
# Tracking the blob, frame number:  613
# Tracking the blob, frame number:  614
# Tracking the blob, frame number:  615
# Tracking the blob, frame number:  616
# Tracking the blob, frame number:  617
# Tracking the blob, frame number:  618
# Tracking the blob, frame number:  619
# Tracking the blob, frame number:  620
# Tracking the blob, frame number:  621
# Tracking the blob, frame number:  622
# Tracking the blob, frame number:  623
# Tracking the blob, frame number:  624
# Tracking the blob, frame number:  625
# Tracking the blob, frame number:  626
# Tracking the blob, frame number:  627
# Tracking the blob, frame number:  628
# Tracking the blob, frame number:  629
# Tracking the blob, frame number:  630
# Tracking the blob, frame number:  631
# Tracking the blob, frame number:  632
# Tracking the blob, frame number:  633
# Tracking the blob, frame number:  634
# Tracking the blob, frame number:  635
# Tracking the blob, frame number:  636
# Tracking the blob, frame number:  637
# Tracking the blob, frame number:  638
# Tracking the blob, frame number:  639
# Tracking the blob, frame number:  640
# Tracking the blob, frame number:  641
# Tracking the blob, frame number:  642
# Tracking the blob, frame number:  643
# Tracking the blob, frame number:  644
# Tracking the blob, frame number:  645
# Tracking the blob, frame number:  646
# Tracking the blob, frame number:  647
# Tracking the blob, frame number:  648
# Tracking the blob, frame number:  649
# Tracking the blob, frame number:  650
# Tracking the blob, frame number:  651
# Tracking the blob, frame number:  652
# Tracking the blob, frame number:  653
# New rightmost blob detected, shift =  17
# Tracking the blob, frame number:  655
# Tracking the blob, frame number:  656
# Tracking the blob, frame number:  657
# Tracking the blob, frame number:  658
# Tracking the blob, frame number:  659
# Tracking the blob, frame number:  660
# Tracking the blob, frame number:  661
# Tracking the blob, frame number:  662
# Tracking the blob, frame number:  663
# Tracking the blob, frame number:  664
# Tracking the blob, frame number:  665
# Tracking the blob, frame number:  666
# Tracking the blob, frame number:  667
# Tracking the blob, frame number:  668
# Tracking the blob, frame number:  669
# Tracking the blob, frame number:  670
# Tracking the blob, frame number:  671
# Tracking the blob, frame number:  672
# Tracking the blob, frame number:  673
# Tracking the blob, frame number:  674
# Tracking the blob, frame number:  675
# Tracking the blob, frame number:  676
# Tracking the blob, frame number:  677
# Tracking the blob, frame number:  678
# Tracking the blob, frame number:  679
# Tracking the blob, frame number:  680
# Tracking the blob, frame number:  681
# Tracking the blob, frame number:  682
# New rightmost blob detected, shift =  18
# Tracking the blob, frame number:  684
# Tracking the blob, frame number:  685
# Tracking the blob, frame number:  686
# Tracking the blob, frame number:  687
# Tracking the blob, frame number:  688
# Tracking the blob, frame number:  689
# Tracking the blob, frame number:  690
# Tracking the blob, frame number:  691
# Tracking the blob, frame number:  692
# Tracking the blob, frame number:  693
# Tracking the blob, frame number:  694
# Tracking the blob, frame number:  695
# Tracking the blob, frame number:  696
# Tracking the blob, frame number:  697
# Tracking the blob, frame number:  698
# Tracking the blob, frame number:  699
# Tracking the blob, frame number:  700
# Tracking the blob, frame number:  701
# Tracking the blob, frame number:  702
# Tracking the blob, frame number:  703
# Tracking the blob, frame number:  704
# Tracking the blob, frame number:  705
# Tracking the blob, frame number:  706
# New rightmost blob detected, shift =  19
# Tracking the blob, frame number:  708
# Tracking the blob, frame number:  709
# Tracking the blob, frame number:  710
# Tracking the blob, frame number:  711
# Tracking the blob, frame number:  712
# Tracking the blob, frame number:  713
# New rightmost blob detected, shift =  20
# Tracking the blob, frame number:  715
# Tracking the blob, frame number:  716
# Tracking the blob, frame number:  717
# Tracking the blob, frame number:  718
# Tracking the blob, frame number:  719
# Tracking the blob, frame number:  720
# Tracking the blob, frame number:  721
# Tracking the blob, frame number:  722
# Tracking the blob, frame number:  723
# Tracking the blob, frame number:  724
# Tracking the blob, frame number:  725
# Tracking the blob, frame number:  726
# Tracking the blob, frame number:  727
# Tracking the blob, frame number:  728
# Tracking the blob, frame number:  729
# Tracking the blob, frame number:  730
# Tracking the blob, frame number:  731
# Tracking the blob, frame number:  732
# Tracking the blob, frame number:  733
# Tracking the blob, frame number:  734
# Tracking the blob, frame number:  735
# Tracking the blob, frame number:  736
# Tracking the blob, frame number:  737
# Tracking the blob, frame number:  738
# Tracking the blob, frame number:  739
# Tracking the blob, frame number:  740
# Tracking the blob, frame number:  741
# Tracking the blob, frame number:  742
# Tracking the blob, frame number:  743
# Tracking the blob, frame number:  744
# Tracking the blob, frame number:  745
# Tracking the blob, frame number:  746
# Tracking the blob, frame number:  747
# Tracking the blob, frame number:  748
# Tracking the blob, frame number:  749
# Tracking the blob, frame number:  750
# Tracking the blob, frame number:  751
# Tracking the blob, frame number:  752
# New rightmost blob detected, shift =  21
# Tracking the blob, frame number:  754
# Tracking the blob, frame number:  755
# Tracking the blob, frame number:  756
# Tracking the blob, frame number:  757
# Tracking the blob, frame number:  758
# Tracking the blob, frame number:  759
# Tracking the blob, frame number:  760
# Tracking the blob, frame number:  761
# Tracking the blob, frame number:  762
# Tracking the blob, frame number:  763
# Tracking the blob, frame number:  764
# Tracking the blob, frame number:  765
# Tracking the blob, frame number:  766
# Tracking the blob, frame number:  767
# Tracking the blob, frame number:  768
# Tracking the blob, frame number:  769
# Tracking the blob, frame number:  770
# Tracking the blob, frame number:  771
# Tracking the blob, frame number:  772
# Tracking the blob, frame number:  773
# Tracking the blob, frame number:  774
# Tracking the blob, frame number:  775
# Tracking the blob, frame number:  776
# Tracking the blob, frame number:  777
# Tracking the blob, frame number:  778
# Tracking the blob, frame number:  779
# Tracking the blob, frame number:  780
# Tracking the blob, frame number:  781
# Tracking the blob, frame number:  782
# Tracking the blob, frame number:  783
# Tracking the blob, frame number:  784
# Tracking the blob, frame number:  785
# Tracking the blob, frame number:  786
# Tracking the blob, frame number:  787
# Tracking the blob, frame number:  788
# Tracking the blob, frame number:  789
# Tracking the blob, frame number:  790
# New rightmost blob detected, shift =  22
# Tracking the blob, frame number:  792
# Tracking the blob, frame number:  793
# Tracking the blob, frame number:  794
# Tracking the blob, frame number:  795
# Tracking the blob, frame number:  796
# Tracking the blob, frame number:  797
# Tracking the blob, frame number:  798
# Tracking the blob, frame number:  799
# Tracking the blob, frame number:  800
# Tracking the blob, frame number:  801
# Tracking the blob, frame number:  802
# Tracking the blob, frame number:  803
# Tracking the blob, frame number:  804
# Tracking the blob, frame number:  805
# Tracking the blob, frame number:  806
# Tracking the blob, frame number:  807
# Tracking the blob, frame number:  808
# Tracking the blob, frame number:  809
# Tracking the blob, frame number:  810
# Tracking the blob, frame number:  811
# Tracking the blob, frame number:  812
# Tracking the blob, frame number:  813
# Tracking the blob, frame number:  814
# Tracking the blob, frame number:  815
# Tracking the blob, frame number:  816
# Tracking the blob, frame number:  817
# Tracking the blob, frame number:  818
# Tracking the blob, frame number:  819
# Tracking the blob, frame number:  820
# Tracking the blob, frame number:  821
# Tracking the blob, frame number:  822
# Tracking the blob, frame number:  823
# Tracking the blob, frame number:  824
# Tracking the blob, frame number:  825
# Tracking the blob, frame number:  826
# Tracking the blob, frame number:  827
# Tracking the blob, frame number:  828
# Tracking the blob, frame number:  829
# Tracking the blob, frame number:  830
# Tracking the blob, frame number:  831
# Tracking the blob, frame number:  832
# New rightmost blob detected, shift =  23
# Tracking the blob, frame number:  834
# Tracking the blob, frame number:  835
# Tracking the blob, frame number:  836
# Tracking the blob, frame number:  837
# Tracking the blob, frame number:  838
# Tracking the blob, frame number:  839
# Tracking the blob, frame number:  840
# Tracking the blob, frame number:  841
# Tracking the blob, frame number:  842
# Tracking the blob, frame number:  843
# Tracking the blob, frame number:  844
# Tracking the blob, frame number:  845
# Tracking the blob, frame number:  846
# Tracking the blob, frame number:  847
# Tracking the blob, frame number:  848
# Tracking the blob, frame number:  849
# Tracking the blob, frame number:  850
# Tracking the blob, frame number:  851
# Tracking the blob, frame number:  852
# Tracking the blob, frame number:  853
# New rightmost blob detected, shift =  24
# Tracking the blob, frame number:  855
# Tracking the blob, frame number:  856
# Tracking the blob, frame number:  857
# Tracking the blob, frame number:  858
# Tracking the blob, frame number:  859
# Tracking the blob, frame number:  860
# Tracking the blob, frame number:  861
# Tracking the blob, frame number:  862
# Tracking the blob, frame number:  863
# Tracking the blob, frame number:  864
# Tracking the blob, frame number:  865
# Tracking the blob, frame number:  866
# Tracking the blob, frame number:  867
# Tracking the blob, frame number:  868
# Tracking the blob, frame number:  869
# Tracking the blob, frame number:  870
# Tracking the blob, frame number:  871
# New rightmost blob detected, shift =  25
# Tracking the blob, frame number:  873
# Tracking the blob, frame number:  874
# Tracking the blob, frame number:  875
# Tracking the blob, frame number:  876
# Tracking the blob, frame number:  877
# Tracking the blob, frame number:  878
# Tracking the blob, frame number:  879
# Tracking the blob, frame number:  880
# Tracking the blob, frame number:  881
# Tracking the blob, frame number:  882
# Tracking the blob, frame number:  883
# Tracking the blob, frame number:  884
# Tracking the blob, frame number:  885
# Tracking the blob, frame number:  886
# Tracking the blob, frame number:  887
# Tracking the blob, frame number:  888
# Tracking the blob, frame number:  889
# Tracking the blob, frame number:  890
# Tracking the blob, frame number:  891
# Tracking the blob, frame number:  892
# Tracking the blob, frame number:  893
# Tracking the blob, frame number:  894
# Tracking the blob, frame number:  895
# Tracking the blob, frame number:  896
# Tracking the blob, frame number:  897
# Tracking the blob, frame number:  898
# Tracking the blob, frame number:  899
# Tracking the blob, frame number:  900
# Tracking the blob, frame number:  901
# Tracking the blob, frame number:  902
# Tracking the blob, frame number:  903
# Tracking the blob, frame number:  904
# Tracking the blob, frame number:  905
# Tracking the blob, frame number:  906
# Tracking the blob, frame number:  907
# Tracking the blob, frame number:  908
# Tracking the blob, frame number:  909
# Tracking the blob, frame number:  910
# Tracking the blob, frame number:  911
# Tracking the blob, frame number:  912
# Tracking the blob, frame number:  913
# Tracking the blob, frame number:  914
# Tracking the blob, frame number:  915
# Tracking the blob, frame number:  916
# Tracking the blob, frame number:  917
# Tracking the blob, frame number:  918
# Tracking the blob, frame number:  919
# Tracking the blob, frame number:  920
# Tracking the blob, frame number:  921
# Tracking the blob, frame number:  922
# Tracking the blob, frame number:  923
# Tracking the blob, frame number:  924
# New rightmost blob detected, shift =  26
# Tracking the blob, frame number:  926
# Tracking the blob, frame number:  927
# Tracking the blob, frame number:  928
# Tracking the blob, frame number:  929
# Tracking the blob, frame number:  930
# Tracking the blob, frame number:  931
# Tracking the blob, frame number:  932
# Tracking the blob, frame number:  933
# Tracking the blob, frame number:  934
# Tracking the blob, frame number:  935
# Tracking the blob, frame number:  936
# Tracking the blob, frame number:  937
# Tracking the blob, frame number:  938
# Tracking the blob, frame number:  939
# Tracking the blob, frame number:  940
# Tracking the blob, frame number:  941
# Tracking the blob, frame number:  942
# Tracking the blob, frame number:  943
# Tracking the blob, frame number:  944
# Tracking the blob, frame number:  945
# Tracking the blob, frame number:  946
# Tracking the blob, frame number:  947
# Tracking the blob, frame number:  948
# Tracking the blob, frame number:  949
# Tracking the blob, frame number:  950
# Tracking the blob, frame number:  951
# Tracking the blob, frame number:  952
# Tracking the blob, frame number:  953
# Tracking the blob, frame number:  954
# Tracking the blob, frame number:  955
# Tracking the blob, frame number:  956
# Tracking the blob, frame number:  957
# Tracking the blob, frame number:  958
# Tracking the blob, frame number:  959
# Tracking the blob, frame number:  960
# Tracking the blob, frame number:  961
# Tracking the blob, frame number:  962
# Tracking the blob, frame number:  963
# Tracking the blob, frame number:  964
# Tracking the blob, frame number:  965
# New rightmost blob detected, shift =  27
# Tracking the blob, frame number:  967
# Tracking the blob, frame number:  968
# Tracking the blob, frame number:  969
# Tracking the blob, frame number:  970
# Tracking the blob, frame number:  971
# Tracking the blob, frame number:  972
# Tracking the blob, frame number:  973
# Tracking the blob, frame number:  974
# Tracking the blob, frame number:  975
# Tracking the blob, frame number:  976
# Tracking the blob, frame number:  977
# Tracking the blob, frame number:  978
# Tracking the blob, frame number:  979
# Tracking the blob, frame number:  980
# Tracking the blob, frame number:  981
# Tracking the blob, frame number:  982
# Tracking the blob, frame number:  983
# Tracking the blob, frame number:  984
# Tracking the blob, frame number:  985
# Tracking the blob, frame number:  986
# Tracking the blob, frame number:  987
# Tracking the blob, frame number:  988
# Tracking the blob, frame number:  989
# Tracking the blob, frame number:  990
# Tracking the blob, frame number:  991
# Tracking the blob, frame number:  992
# Tracking the blob, frame number:  993
# Tracking the blob, frame number:  994
# Tracking the blob, frame number:  995
# Tracking the blob, frame number:  996
# Tracking the blob, frame number:  997
# Tracking the blob, frame number:  998
# Tracking the blob, frame number:  999
# Tracking the blob, frame number:  1000
# Tracking the blob, frame number:  1001
# Tracking the blob, frame number:  1002
# Tracking the blob, frame number:  1003
# Tracking the blob, frame number:  1004
# Tracking the blob, frame number:  1005
# Tracking the blob, frame number:  1006
# Tracking the blob, frame number:  1007
# Tracking the blob, frame number:  1008
# Tracking the blob, frame number:  1009
# Tracking the blob, frame number:  1010
# Tracking the blob, frame number:  1011
# Tracking the blob, frame number:  1012
# Tracking the blob, frame number:  1013
# Tracking the blob, frame number:  1014
# Tracking the blob, frame number:  1015
# Tracking the blob, frame number:  1016
# Tracking the blob, frame number:  1017
# Tracking the blob, frame number:  1018
# Tracking the blob, frame number:  1019
# Tracking the blob, frame number:  1020
# Tracking the blob, frame number:  1021
# New rightmost blob detected, shift =  28
# Tracking the blob, frame number:  1023
# Tracking the blob, frame number:  1024
# Tracking the blob, frame number:  1025
# Tracking the blob, frame number:  1026
# Tracking the blob, frame number:  1027
# Tracking the blob, frame number:  1028
# Tracking the blob, frame number:  1029
# Tracking the blob, frame number:  1030
# Tracking the blob, frame number:  1031
# Tracking the blob, frame number:  1032
# Tracking the blob, frame number:  1033
# Tracking the blob, frame number:  1034
# Tracking the blob, frame number:  1035
# Tracking the blob, frame number:  1036
# Tracking the blob, frame number:  1037
# Tracking the blob, frame number:  1038
# Tracking the blob, frame number:  1039
# Tracking the blob, frame number:  1040
# Tracking the blob, frame number:  1041
# Tracking the blob, frame number:  1042
# Tracking the blob, frame number:  1043
# Tracking the blob, frame number:  1044
# Tracking the blob, frame number:  1045
# Tracking the blob, frame number:  1046
# Tracking the blob, frame number:  1047
# Tracking the blob, frame number:  1048
# Tracking the blob, frame number:  1049
# Tracking the blob, frame number:  1050
# Tracking the blob, frame number:  1051
# New rightmost blob detected, shift =  29
# Tracking the blob, frame number:  1053
# Tracking the blob, frame number:  1054
# Tracking the blob, frame number:  1055
# Tracking the blob, frame number:  1056
# Tracking the blob, frame number:  1057
# Tracking the blob, frame number:  1058
# Tracking the blob, frame number:  1059
# Tracking the blob, frame number:  1060
# Tracking the blob, frame number:  1061
# Tracking the blob, frame number:  1062
# Tracking the blob, frame number:  1063
# Tracking the blob, frame number:  1064
# New rightmost blob detected, shift =  30
# Tracking the blob, frame number:  1066
# Tracking the blob, frame number:  1067
# Tracking the blob, frame number:  1068
# Tracking the blob, frame number:  1069
# Tracking the blob, frame number:  1070
# Tracking the blob, frame number:  1071
# Tracking the blob, frame number:  1072
# Tracking the blob, frame number:  1073
# Tracking the blob, frame number:  1074
# Tracking the blob, frame number:  1075
# Tracking the blob, frame number:  1076
# Tracking the blob, frame number:  1077
# Tracking the blob, frame number:  1078
# Tracking the blob, frame number:  1079
# Tracking the blob, frame number:  1080
# Tracking the blob, frame number:  1081
# Tracking the blob, frame number:  1082
# Tracking the blob, frame number:  1083
# Tracking the blob, frame number:  1084
# Tracking the blob, frame number:  1085
# Tracking the blob, frame number:  1086
# Tracking the blob, frame number:  1087
# Tracking the blob, frame number:  1088
# Tracking the blob, frame number:  1089
# Tracking the blob, frame number:  1090
# Tracking the blob, frame number:  1091
# Tracking the blob, frame number:  1092
# Tracking the blob, frame number:  1093
# Tracking the blob, frame number:  1094
# Tracking the blob, frame number:  1095
# Tracking the blob, frame number:  1096
# Tracking the blob, frame number:  1097
# Tracking the blob, frame number:  1098
# Tracking the blob, frame number:  1099
# Tracking the blob, frame number:  1100
# Tracking the blob, frame number:  1101
# Tracking the blob, frame number:  1102
# Tracking the blob, frame number:  1103
# Tracking the blob, frame number:  1104
# Tracking the blob, frame number:  1105
# Tracking the blob, frame number:  1106
# Tracking the blob, frame number:  1107
# Tracking the blob, frame number:  1108
# Tracking the blob, frame number:  1109
# Tracking the blob, frame number:  1110
# Tracking the blob, frame number:  1111
# Tracking the blob, frame number:  1112
# Tracking the blob, frame number:  1113
# Tracking the blob, frame number:  1114
# Tracking the blob, frame number:  1115
# Tracking the blob, frame number:  1116
# Tracking the blob, frame number:  1117
# Tracking the blob, frame number:  1118
# Tracking the blob, frame number:  1119
# Tracking the blob, frame number:  1120
# Tracking the blob, frame number:  1121
# Tracking the blob, frame number:  1122
# Tracking the blob, frame number:  1123
# Tracking the blob, frame number:  1124
# Tracking the blob, frame number:  1125
# Tracking the blob, frame number:  1126
# Tracking the blob, frame number:  1127
# Tracking the blob, frame number:  1128
# Tracking the blob, frame number:  1129
# Tracking the blob, frame number:  1130
# Tracking the blob, frame number:  1131
# Tracking the blob, frame number:  1132
# Tracking the blob, frame number:  1133
# Tracking the blob, frame number:  1134
# Tracking the blob, frame number:  1135
# Tracking the blob, frame number:  1136
# Tracking the blob, frame number:  1137
# Tracking the blob, frame number:  1138
# Tracking the blob, frame number:  1139
# Tracking the blob, frame number:  1140
# Tracking the blob, frame number:  1141
# Tracking the blob, frame number:  1142
# Tracking the blob, frame number:  1143
# Tracking the blob, frame number:  1144
# Tracking the blob, frame number:  1145
# Tracking the blob, frame number:  1146
# Tracking the blob, frame number:  1147
# Tracking the blob, frame number:  1148
# Tracking the blob, frame number:  1149
# Tracking the blob, frame number:  1150
# Tracking the blob, frame number:  1151
# Tracking the blob, frame number:  1152
# Tracking the blob, frame number:  1153
# Tracking the blob, frame number:  1154
# Tracking the blob, frame number:  1155
# Tracking the blob, frame number:  1156
# Tracking the blob, frame number:  1157
# Tracking the blob, frame number:  1158
# Tracking the blob, frame number:  1159
# Tracking the blob, frame number:  1160
# Tracking the blob, frame number:  1161
# Tracking the blob, frame number:  1162
# New rightmost blob detected, shift =  31
# Tracking the blob, frame number:  1164
# Tracking the blob, frame number:  1165
# Tracking the blob, frame number:  1166
# Tracking the blob, frame number:  1167
# Tracking the blob, frame number:  1168
# Tracking the blob, frame number:  1169
# Tracking the blob, frame number:  1170
# Tracking the blob, frame number:  1171
# Tracking the blob, frame number:  1172
# Tracking the blob, frame number:  1173
# Tracking the blob, frame number:  1174
# Tracking the blob, frame number:  1175
# Tracking the blob, frame number:  1176
# Tracking the blob, frame number:  1177
# Tracking the blob, frame number:  1178
# Tracking the blob, frame number:  1179
# Tracking the blob, frame number:  1180
# Tracking the blob, frame number:  1181
# Tracking the blob, frame number:  1182
# Tracking the blob, frame number:  1183
# Tracking the blob, frame number:  1184
# Tracking the blob, frame number:  1185
# Tracking the blob, frame number:  1186
# Tracking the blob, frame number:  1187
# Tracking the blob, frame number:  1188
# Tracking the blob, frame number:  1189
# Tracking the blob, frame number:  1190
# New rightmost blob detected, shift =  32
# Tracking the blob, frame number:  1192
# Tracking the blob, frame number:  1193
# Tracking the blob, frame number:  1194
# Tracking the blob, frame number:  1195
# Tracking the blob, frame number:  1196
# Tracking the blob, frame number:  1197
# Tracking the blob, frame number:  1198
# Tracking the blob, frame number:  1199
# Tracking the blob, frame number:  1200
# Tracking the blob, frame number:  1201
# Tracking the blob, frame number:  1202
# Tracking the blob, frame number:  1203
# Tracking the blob, frame number:  1204
# Tracking the blob, frame number:  1205
# Tracking the blob, frame number:  1206
# Tracking the blob, frame number:  1207
# Tracking the blob, frame number:  1208
# Tracking the blob, frame number:  1209
# Tracking the blob, frame number:  1210
# Tracking the blob, frame number:  1211
# Tracking the blob, frame number:  1212
# Tracking the blob, frame number:  1213
# Tracking the blob, frame number:  1214
# Tracking the blob, frame number:  1215
# Tracking the blob, frame number:  1216
# Tracking the blob, frame number:  1217
# Tracking the blob, frame number:  1218
# Tracking the blob, frame number:  1219
# Tracking the blob, frame number:  1220
# Tracking the blob, frame number:  1221
# Tracking the blob, frame number:  1222
# Tracking the blob, frame number:  1223
# Tracking the blob, frame number:  1224
# Tracking the blob, frame number:  1225
# Tracking the blob, frame number:  1226
# Tracking the blob, frame number:  1227
# New rightmost blob detected, shift =  33
# Tracking the blob, frame number:  1229
# Tracking the blob, frame number:  1230
# Tracking the blob, frame number:  1231
# Tracking the blob, frame number:  1232
# Tracking the blob, frame number:  1233
# Tracking the blob, frame number:  1234
# Tracking the blob, frame number:  1235
# Tracking the blob, frame number:  1236
# Tracking the blob, frame number:  1237
# Tracking the blob, frame number:  1238
# Tracking the blob, frame number:  1239
# Tracking the blob, frame number:  1240
# Tracking the blob, frame number:  1241
# Tracking the blob, frame number:  1242
# Tracking the blob, frame number:  1243
# Tracking the blob, frame number:  1244
# Tracking the blob, frame number:  1245
# Tracking the blob, frame number:  1246
# Tracking the blob, frame number:  1247
# Tracking the blob, frame number:  1248
# Tracking the blob, frame number:  1249
# Tracking the blob, frame number:  1250
# Tracking the blob, frame number:  1251
# Tracking the blob, frame number:  1252
# Tracking the blob, frame number:  1253
# Tracking the blob, frame number:  1254
# Tracking the blob, frame number:  1255
# Tracking the blob, frame number:  1256
# Tracking the blob, frame number:  1257
# ...
# Tracking the blob, frame number:  1765
# Tracking the blob, frame number:  1766
# Tracking the blob, frame number:  1767
# Tracking the blob, frame number:  1768
# Tracking the blob, frame number:  1769
# Tracking the blob, frame number:  1770
# Tracking the blob, frame number:  1771
# Tracking the blob, frame number:  1772
# Tracking the blob, frame number:  1773
# Tracking the blob, frame number:  1774
# Tracking the blob, frame number:  1775
# Tracking the blob, frame number:  1776
# Tracking the blob, frame number:  1777
# Tracking the blob, frame number:  1778
# Tracking the blob, frame number:  1779
# Tracking the blob, frame number:  1780
# Tracking the blob, frame number:  1781
# Tracking the blob, frame number:  1782
# Tracking the blob, frame number:  1783
# Tracking the blob, frame number:  1784
# Tracking the blob, frame number:  1785
# Tracking the blob, frame number:  1786
# Tracking the blob, frame number:  1787
# Tracking the blob, frame number:  1788
# Tracking the blob, frame number:  1789
# Tracking the blob, frame number:  1790
# Tracking the blob, frame number:  1791
# Tracking the blob, frame number:  1792
# Tracking the blob, frame number:  1793
# Tracking the blob, frame number:  1794
# Tracking the blob, frame number:  1795
# Tracking the blob, frame number:  1796
# Tracking the blob, frame number:  1797
# Tracking the blob, frame number:  1798
# Tracking the blob, frame number:  1799
# Tracking the blob, frame number:  1800
# Tracking the blob, frame number:  1801
# Tracking the blob, frame number:  1802
# Tracking the blob, frame number:  1803
# Tracking the blob, frame number:  1804
# Tracking the blob, frame number:  1805
# Tracking the blob, frame number:  1806
# Tracking the blob, frame number:  1807
# Tracking the blob, frame number:  1808
# Tracking the blob, frame number:  1809
# Tracking the blob, frame number:  1810
# Tracking the blob, frame number:  1811
# Tracking the blob, frame number:  1812
# Tracking the blob, frame number:  1813
# Tracking the blob, frame number:  1814
# Tracking the blob, frame number:  1815
# Tracking the blob, frame number:  1816
# Tracking the blob, frame number:  1817
# Tracking the blob, frame number:  1818
# Tracking the blob, frame number:  1819
# Tracking the blob, frame number:  1820
# Tracking the blob, frame number:  1821
# Tracking the blob, frame number:  1822
# Tracking the blob, frame number:  1823
# Tracking the blob, frame number:  1824
# Tracking the blob, frame number:  1825
# Tracking the blob, frame number:  1826
# Tracking the blob, frame number:  1827
# Tracking the blob, frame number:  1828
# Tracking the blob, frame number:  1829
# Tracking the blob, frame number:  1830
# Tracking the blob, frame number:  1831
# Tracking the blob, frame number:  1832
# Tracking the blob, frame number:  1833
# Tracking the blob, frame number:  1834
# Tracking the blob, frame number:  1835
# Tracking the blob, frame number:  1836
# Tracking the blob, frame number:  1837
# Tracking the blob, frame number:  1838
# Tracking the blob, frame number:  1839
# Tracking the blob, frame number:  1840
# Tracking the blob, frame number:  1841
# Tracking the blob, frame number:  1842
# Tracking the blob, frame number:  1843
# Tracking the blob, frame number:  1844
# Tracking the blob, frame number:  1845
# Tracking the blob, frame number:  1846
# Tracking the blob, frame number:  1847
# Tracking the blob, frame number:  1848
# Tracking the blob, frame number:  1849
# Tracking the blob, frame number:  1850
# Tracking the blob, frame number:  1851
# Tracking the blob, frame number:  1852
# Tracking the blob, frame number:  1853
# Tracking the blob, frame number:  1854
# Tracking the blob, frame number:  1855
# Tracking the blob, frame number:  1856
# Tracking the blob, frame number:  1857
# Tracking the blob, frame number:  1858
# Tracking the blob, frame number:  1859
# Tracking the blob, frame number:  1860
# Tracking the blob, frame number:  1861
# Tracking the blob, frame number:  1862
# Tracking the blob, frame number:  1863
# Tracking the blob, frame number:  1864
# Tracking the blob, frame number:  1865
# Tracking the blob, frame number:  1866
# Tracking the blob, frame number:  1867
# Tracking the blob, frame number:  1868
# Tracking the blob, frame number:  1869
# Tracking the blob, frame number:  1870
# Tracking the blob, frame number:  1871
# Tracking the blob, frame number:  1872
# Tracking the blob, frame number:  1873
# Tracking the blob, frame number:  1874
# Tracking the blob, frame number:  1875
# Tracking the blob, frame number:  1876
# Tracking the blob, frame number:  1877
# Tracking the blob, frame number:  1878
# New rightmost blob detected, shift =  75
# Tracking the blob, frame number:  1880
# Tracking the blob, frame number:  1881
# Tracking the blob, frame number:  1882
# Tracking the blob, frame number:  1883
# Tracking the blob, frame number:  1884
# Tracking the blob, frame number:  1885
# Tracking the blob, frame number:  1886
# Tracking the blob, frame number:  1887
# New rightmost blob detected, shift =  76
# Tracking the blob, frame number:  1889
# Tracking the blob, frame number:  1890
# Tracking the blob, frame number:  1891
# Tracking the blob, frame number:  1892
# Tracking the blob, frame number:  1893
# New rightmost blob detected, shift =  77
# New rightmost blob detected, shift =  78
# Tracking the blob, frame number:  1896
# Tracking the blob, frame number:  1897
# Tracking the blob, frame number:  1898
# Tracking the blob, frame number:  1899
# New rightmost blob detected, shift =  79
# Tracking the blob, frame number:  1901
# Tracking the blob, frame number:  1902
# Tracking the blob, frame number:  1903
# Tracking the blob, frame number:  1904
# Tracking the blob, frame number:  1905
# Tracking the blob, frame number:  1906
# Tracking the blob, frame number:  1907
# Tracking the blob, frame number:  1908
# Tracking the blob, frame number:  1909
# Tracking the blob, frame number:  1910
# Tracking the blob, frame number:  1911
# Tracking the blob, frame number:  1912
# Tracking the blob, frame number:  1913
# Tracking the blob, frame number:  1914
# Tracking the blob, frame number:  1915
# Tracking the blob, frame number:  1916
# Tracking the blob, frame number:  1917
# Tracking the blob, frame number:  1918
# Tracking the blob, frame number:  1919
# Tracking the blob, frame number:  1920
# Tracking the blob, frame number:  1921
# Tracking the blob, frame number:  1922
# Tracking the blob, frame number:  1923
# Tracking the blob, frame number:  1924
# Tracking the blob, frame number:  1925
# Tracking the blob, frame number:  1926
# Tracking the blob, frame number:  1927
# Tracking the blob, frame number:  1928
# Tracking the blob, frame number:  1929
# Tracking the blob, frame number:  1930
# Tracking the blob, frame number:  1931
# New rightmost blob detected, shift =  80
# Tracking the blob, frame number:  1933
# Tracking the blob, frame number:  1934
# Tracking the blob, frame number:  1935
# Tracking the blob, frame number:  1936
# Tracking the blob, frame number:  1937
# Tracking the blob, frame number:  1938
# Tracking the blob, frame number:  1939
# Tracking the blob, frame number:  1940
# Tracking the blob, frame number:  1941
# Tracking the blob, frame number:  1942
# Tracking the blob, frame number:  1943
# Tracking the blob, frame number:  1944
# Tracking the blob, frame number:  1945
# Tracking the blob, frame number:  1946
# New rightmost blob detected, shift =  81
# Tracking the blob, frame number:  1948
# Tracking the blob, frame number:  1949
# Tracking the blob, frame number:  1950
# Tracking the blob, frame number:  1951
# Tracking the blob, frame number:  1952
# Tracking the blob, frame number:  1953
# Tracking the blob, frame number:  1954
# Tracking the blob, frame number:  1955
# Tracking the blob, frame number:  1956
# Tracking the blob, frame number:  1957
# Tracking the blob, frame number:  1958
# New rightmost blob detected, shift =  82
# Tracking the blob, frame number:  1960
# Tracking the blob, frame number:  1961
# Tracking the blob, frame number:  1962
# Tracking the blob, frame number:  1963
# Tracking the blob, frame number:  1964
# Tracking the blob, frame number:  1965
# Tracking the blob, frame number:  1966
# Tracking the blob, frame number:  1967
# Tracking the blob, frame number:  1968
# Tracking the blob, frame number:  1969
# Tracking the blob, frame number:  1970
# New rightmost blob detected, shift =  83
# Tracking the blob, frame number:  1972
# Tracking the blob, frame number:  1973
# Tracking the blob, frame number:  1974
# Tracking the blob, frame number:  1975
# Tracking the blob, frame number:  1976
# Tracking the blob, frame number:  1977
# Tracking the blob, frame number:  1978
# Tracking the blob, frame number:  1979
# Tracking the blob, frame number:  1980
# Tracking the blob, frame number:  1981
# Tracking the blob, frame number:  1982
# Tracking the blob, frame number:  1983
# New rightmost blob detected, shift =  84
# Tracking the blob, frame number:  1985
# Tracking the blob, frame number:  1986
# Tracking the blob, frame number:  1987
# Tracking the blob, frame number:  1988
# Tracking the blob, frame number:  1989
# Tracking the blob, frame number:  1990
# Tracking the blob, frame number:  1991
# Tracking the blob, frame number:  1992
# Tracking the blob, frame number:  1993
# Tracking the blob, frame number:  1994
# Tracking the blob, frame number:  1995
# Tracking the blob, frame number:  1996
# Tracking the blob, frame number:  1997
# Tracking the blob, frame number:  1998
# New rightmost blob detected, shift =  85
# Tracking the blob, frame number:  2000
# Tracking the blob, frame number:  2001
# Tracking the blob, frame number:  2002
# Tracking the blob, frame number:  2003
# Tracking the blob, frame number:  2004
# Tracking the blob, frame number:  2005
# Tracking the blob, frame number:  2006
# Tracking the blob, frame number:  2007
# Tracking the blob, frame number:  2008
# Tracking the blob, frame number:  2009
# Tracking the blob, frame number:  2010
# Tracking the blob, frame number:  2011
# Tracking the blob, frame number:  2012
# Tracking the blob, frame number:  2013
# Tracking the blob, frame number:  2014
# Tracking the blob, frame number:  2015
# Tracking the blob, frame number:  2016
# Tracking the blob, frame number:  2017
# Tracking the blob, frame number:  2018
# Tracking the blob, frame number:  2019
# New rightmost blob detected, shift =  86
# Tracking the blob, frame number:  2021
# Tracking the blob, frame number:  2022
# Tracking the blob, frame number:  2023
# Tracking the blob, frame number:  2024
# Tracking the blob, frame number:  2025
# Tracking the blob, frame number:  2026
# Tracking the blob, frame number:  2027
# Tracking the blob, frame number:  2028
# Tracking the blob, frame number:  2029
# Tracking the blob, frame number:  2030
# Tracking the blob, frame number:  2031
# Tracking the blob, frame number:  2032
# Tracking the blob, frame number:  2033
# Tracking the blob, frame number:  2034
# New rightmost blob detected, shift =  87
# Tracking the blob, frame number:  2036
# Tracking the blob, frame number:  2037
# Tracking the blob, frame number:  2038
# Tracking the blob, frame number:  2039
# Tracking the blob, frame number:  2040
# Tracking the blob, frame number:  2041
# Tracking the blob, frame number:  2042
# Tracking the blob, frame number:  2043
# Tracking the blob, frame number:  2044
# Tracking the blob, frame number:  2045
# Tracking the blob, frame number:  2046
# Tracking the blob, frame number:  2047
# Tracking the blob, frame number:  2048
# Tracking the blob, frame number:  2049
# Tracking the blob, frame number:  2050
# Tracking the blob, frame number:  2051
# Tracking the blob, frame number:  2052
# Tracking the blob, frame number:  2053
# Tracking the blob, frame number:  2054
# Tracking the blob, frame number:  2055
# Tracking the blob, frame number:  2056
# Tracking the blob, frame number:  2057
# New rightmost blob detected, shift =  88
# Tracking the blob, frame number:  2059
# Tracking the blob, frame number:  2060
# Tracking the blob, frame number:  2061
# Tracking the blob, frame number:  2062
# Tracking the blob, frame number:  2063
# Tracking the blob, frame number:  2064
# Tracking the blob, frame number:  2065
# Tracking the blob, frame number:  2066
# Tracking the blob, frame number:  2067
# Tracking the blob, frame number:  2068
# Tracking the blob, frame number:  2069
# Tracking the blob, frame number:  2070
# Tracking the blob, frame number:  2071
# Tracking the blob, frame number:  2072
# Tracking the blob, frame number:  2073
# Tracking the blob, frame number:  2074
# Tracking the blob, frame number:  2075
# Tracking the blob, frame number:  2076
# Tracking the blob, frame number:  2077
# New rightmost blob detected, shift =  89
# Tracking the blob, frame number:  2079
# Tracking the blob, frame number:  2080
# Tracking the blob, frame number:  2081
# Tracking the blob, frame number:  2082
# Tracking the blob, frame number:  2083
# Tracking the blob, frame number:  2084
# Tracking the blob, frame number:  2085
# Tracking the blob, frame number:  2086
# Tracking the blob, frame number:  2087
# Tracking the blob, frame number:  2088
# New rightmost blob detected, shift =  90
# Tracking the blob, frame number:  2090
# Tracking the blob, frame number:  2091
# Tracking the blob, frame number:  2092
# Tracking the blob, frame number:  2093
# Tracking the blob, frame number:  2094
# Tracking the blob, frame number:  2095
# Tracking the blob, frame number:  2096
# Tracking the blob, frame number:  2097
# Tracking the blob, frame number:  2098
# Tracking the blob, frame number:  2099
# Tracking the blob, frame number:  2100
# Tracking the blob, frame number:  2101
# Tracking the blob, frame number:  2102
# Tracking the blob, frame number:  2103
# Tracking the blob, frame number:  2104
# New rightmost blob detected, shift =  91
# Tracking the blob, frame number:  2106
# Tracking the blob, frame number:  2107
# Tracking the blob, frame number:  2108
# Tracking the blob, frame number:  2109
# Tracking the blob, frame number:  2110
# Tracking the blob, frame number:  2111
# Tracking the blob, frame number:  2112
# Tracking the blob, frame number:  2113
# Tracking the blob, frame number:  2114
# Tracking the blob, frame number:  2115
# Tracking the blob, frame number:  2116
# Tracking the blob, frame number:  2117
# Tracking the blob, frame number:  2118
# Tracking the blob, frame number:  2119
# Tracking the blob, frame number:  2120
# Tracking the blob, frame number:  2121
# Tracking the blob, frame number:  2122
# Tracking the blob, frame number:  2123
# Tracking the blob, frame number:  2124
# New rightmost blob detected, shift =  92
# Tracking the blob, frame number:  2126
# Tracking the blob, frame number:  2127
# Tracking the blob, frame number:  2128
# Tracking the blob, frame number:  2129
# Tracking the blob, frame number:  2130
# Tracking the blob, frame number:  2131
# Tracking the blob, frame number:  2132
# Tracking the blob, frame number:  2133
# Tracking the blob, frame number:  2134
# Tracking the blob, frame number:  2135
# Tracking the blob, frame number:  2136
# Tracking the blob, frame number:  2137
# Tracking the blob, frame number:  2138
# Tracking the blob, frame number:  2139
# Tracking the blob, frame number:  2140
# Tracking the blob, frame number:  2141
# Tracking the blob, frame number:  2142
# Tracking the blob, frame number:  2143
# Tracking the blob, frame number:  2144
# Tracking the blob, frame number:  2145
# Tracking the blob, frame number:  2146
# Tracking the blob, frame number:  2147
# Tracking the blob, frame number:  2148
# Tracking the blob, frame number:  2149
# Tracking the blob, frame number:  2150
# Tracking the blob, frame number:  2151
# Tracking the blob, frame number:  2152
# Tracking the blob, frame number:  2153
# Tracking the blob, frame number:  2154
# Tracking the blob, frame number:  2155
# Tracking the blob, frame number:  2156
# Tracking the blob, frame number:  2157
# Tracking the blob, frame number:  2158
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 25
#      22 filled_image = fill_blobs(filtered_image)
#      23 result_image, centroid_positions = detect_rightmost_blobs(filled_image, frame)
# ---> 25 if(in_bounds(previous_centroid, centroid_positions[0])):
#      26     print("Tracking the blob, frame number: ", frame_counter)
#      27 elif(in_bounds(previous_centroid, centroid_positions[1])):
#
# TypeError: 'NoneType' object is not subscriptable

# %%
video_path = 'data/Data/kaniula2.avi'

cap = cv2.VideoCapture(video_path)

previous_centroid = (0.0, 0.0)
shift = 0
radius = 10

frame_counter = 0

while True:
    ret, frame = cap.read()

    if not ret:
        break

    frame_counter += 1

    binary_image = create_binary_image(frame)
    masked_image = apply_mask(binary_image, 125)
    filtered_image = filter_blobs(masked_image)
    filled_image = fill_blobs(filtered_image)
    result_image, centroid_positions = detect_rightmost_blobs(filled_image, frame)

    if(in_bounds(previous_centroid, centroid_positions[0])):
        print("Tracking the blob, frame number: ", frame_counter)
    elif(in_bounds(previous_centroid, centroid_positions[1])):
        shift -= 1
        print("Previous blob disappeared, shift = ", shift)
    elif(not in_bounds(previous_centroid, centroid_positions[0]) and euc_distance(centroid_positions[0], previous_centroid) < 100):
        shift += 1
        print("New rightmost blob detected, shift = ", shift)
        
    previous_centroid = centroid_positions[0]

    cv2.imshow("Binary Image", filled_image)
    cv2.imshow("Result Image", frame)
    cv2.waitKey(1)
# Out:
# Tracking the blob, frame number:  2
# Tracking the blob, frame number:  3
# Tracking the blob, frame number:  4
# Tracking the blob, frame number:  5
# Tracking the blob, frame number:  6
# Tracking the blob, frame number:  7
# Tracking the blob, frame number:  8
# Tracking the blob, frame number:  9
# Tracking the blob, frame number:  10
# Tracking the blob, frame number:  11
# Tracking the blob, frame number:  12
# Tracking the blob, frame number:  13
# Tracking the blob, frame number:  14
# Tracking the blob, frame number:  15
# Tracking the blob, frame number:  16
# Tracking the blob, frame number:  17
# Tracking the blob, frame number:  18
# Tracking the blob, frame number:  19
# Tracking the blob, frame number:  20
# Previous blob disappeared, shift =  -1
# Tracking the blob, frame number:  22
# Tracking the blob, frame number:  23
# Tracking the blob, frame number:  24
# Tracking the blob, frame number:  25
# Tracking the blob, frame number:  26
# Tracking the blob, frame number:  27
# Tracking the blob, frame number:  28
# Tracking the blob, frame number:  29
# Tracking the blob, frame number:  30
# Tracking the blob, frame number:  31
# Tracking the blob, frame number:  32
# Tracking the blob, frame number:  33
# Tracking the blob, frame number:  34
# Tracking the blob, frame number:  35
# Tracking the blob, frame number:  36
# Tracking the blob, frame number:  37
# Tracking the blob, frame number:  38
# Tracking the blob, frame number:  39
# Tracking the blob, frame number:  40
# Tracking the blob, frame number:  41
# Tracking the blob, frame number:  42
# Tracking the blob, frame number:  43
# Tracking the blob, frame number:  44
# Tracking the blob, frame number:  45
# Tracking the blob, frame number:  46
# Tracking the blob, frame number:  47
# Tracking the blob, frame number:  48
# Tracking the blob, frame number:  49
# Tracking the blob, frame number:  50
# Tracking the blob, frame number:  51
# Tracking the blob, frame number:  52
# Tracking the blob, frame number:  53
# Tracking the blob, frame number:  54
# Tracking the blob, frame number:  55
# Tracking the blob, frame number:  56
# Tracking the blob, frame number:  57
# Tracking the blob, frame number:  58
# Tracking the blob, frame number:  59
# Tracking the blob, frame number:  60
# Tracking the blob, frame number:  61
# Tracking the blob, frame number:  62
# Tracking the blob, frame number:  63
# Tracking the blob, frame number:  64
# Tracking the blob, frame number:  65
# Tracking the blob, frame number:  66
# Tracking the blob, frame number:  67
# Tracking the blob, frame number:  68
# Tracking the blob, frame number:  69
# Tracking the blob, frame number:  70
# Tracking the blob, frame number:  71
# Tracking the blob, frame number:  72
# Tracking the blob, frame number:  73
# Tracking the blob, frame number:  74
# Tracking the blob, frame number:  75
# Tracking the blob, frame number:  76
# Tracking the blob, frame number:  77
# Tracking the blob, frame number:  78
# Tracking the blob, frame number:  79
# Tracking the blob, frame number:  80
# Tracking the blob, frame number:  81
# Tracking the blob, frame number:  82
# Tracking the blob, frame number:  83
# Tracking the blob, frame number:  84
# Tracking the blob, frame number:  85
# Tracking the blob, frame number:  86
# Tracking the blob, frame number:  87
# Tracking the blob, frame number:  88
# Tracking the blob, frame number:  89
# Tracking the blob, frame number:  90
# Tracking the blob, frame number:  91
# Tracking the blob, frame number:  92
# Tracking the blob, frame number:  93
# Tracking the blob, frame number:  94
# Tracking the blob, frame number:  95
# Tracking the blob, frame number:  96
# Tracking the blob, frame number:  97
# Tracking the blob, frame number:  98
# Tracking the blob, frame number:  99
# Tracking the blob, frame number:  100
# Tracking the blob, frame number:  101
# Tracking the blob, frame number:  102
# Tracking the blob, frame number:  103
# Tracking the blob, frame number:  104
# Tracking the blob, frame number:  105
# Tracking the blob, frame number:  106
# Tracking the blob, frame number:  107
# Tracking the blob, frame number:  108
# Tracking the blob, frame number:  109
# Tracking the blob, frame number:  110
# Tracking the blob, frame number:  111
# Tracking the blob, frame number:  112
# Tracking the blob, frame number:  113
# Tracking the blob, frame number:  114
# Tracking the blob, frame number:  115
# Tracking the blob, frame number:  116
# Tracking the blob, frame number:  117
# Tracking the blob, frame number:  118
# Tracking the blob, frame number:  119
# Tracking the blob, frame number:  120
# Tracking the blob, frame number:  121
# Tracking the blob, frame number:  122
# Tracking the blob, frame number:  123
# Tracking the blob, frame number:  124
# Tracking the blob, frame number:  125
# Tracking the blob, frame number:  126
# Tracking the blob, frame number:  127
# Tracking the blob, frame number:  128
# Tracking the blob, frame number:  129
# Tracking the blob, frame number:  130
# Tracking the blob, frame number:  131
# Tracking the blob, frame number:  132
# Tracking the blob, frame number:  133
# Tracking the blob, frame number:  134
# Tracking the blob, frame number:  135
# Tracking the blob, frame number:  136
# Tracking the blob, frame number:  137
# Tracking the blob, frame number:  138
# Tracking the blob, frame number:  139
# Tracking the blob, frame number:  140
# Tracking the blob, frame number:  141
# Tracking the blob, frame number:  142
# Tracking the blob, frame number:  143
# Tracking the blob, frame number:  144
# Tracking the blob, frame number:  145
# Tracking the blob, frame number:  146
# Tracking the blob, frame number:  147
# Tracking the blob, frame number:  148
# Tracking the blob, frame number:  149
# Tracking the blob, frame number:  150
# Tracking the blob, frame number:  151
# Tracking the blob, frame number:  152
# Tracking the blob, frame number:  153
# Tracking the blob, frame number:  154
# Tracking the blob, frame number:  155
# Tracking the blob, frame number:  156
# Tracking the blob, frame number:  157
# Tracking the blob, frame number:  158
# Tracking the blob, frame number:  159
# Tracking the blob, frame number:  160
# Tracking the blob, frame number:  161
# Tracking the blob, frame number:  162
# Tracking the blob, frame number:  163
# Tracking the blob, frame number:  164
# Tracking the blob, frame number:  165
# Tracking the blob, frame number:  166
# Tracking the blob, frame number:  167
# Tracking the blob, frame number:  168
# Tracking the blob, frame number:  169
# Tracking the blob, frame number:  170
# Tracking the blob, frame number:  171
# Tracking the blob, frame number:  172
# Tracking the blob, frame number:  173
# Tracking the blob, frame number:  174
# Tracking the blob, frame number:  175
# Tracking the blob, frame number:  176
# Tracking the blob, frame number:  177
# Tracking the blob, frame number:  178
# Tracking the blob, frame number:  179
# Tracking the blob, frame number:  180
# Tracking the blob, frame number:  181
# Tracking the blob, frame number:  182
# Tracking the blob, frame number:  183
# Tracking the blob, frame number:  184
# Tracking the blob, frame number:  185
# Tracking the blob, frame number:  186
# Tracking the blob, frame number:  187
# Tracking the blob, frame number:  188
# Tracking the blob, frame number:  189
# Tracking the blob, frame number:  190
# Tracking the blob, frame number:  191
# Tracking the blob, frame number:  192
# Tracking the blob, frame number:  193
# Tracking the blob, frame number:  194
# Tracking the blob, frame number:  195
# Tracking the blob, frame number:  196
# Tracking the blob, frame number:  197
# Tracking the blob, frame number:  198
# Tracking the blob, frame number:  199
# Tracking the blob, frame number:  200
# Tracking the blob, frame number:  201
# Tracking the blob, frame number:  202
# Tracking the blob, frame number:  203
# Tracking the blob, frame number:  204
# Tracking the blob, frame number:  205
# Tracking the blob, frame number:  206
# Tracking the blob, frame number:  207
# Tracking the blob, frame number:  208
# Tracking the blob, frame number:  209
# Tracking the blob, frame number:  210
# Tracking the blob, frame number:  211
# Tracking the blob, frame number:  212
# Tracking the blob, frame number:  213
# Tracking the blob, frame number:  214
# Tracking the blob, frame number:  215
# Tracking the blob, frame number:  216
# Tracking the blob, frame number:  217
# Tracking the blob, frame number:  218
# Tracking the blob, frame number:  219
# Tracking the blob, frame number:  220
# Tracking the blob, frame number:  221
# Tracking the blob, frame number:  222
# Tracking the blob, frame number:  223
# Tracking the blob, frame number:  224
# Tracking the blob, frame number:  225
# Tracking the blob, frame number:  226
# Tracking the blob, frame number:  227
# Tracking the blob, frame number:  228
# Tracking the blob, frame number:  229
# Tracking the blob, frame number:  230
# Tracking the blob, frame number:  231
# Tracking the blob, frame number:  232
# Tracking the blob, frame number:  233
# Tracking the blob, frame number:  234
# Tracking the blob, frame number:  235
# Tracking the blob, frame number:  236
# Tracking the blob, frame number:  237
# Tracking the blob, frame number:  238
# Tracking the blob, frame number:  239
# Tracking the blob, frame number:  240
# Tracking the blob, frame number:  241
# Tracking the blob, frame number:  242
# Tracking the blob, frame number:  243
# Tracking the blob, frame number:  244
# Tracking the blob, frame number:  245
# Tracking the blob, frame number:  246
# Tracking the blob, frame number:  247
# Tracking the blob, frame number:  248
# Tracking the blob, frame number:  249
# Tracking the blob, frame number:  250
# Tracking the blob, frame number:  251
# Tracking the blob, frame number:  252
# Tracking the blob, frame number:  253
# Tracking the blob, frame number:  254
# Tracking the blob, frame number:  255
# Tracking the blob, frame number:  256
# Tracking the blob, frame number:  257
# Tracking the blob, frame number:  258
# Tracking the blob, frame number:  259
# Tracking the blob, frame number:  260
# Tracking the blob, frame number:  261
# Tracking the blob, frame number:  262
# Tracking the blob, frame number:  263
# Tracking the blob, frame number:  264
# Tracking the blob, frame number:  265
# Tracking the blob, frame number:  266
# New rightmost blob detected, shift =  0
# Tracking the blob, frame number:  268
# Tracking the blob, frame number:  269
# Tracking the blob, frame number:  270
# Tracking the blob, frame number:  271
# Tracking the blob, frame number:  272
# Tracking the blob, frame number:  273
# Tracking the blob, frame number:  274
# Tracking the blob, frame number:  275
# Tracking the blob, frame number:  276
# Tracking the blob, frame number:  277
# Tracking the blob, frame number:  278
# Tracking the blob, frame number:  279
# Tracking the blob, frame number:  280
# Tracking the blob, frame number:  281
# Tracking the blob, frame number:  282
# Tracking the blob, frame number:  283
# Tracking the blob, frame number:  284
# Tracking the blob, frame number:  285
# Tracking the blob, frame number:  286
# Tracking the blob, frame number:  287
# Tracking the blob, frame number:  288
# Tracking the blob, frame number:  289
# Tracking the blob, frame number:  290
# Tracking the blob, frame number:  291
# Tracking the blob, frame number:  292
# Tracking the blob, frame number:  293
# Tracking the blob, frame number:  294
# Tracking the blob, frame number:  295
# Tracking the blob, frame number:  296
# Tracking the blob, frame number:  297
# Tracking the blob, frame number:  298
# Tracking the blob, frame number:  299
# Tracking the blob, frame number:  300
# Tracking the blob, frame number:  301
# Tracking the blob, frame number:  302
# Tracking the blob, frame number:  303
# Tracking the blob, frame number:  304
# Tracking the blob, frame number:  305
# Tracking the blob, frame number:  306
# Tracking the blob, frame number:  307
# Tracking the blob, frame number:  308
# Tracking the blob, frame number:  309
# Tracking the blob, frame number:  310
# Tracking the blob, frame number:  311
# Tracking the blob, frame number:  312
# Tracking the blob, frame number:  313
# Tracking the blob, frame number:  314
# Tracking the blob, frame number:  315
# Tracking the blob, frame number:  316
# Tracking the blob, frame number:  317
# Tracking the blob, frame number:  318
# Tracking the blob, frame number:  319
# New rightmost blob detected, shift =  1
# Tracking the blob, frame number:  321
# Tracking the blob, frame number:  322
# Tracking the blob, frame number:  323
# Tracking the blob, frame number:  324
# Tracking the blob, frame number:  325
# Tracking the blob, frame number:  326
# Tracking the blob, frame number:  327
# Tracking the blob, frame number:  328
# Tracking the blob, frame number:  329
# Tracking the blob, frame number:  330
# Tracking the blob, frame number:  331
# Tracking the blob, frame number:  332
# Tracking the blob, frame number:  333
# Tracking the blob, frame number:  334
# Tracking the blob, frame number:  335
# Tracking the blob, frame number:  336
# Tracking the blob, frame number:  337
# Tracking the blob, frame number:  338
# Tracking the blob, frame number:  339
# Tracking the blob, frame number:  340
# Tracking the blob, frame number:  341
# Tracking the blob, frame number:  342
# Tracking the blob, frame number:  343
# Tracking the blob, frame number:  344
# Tracking the blob, frame number:  345
# Tracking the blob, frame number:  346
# Tracking the blob, frame number:  347
# Tracking the blob, frame number:  348
# Tracking the blob, frame number:  349
# Tracking the blob, frame number:  350
# Tracking the blob, frame number:  351
# Tracking the blob, frame number:  352
# Tracking the blob, frame number:  353
# Tracking the blob, frame number:  354
# Tracking the blob, frame number:  355
# Tracking the blob, frame number:  356
# Tracking the blob, frame number:  357
# Tracking the blob, frame number:  358
# Tracking the blob, frame number:  359
# Tracking the blob, frame number:  360
# Tracking the blob, frame number:  361
# Tracking the blob, frame number:  362
# Tracking the blob, frame number:  363
# Tracking the blob, frame number:  364
# Tracking the blob, frame number:  365
# Tracking the blob, frame number:  366
# Tracking the blob, frame number:  367
# Tracking the blob, frame number:  368
# Tracking the blob, frame number:  369
# Tracking the blob, frame number:  370
# Tracking the blob, frame number:  371
# Tracking the blob, frame number:  372
# Tracking the blob, frame number:  373
# Tracking the blob, frame number:  374
# Tracking the blob, frame number:  375
# Tracking the blob, frame number:  376
# Tracking the blob, frame number:  377
# Tracking the blob, frame number:  378
# Tracking the blob, frame number:  379
# Tracking the blob, frame number:  380
# Tracking the blob, frame number:  381
# Tracking the blob, frame number:  382
# Tracking the blob, frame number:  383
# Tracking the blob, frame number:  384
# Tracking the blob, frame number:  385
# Tracking the blob, frame number:  386
# Tracking the blob, frame number:  387
# Tracking the blob, frame number:  388
# Tracking the blob, frame number:  389
# Tracking the blob, frame number:  390
# Tracking the blob, frame number:  391
# Tracking the blob, frame number:  392
# Tracking the blob, frame number:  393
# Tracking the blob, frame number:  394
# Tracking the blob, frame number:  395
# Tracking the blob, frame number:  396
# Tracking the blob, frame number:  397
# Tracking the blob, frame number:  398
# Tracking the blob, frame number:  399
# Tracking the blob, frame number:  400
# Tracking the blob, frame number:  401
# Tracking the blob, frame number:  402
# Tracking the blob, frame number:  403
# Tracking the blob, frame number:  404
# Tracking the blob, frame number:  405
# Tracking the blob, frame number:  406
# Tracking the blob, frame number:  407
# Tracking the blob, frame number:  408
# Tracking the blob, frame number:  409
# Tracking the blob, frame number:  410
# Tracking the blob, frame number:  411
# Tracking the blob, frame number:  412
# Tracking the blob, frame number:  413
# Tracking the blob, frame number:  414
# Tracking the blob, frame number:  415
# Tracking the blob, frame number:  416
# Tracking the blob, frame number:  417
# Tracking the blob, frame number:  418
# Tracking the blob, frame number:  419
# Tracking the blob, frame number:  420
# Tracking the blob, frame number:  421
# Tracking the blob, frame number:  422
# Tracking the blob, frame number:  423
# Tracking the blob, frame number:  424
# Tracking the blob, frame number:  425
# Tracking the blob, frame number:  426
# Tracking the blob, frame number:  427
# Previous blob disappeared, shift =  0
# Tracking the blob, frame number:  429
# Tracking the blob, frame number:  430
# Tracking the blob, frame number:  431
# Tracking the blob, frame number:  432
# Tracking the blob, frame number:  433
# Tracking the blob, frame number:  434
# Tracking the blob, frame number:  435
# Tracking the blob, frame number:  436
# Tracking the blob, frame number:  437
# Tracking the blob, frame number:  438
# Tracking the blob, frame number:  439
# Tracking the blob, frame number:  440
# Tracking the blob, frame number:  441
# Tracking the blob, frame number:  442
# Tracking the blob, frame number:  443
# Tracking the blob, frame number:  444
# Tracking the blob, frame number:  445
# Tracking the blob, frame number:  446
# Tracking the blob, frame number:  447
# Tracking the blob, frame number:  448
# Tracking the blob, frame number:  449
# Tracking the blob, frame number:  450
# Tracking the blob, frame number:  451
# Tracking the blob, frame number:  452
# Tracking the blob, frame number:  453
# Tracking the blob, frame number:  454
# Tracking the blob, frame number:  455
# Tracking the blob, frame number:  456
# Tracking the blob, frame number:  457
# Tracking the blob, frame number:  458
# Tracking the blob, frame number:  459
# Tracking the blob, frame number:  460
# Tracking the blob, frame number:  461
# Tracking the blob, frame number:  462
# Tracking the blob, frame number:  463
# Tracking the blob, frame number:  464
# Tracking the blob, frame number:  465
# Tracking the blob, frame number:  466
# Tracking the blob, frame number:  467
# Tracking the blob, frame number:  468
# Tracking the blob, frame number:  469
# Tracking the blob, frame number:  470
# Tracking the blob, frame number:  471
# Tracking the blob, frame number:  472
# Tracking the blob, frame number:  473
# Tracking the blob, frame number:  474
# Tracking the blob, frame number:  475
# Tracking the blob, frame number:  476
# Previous blob disappeared, shift =  -1
# Tracking the blob, frame number:  478
# Tracking the blob, frame number:  479
# Tracking the blob, frame number:  480
# Tracking the blob, frame number:  481
# Tracking the blob, frame number:  482
# Tracking the blob, frame number:  483
# Tracking the blob, frame number:  484
# Tracking the blob, frame number:  485
# Tracking the blob, frame number:  486
# Tracking the blob, frame number:  487
# Tracking the blob, frame number:  488
# Tracking the blob, frame number:  489
# Tracking the blob, frame number:  490
# Tracking the blob, frame number:  491
# Tracking the blob, frame number:  492
# Tracking the blob, frame number:  493
# Tracking the blob, frame number:  494
# Tracking the blob, frame number:  495
# Tracking the blob, frame number:  496
# Tracking the blob, frame number:  497
# Tracking the blob, frame number:  498
# Tracking the blob, frame number:  499
# Tracking the blob, frame number:  500
# Tracking the blob, frame number:  501
# Tracking the blob, frame number:  502
# Tracking the blob, frame number:  503
# Tracking the blob, frame number:  504
# Tracking the blob, frame number:  505
# Tracking the blob, frame number:  506
# Tracking the blob, frame number:  507
# Tracking the blob, frame number:  508
# Tracking the blob, frame number:  509
# Tracking the blob, frame number:  510
# Tracking the blob, frame number:  511
# Tracking the blob, frame number:  512
# Tracking the blob, frame number:  513
# Tracking the blob, frame number:  514
# Tracking the blob, frame number:  515
# Tracking the blob, frame number:  516
# Tracking the blob, frame number:  517
# Tracking the blob, frame number:  518
# Tracking the blob, frame number:  519
# Tracking the blob, frame number:  520
# Tracking the blob, frame number:  521
# Tracking the blob, frame number:  522
# Tracking the blob, frame number:  523
# Tracking the blob, frame number:  524
# Tracking the blob, frame number:  525
# Tracking the blob, frame number:  526
# Tracking the blob, frame number:  527
# Tracking the blob, frame number:  528
# Tracking the blob, frame number:  529
# Tracking the blob, frame number:  530
# Tracking the blob, frame number:  531
# Tracking the blob, frame number:  532
# Tracking the blob, frame number:  533
# Tracking the blob, frame number:  534
# Tracking the blob, frame number:  535
# Tracking the blob, frame number:  536
# Tracking the blob, frame number:  537
# Tracking the blob, frame number:  538
# Tracking the blob, frame number:  539
# Tracking the blob, frame number:  540
# Tracking the blob, frame number:  541
# Tracking the blob, frame number:  542
# Tracking the blob, frame number:  543
# Tracking the blob, frame number:  544
# Tracking the blob, frame number:  545
# Tracking the blob, frame number:  546
# Tracking the blob, frame number:  547
# Tracking the blob, frame number:  548
# Tracking the blob, frame number:  549
# Tracking the blob, frame number:  550
# Tracking the blob, frame number:  551
# Tracking the blob, frame number:  552
# Tracking the blob, frame number:  553
# Tracking the blob, frame number:  554
# Tracking the blob, frame number:  555
# Tracking the blob, frame number:  556
# Tracking the blob, frame number:  557
# Tracking the blob, frame number:  558
# Tracking the blob, frame number:  559
# Tracking the blob, frame number:  560
# Tracking the blob, frame number:  561
# Tracking the blob, frame number:  562
# Tracking the blob, frame number:  563
# Tracking the blob, frame number:  564
# Tracking the blob, frame number:  565
# Tracking the blob, frame number:  566
# Tracking the blob, frame number:  567
# Tracking the blob, frame number:  568
# Tracking the blob, frame number:  569
# Tracking the blob, frame number:  570
# Tracking the blob, frame number:  571
# Tracking the blob, frame number:  572
# Tracking the blob, frame number:  573
# Tracking the blob, frame number:  574
# Tracking the blob, frame number:  575
# Tracking the blob, frame number:  576
# Tracking the blob, frame number:  577
# Tracking the blob, frame number:  578
# Tracking the blob, frame number:  579
# Tracking the blob, frame number:  580
# Tracking the blob, frame number:  581
# Tracking the blob, frame number:  582
# Tracking the blob, frame number:  583
# Tracking the blob, frame number:  584
# Tracking the blob, frame number:  585
# Tracking the blob, frame number:  586
# Tracking the blob, frame number:  587
# Tracking the blob, frame number:  588
# Tracking the blob, frame number:  589
# Tracking the blob, frame number:  590
# Tracking the blob, frame number:  591
# Tracking the blob, frame number:  592
# Tracking the blob, frame number:  593
# Tracking the blob, frame number:  594
# Tracking the blob, frame number:  595
# Tracking the blob, frame number:  596
# Tracking the blob, frame number:  597
# Tracking the blob, frame number:  598
# Tracking the blob, frame number:  599
# Tracking the blob, frame number:  600
# Tracking the blob, frame number:  601
# Tracking the blob, frame number:  602
# Tracking the blob, frame number:  603
# Tracking the blob, frame number:  604
# Tracking the blob, frame number:  605
# Tracking the blob, frame number:  606
# Tracking the blob, frame number:  607
# Tracking the blob, frame number:  608
# Tracking the blob, frame number:  609
# Tracking the blob, frame number:  610
# Tracking the blob, frame number:  611
# Tracking the blob, frame number:  612
# Tracking the blob, frame number:  613
# Tracking the blob, frame number:  614
# Tracking the blob, frame number:  615
# Tracking the blob, frame number:  616
# Tracking the blob, frame number:  617
# Tracking the blob, frame number:  618
# Tracking the blob, frame number:  619
# Tracking the blob, frame number:  620
# Tracking the blob, frame number:  621
# Tracking the blob, frame number:  622
# Tracking the blob, frame number:  623
# Tracking the blob, frame number:  624
# Tracking the blob, frame number:  625
# Tracking the blob, frame number:  626
# Tracking the blob, frame number:  627
# Tracking the blob, frame number:  628
# Tracking the blob, frame number:  629
# Tracking the blob, frame number:  630
# Tracking the blob, frame number:  631
# Tracking the blob, frame number:  632
# Tracking the blob, frame number:  633
# Tracking the blob, frame number:  634
# Tracking the blob, frame number:  635
# Tracking the blob, frame number:  636
# Tracking the blob, frame number:  637
# Tracking the blob, frame number:  638
# Tracking the blob, frame number:  639
# Tracking the blob, frame number:  640
# Tracking the blob, frame number:  641
# Tracking the blob, frame number:  642
# Tracking the blob, frame number:  643
# Tracking the blob, frame number:  644
# Tracking the blob, frame number:  645
# Tracking the blob, frame number:  646
# Tracking the blob, frame number:  647
# Tracking the blob, frame number:  648
# Tracking the blob, frame number:  649
# Tracking the blob, frame number:  650
# Tracking the blob, frame number:  651
# Tracking the blob, frame number:  652
# Tracking the blob, frame number:  653
# Tracking the blob, frame number:  654
# Tracking the blob, frame number:  655
# Tracking the blob, frame number:  656
# Tracking the blob, frame number:  657
# Tracking the blob, frame number:  658
# Tracking the blob, frame number:  659
# Tracking the blob, frame number:  660
# Tracking the blob, frame number:  661
# Tracking the blob, frame number:  662
# Tracking the blob, frame number:  663
# Tracking the blob, frame number:  664
# Tracking the blob, frame number:  665
# Tracking the blob, frame number:  666
# Tracking the blob, frame number:  667
# Tracking the blob, frame number:  668
# Tracking the blob, frame number:  669
# Tracking the blob, frame number:  670
# Tracking the blob, frame number:  671
# Tracking the blob, frame number:  672
# Tracking the blob, frame number:  673
# Tracking the blob, frame number:  674
# Tracking the blob, frame number:  675
# Tracking the blob, frame number:  676
# Tracking the blob, frame number:  677
# Tracking the blob, frame number:  678
# Tracking the blob, frame number:  679
# Tracking the blob, frame number:  680
# Tracking the blob, frame number:  681
# Tracking the blob, frame number:  682
# Tracking the blob, frame number:  683
# Tracking the blob, frame number:  684
# Tracking the blob, frame number:  685
# Tracking the blob, frame number:  686
# Tracking the blob, frame number:  687
# Tracking the blob, frame number:  688
# Tracking the blob, frame number:  689
# Tracking the blob, frame number:  690
# Tracking the blob, frame number:  691
# Tracking the blob, frame number:  692
# Tracking the blob, frame number:  693
# Tracking the blob, frame number:  694
# New rightmost blob detected, shift =  0
# Tracking the blob, frame number:  696
# Tracking the blob, frame number:  697
# Tracking the blob, frame number:  698
# Tracking the blob, frame number:  699
# Tracking the blob, frame number:  700
# Tracking the blob, frame number:  701
# Tracking the blob, frame number:  702
# Tracking the blob, frame number:  703
# Tracking the blob, frame number:  704
# Tracking the blob, frame number:  705
# Tracking the blob, frame number:  706
# Tracking the blob, frame number:  707
# Tracking the blob, frame number:  708
# Tracking the blob, frame number:  709
# Tracking the blob, frame number:  710
# Tracking the blob, frame number:  711
# Tracking the blob, frame number:  712
# Tracking the blob, frame number:  713
# Tracking the blob, frame number:  714
# Tracking the blob, frame number:  715
# Tracking the blob, frame number:  716
# Tracking the blob, frame number:  717
# Tracking the blob, frame number:  718
# Tracking the blob, frame number:  719
# Tracking the blob, frame number:  720
# Tracking the blob, frame number:  721
# Tracking the blob, frame number:  722
# Tracking the blob, frame number:  723
# Tracking the blob, frame number:  724
# Tracking the blob, frame number:  725
# Tracking the blob, frame number:  726
# Tracking the blob, frame number:  727
# Tracking the blob, frame number:  728
# Tracking the blob, frame number:  729
# Tracking the blob, frame number:  730
# Tracking the blob, frame number:  731
# Tracking the blob, frame number:  732
# Tracking the blob, frame number:  733
# Tracking the blob, frame number:  734
# Tracking the blob, frame number:  735
# Tracking the blob, frame number:  736
# Tracking the blob, frame number:  737
# Tracking the blob, frame number:  738
# Tracking the blob, frame number:  739
# Tracking the blob, frame number:  740
# Tracking the blob, frame number:  741
# Tracking the blob, frame number:  742
# Tracking the blob, frame number:  743
# Tracking the blob, frame number:  744
# Tracking the blob, frame number:  745
# Tracking the blob, frame number:  746
# Tracking the blob, frame number:  747
# Tracking the blob, frame number:  748
# Tracking the blob, frame number:  749
# Tracking the blob, frame number:  750
# Tracking the blob, frame number:  751
# Tracking the blob, frame number:  752
# Tracking the blob, frame number:  753
# Tracking the blob, frame number:  754
# Tracking the blob, frame number:  755
# Tracking the blob, frame number:  756
# Tracking the blob, frame number:  757
# Tracking the blob, frame number:  758
# Tracking the blob, frame number:  759
# Tracking the blob, frame number:  760
# Tracking the blob, frame number:  761
# Tracking the blob, frame number:  762
# Tracking the blob, frame number:  763
# Tracking the blob, frame number:  764
# Tracking the blob, frame number:  765
# Tracking the blob, frame number:  766
# Tracking the blob, frame number:  767
# Tracking the blob, frame number:  768
# Tracking the blob, frame number:  769
# Tracking the blob, frame number:  770
# Tracking the blob, frame number:  771
# Tracking the blob, frame number:  772
# Tracking the blob, frame number:  773
# Tracking the blob, frame number:  774
# Tracking the blob, frame number:  775
# Tracking the blob, frame number:  776
# Tracking the blob, frame number:  777
# Tracking the blob, frame number:  778
# Tracking the blob, frame number:  779
# Tracking the blob, frame number:  780
# Tracking the blob, frame number:  781
# Tracking the blob, frame number:  782
# Tracking the blob, frame number:  783
# Tracking the blob, frame number:  784
# Tracking the blob, frame number:  785
# Tracking the blob, frame number:  786
# Tracking the blob, frame number:  787
# Tracking the blob, frame number:  788
# Tracking the blob, frame number:  789
# Tracking the blob, frame number:  790
# Tracking the blob, frame number:  791
# Tracking the blob, frame number:  792
# Tracking the blob, frame number:  793
# Tracking the blob, frame number:  794
# Tracking the blob, frame number:  795
# Tracking the blob, frame number:  796
# Tracking the blob, frame number:  797
# Tracking the blob, frame number:  798
# Tracking the blob, frame number:  799
# Tracking the blob, frame number:  800
# Tracking the blob, frame number:  801
# Tracking the blob, frame number:  802
# Tracking the blob, frame number:  803
# Tracking the blob, frame number:  804
# Tracking the blob, frame number:  805
# Tracking the blob, frame number:  806
# Tracking the blob, frame number:  807
# Tracking the blob, frame number:  808
# Tracking the blob, frame number:  809
# Tracking the blob, frame number:  810
# Tracking the blob, frame number:  811
# Tracking the blob, frame number:  812
# Tracking the blob, frame number:  813
# Tracking the blob, frame number:  814
# Tracking the blob, frame number:  815
# Tracking the blob, frame number:  816
# Tracking the blob, frame number:  817
# Tracking the blob, frame number:  818
# Tracking the blob, frame number:  819
# Tracking the blob, frame number:  820
# Tracking the blob, frame number:  821
# Tracking the blob, frame number:  822
# Tracking the blob, frame number:  823
# Previous blob disappeared, shift =  -1
# Tracking the blob, frame number:  825
# Tracking the blob, frame number:  826
# Tracking the blob, frame number:  827
# Tracking the blob, frame number:  828
# Tracking the blob, frame number:  829
# Tracking the blob, frame number:  830
# Tracking the blob, frame number:  831
# Tracking the blob, frame number:  832
# Tracking the blob, frame number:  833
# Tracking the blob, frame number:  834
# Tracking the blob, frame number:  835
# Tracking the blob, frame number:  836
# Tracking the blob, frame number:  837
# Tracking the blob, frame number:  838
# Tracking the blob, frame number:  839
# Tracking the blob, frame number:  840
# Tracking the blob, frame number:  841
# Tracking the blob, frame number:  842
# Tracking the blob, frame number:  843
# Tracking the blob, frame number:  844
# Tracking the blob, frame number:  845
# Tracking the blob, frame number:  846
# Tracking the blob, frame number:  847
# Tracking the blob, frame number:  848
# Tracking the blob, frame number:  849
# Tracking the blob, frame number:  850
# Tracking the blob, frame number:  851
# Tracking the blob, frame number:  852
# Tracking the blob, frame number:  853
# Tracking the blob, frame number:  854
# Tracking the blob, frame number:  855
# Tracking the blob, frame number:  856
# Tracking the blob, frame number:  857
# Tracking the blob, frame number:  858
# Tracking the blob, frame number:  859
# Tracking the blob, frame number:  860
# Tracking the blob, frame number:  861
# Tracking the blob, frame number:  862
# Tracking the blob, frame number:  863
# Tracking the blob, frame number:  864
# Tracking the blob, frame number:  865
# Tracking the blob, frame number:  866
# Tracking the blob, frame number:  867
# Tracking the blob, frame number:  868
# Tracking the blob, frame number:  869
# Tracking the blob, frame number:  870
# Tracking the blob, frame number:  871
# Tracking the blob, frame number:  872
# Tracking the blob, frame number:  873
# Tracking the blob, frame number:  874
# Tracking the blob, frame number:  875
# Tracking the blob, frame number:  876
# Tracking the blob, frame number:  877
# Tracking the blob, frame number:  878
# Tracking the blob, frame number:  879
# Tracking the blob, frame number:  880
# Tracking the blob, frame number:  881
# Tracking the blob, frame number:  882
# Tracking the blob, frame number:  883
# Tracking the blob, frame number:  884
# Tracking the blob, frame number:  885
# Tracking the blob, frame number:  886
# Tracking the blob, frame number:  887
# Tracking the blob, frame number:  888
# Tracking the blob, frame number:  889
# Tracking the blob, frame number:  890
# Tracking the blob, frame number:  891
# Tracking the blob, frame number:  892
# Tracking the blob, frame number:  893
# Tracking the blob, frame number:  894
# Tracking the blob, frame number:  895
# Tracking the blob, frame number:  896
# Tracking the blob, frame number:  897
# Tracking the blob, frame number:  898
# Tracking the blob, frame number:  899
# Tracking the blob, frame number:  900
# Tracking the blob, frame number:  901
# Tracking the blob, frame number:  902
# Tracking the blob, frame number:  903
# Tracking the blob, frame number:  904
# Tracking the blob, frame number:  905
# Tracking the blob, frame number:  906
# Tracking the blob, frame number:  907
# Tracking the blob, frame number:  908
# Tracking the blob, frame number:  909
# Tracking the blob, frame number:  910
# Tracking the blob, frame number:  911
# Tracking the blob, frame number:  912
# Tracking the blob, frame number:  913
# Tracking the blob, frame number:  914
# Tracking the blob, frame number:  915
# Tracking the blob, frame number:  916
# Tracking the blob, frame number:  917
# Tracking the blob, frame number:  918
# Tracking the blob, frame number:  919
# Tracking the blob, frame number:  920
# Tracking the blob, frame number:  921
# Tracking the blob, frame number:  922
# Tracking the blob, frame number:  923
# Tracking the blob, frame number:  924
# Tracking the blob, frame number:  925
# Tracking the blob, frame number:  926
# Tracking the blob, frame number:  927
# Tracking the blob, frame number:  928
# Tracking the blob, frame number:  929
# Tracking the blob, frame number:  930
# Tracking the blob, frame number:  931
# Tracking the blob, frame number:  932
# Tracking the blob, frame number:  933
# Tracking the blob, frame number:  934
# Tracking the blob, frame number:  935
# Tracking the blob, frame number:  936
# Tracking the blob, frame number:  937
# Tracking the blob, frame number:  938
# Tracking the blob, frame number:  939
# Tracking the blob, frame number:  940
# Tracking the blob, frame number:  941
# Tracking the blob, frame number:  942
# Tracking the blob, frame number:  943
# Tracking the blob, frame number:  944
# Tracking the blob, frame number:  945
# Tracking the blob, frame number:  946
# Tracking the blob, frame number:  947
# Tracking the blob, frame number:  948
# Tracking the blob, frame number:  949
# Tracking the blob, frame number:  950
# Tracking the blob, frame number:  951
# Tracking the blob, frame number:  952
# Tracking the blob, frame number:  953
# Tracking the blob, frame number:  954
# Tracking the blob, frame number:  955
# Tracking the blob, frame number:  956
# Tracking the blob, frame number:  957
# Tracking the blob, frame number:  958
# Tracking the blob, frame number:  959
# Tracking the blob, frame number:  960
# Tracking the blob, frame number:  961
# Tracking the blob, frame number:  962
# Tracking the blob, frame number:  963
# Tracking the blob, frame number:  964
# Tracking the blob, frame number:  965
# Tracking the blob, frame number:  966
# Tracking the blob, frame number:  967
# Tracking the blob, frame number:  968
# Tracking the blob, frame number:  969
# Tracking the blob, frame number:  970
# Tracking the blob, frame number:  971
# Tracking the blob, frame number:  972
# Tracking the blob, frame number:  973
# Tracking the blob, frame number:  974
# Tracking the blob, frame number:  975
# Tracking the blob, frame number:  976
# Tracking the blob, frame number:  977
# Tracking the blob, frame number:  978
# Tracking the blob, frame number:  979
# Tracking the blob, frame number:  980
# Tracking the blob, frame number:  981
# Tracking the blob, frame number:  982
# Tracking the blob, frame number:  983
# Tracking the blob, frame number:  984
# Tracking the blob, frame number:  985
# Tracking the blob, frame number:  986
# Tracking the blob, frame number:  987
# Tracking the blob, frame number:  988
# Tracking the blob, frame number:  989
# Tracking the blob, frame number:  990
# Tracking the blob, frame number:  991
# Tracking the blob, frame number:  992
# Tracking the blob, frame number:  993
# Tracking the blob, frame number:  994
# Tracking the blob, frame number:  995
# Tracking the blob, frame number:  996
# Tracking the blob, frame number:  997
# Tracking the blob, frame number:  998
# Tracking the blob, frame number:  999
# Tracking the blob, frame number:  1000
# Tracking the blob, frame number:  1001
# Tracking the blob, frame number:  1002
# Tracking the blob, frame number:  1003
# Tracking the blob, frame number:  1004
# Tracking the blob, frame number:  1005
# Tracking the blob, frame number:  1006
# Tracking the blob, frame number:  1007
# Tracking the blob, frame number:  1008
# Tracking the blob, frame number:  1009
# Tracking the blob, frame number:  1010
# Tracking the blob, frame number:  1011
# Tracking the blob, frame number:  1012
# Tracking the blob, frame number:  1013
# Tracking the blob, frame number:  1014
# Tracking the blob, frame number:  1015
# Tracking the blob, frame number:  1016
# Tracking the blob, frame number:  1017
# Tracking the blob, frame number:  1018
# Tracking the blob, frame number:  1019
# Tracking the blob, frame number:  1020
# Tracking the blob, frame number:  1021
# Tracking the blob, frame number:  1022
# Tracking the blob, frame number:  1023
# Tracking the blob, frame number:  1024
# Tracking the blob, frame number:  1025
# Tracking the blob, frame number:  1026
# Tracking the blob, frame number:  1027
# Tracking the blob, frame number:  1028
# Tracking the blob, frame number:  1029
# Tracking the blob, frame number:  1030
# Tracking the blob, frame number:  1031
# Tracking the blob, frame number:  1032
# Tracking the blob, frame number:  1033
# Tracking the blob, frame number:  1034
# Tracking the blob, frame number:  1035
# Tracking the blob, frame number:  1036
# Tracking the blob, frame number:  1037
# Tracking the blob, frame number:  1038
# Tracking the blob, frame number:  1039
# Tracking the blob, frame number:  1040
# Tracking the blob, frame number:  1041
# Tracking the blob, frame number:  1042
# Tracking the blob, frame number:  1043
# Tracking the blob, frame number:  1044
# Tracking the blob, frame number:  1045
# Tracking the blob, frame number:  1046
# Tracking the blob, frame number:  1047
# Tracking the blob, frame number:  1048
# Tracking the blob, frame number:  1049
# Tracking the blob, frame number:  1050
# Tracking the blob, frame number:  1051
# Tracking the blob, frame number:  1052
# Tracking the blob, frame number:  1053
# Tracking the blob, frame number:  1054
# Tracking the blob, frame number:  1055
# Tracking the blob, frame number:  1056
# Tracking the blob, frame number:  1057
# Tracking the blob, frame number:  1058
# Tracking the blob, frame number:  1059
# Tracking the blob, frame number:  1060
# Tracking the blob, frame number:  1061
# Tracking the blob, frame number:  1062
# Tracking the blob, frame number:  1063
# Tracking the blob, frame number:  1064
# Tracking the blob, frame number:  1065
# Tracking the blob, frame number:  1066
# Tracking the blob, frame number:  1067
# Tracking the blob, frame number:  1068
# Tracking the blob, frame number:  1069
# Tracking the blob, frame number:  1070
# Tracking the blob, frame number:  1071
# Tracking the blob, frame number:  1072
# Tracking the blob, frame number:  1073
# Tracking the blob, frame number:  1074
# Tracking the blob, frame number:  1075
# Tracking the blob, frame number:  1076
# Tracking the blob, frame number:  1077
# Tracking the blob, frame number:  1078
# Tracking the blob, frame number:  1079
# Tracking the blob, frame number:  1080
# Previous blob disappeared, shift =  -2
# Tracking the blob, frame number:  1082
# Tracking the blob, frame number:  1083
# Tracking the blob, frame number:  1084
# Tracking the blob, frame number:  1085
# Tracking the blob, frame number:  1086
# Tracking the blob, frame number:  1087
# Tracking the blob, frame number:  1088
# Tracking the blob, frame number:  1089
# Tracking the blob, frame number:  1090
# Tracking the blob, frame number:  1091
# Tracking the blob, frame number:  1092
# Tracking the blob, frame number:  1093
# Tracking the blob, frame number:  1094
# Tracking the blob, frame number:  1095
# Tracking the blob, frame number:  1096
# Tracking the blob, frame number:  1097
# Tracking the blob, frame number:  1098
# Tracking the blob, frame number:  1099
# Tracking the blob, frame number:  1100
# Tracking the blob, frame number:  1101
# Tracking the blob, frame number:  1102
# Tracking the blob, frame number:  1103
# Tracking the blob, frame number:  1104
# Tracking the blob, frame number:  1105
# Tracking the blob, frame number:  1106
# Tracking the blob, frame number:  1107
# Tracking the blob, frame number:  1108
# Tracking the blob, frame number:  1109
# Tracking the blob, frame number:  1110
# Tracking the blob, frame number:  1111
# Tracking the blob, frame number:  1112
# Tracking the blob, frame number:  1113
# Tracking the blob, frame number:  1114
# Tracking the blob, frame number:  1115
# Tracking the blob, frame number:  1116
# Tracking the blob, frame number:  1117
# Tracking the blob, frame number:  1118
# Tracking the blob, frame number:  1119
# Tracking the blob, frame number:  1120
# Tracking the blob, frame number:  1121
# Previous blob disappeared, shift =  -3
# Tracking the blob, frame number:  1123
# Tracking the blob, frame number:  1124
# Tracking the blob, frame number:  1125
# Tracking the blob, frame number:  1126
# Tracking the blob, frame number:  1127
# Tracking the blob, frame number:  1128
# Tracking the blob, frame number:  1129
# Tracking the blob, frame number:  1130
# Tracking the blob, frame number:  1131
# Tracking the blob, frame number:  1132
# Tracking the blob, frame number:  1133
# Previous blob disappeared, shift =  -4
# Tracking the blob, frame number:  1135
# Tracking the blob, frame number:  1136
# Tracking the blob, frame number:  1137
# Tracking the blob, frame number:  1138
# Tracking the blob, frame number:  1139
# Tracking the blob, frame number:  1140
# Tracking the blob, frame number:  1141
# Tracking the blob, frame number:  1142
# Tracking the blob, frame number:  1143
# Tracking the blob, frame number:  1144
# Tracking the blob, frame number:  1145
# Tracking the blob, frame number:  1146
# Tracking the blob, frame number:  1147
# Tracking the blob, frame number:  1148
# Tracking the blob, frame number:  1149
# Tracking the blob, frame number:  1150
# Tracking the blob, frame number:  1151
# Tracking the blob, frame number:  1152
# Tracking the blob, frame number:  1153
# Tracking the blob, frame number:  1154
# Tracking the blob, frame number:  1155
# Tracking the blob, frame number:  1156
# Tracking the blob, frame number:  1157
# Tracking the blob, frame number:  1158
# Tracking the blob, frame number:  1159
# Tracking the blob, frame number:  1160
# Tracking the blob, frame number:  1161
# Tracking the blob, frame number:  1162
# Tracking the blob, frame number:  1163
# Tracking the blob, frame number:  1164
# Tracking the blob, frame number:  1165
# Tracking the blob, frame number:  1166
# Tracking the blob, frame number:  1167
# Tracking the blob, frame number:  1168
# Tracking the blob, frame number:  1169
# Tracking the blob, frame number:  1170
# Tracking the blob, frame number:  1171
# Previous blob disappeared, shift =  -5
# Tracking the blob, frame number:  1173
# Tracking the blob, frame number:  1174
# Tracking the blob, frame number:  1175
# Tracking the blob, frame number:  1176
# Tracking the blob, frame number:  1177
# Tracking the blob, frame number:  1178
# Tracking the blob, frame number:  1179
# Tracking the blob, frame number:  1180
# Tracking the blob, frame number:  1181
# Tracking the blob, frame number:  1182
# Tracking the blob, frame number:  1183
# Tracking the blob, frame number:  1184
# Tracking the blob, frame number:  1185
# Previous blob disappeared, shift =  -6
# Tracking the blob, frame number:  1187
# Tracking the blob, frame number:  1188
# Tracking the blob, frame number:  1189
# Tracking the blob, frame number:  1190
# Tracking the blob, frame number:  1191
# Tracking the blob, frame number:  1192
# Tracking the blob, frame number:  1193
# Tracking the blob, frame number:  1194
# Tracking the blob, frame number:  1195
# Tracking the blob, frame number:  1196
# Tracking the blob, frame number:  1197
# Tracking the blob, frame number:  1198
# Tracking the blob, frame number:  1199
# Tracking the blob, frame number:  1200
# Tracking the blob, frame number:  1201
# Tracking the blob, frame number:  1202
# Tracking the blob, frame number:  1203
# Tracking the blob, frame number:  1204
# Tracking the blob, frame number:  1205
# Tracking the blob, frame number:  1206
# Tracking the blob, frame number:  1207
# Tracking the blob, frame number:  1208
# Tracking the blob, frame number:  1209
# Tracking the blob, frame number:  1210
# Tracking the blob, frame number:  1211
# Tracking the blob, frame number:  1212
# Tracking the blob, frame number:  1213
# Tracking the blob, frame number:  1214
# Tracking the blob, frame number:  1215
# Tracking the blob, frame number:  1216
# Tracking the blob, frame number:  1217
# Tracking the blob, frame number:  1218
# Tracking the blob, frame number:  1219
# Tracking the blob, frame number:  1220
# Tracking the blob, frame number:  1221
# Previous blob disappeared, shift =  -7
# Tracking the blob, frame number:  1223
# Tracking the blob, frame number:  1224
# Tracking the blob, frame number:  1225
# Tracking the blob, frame number:  1226
# Tracking the blob, frame number:  1227
# Tracking the blob, frame number:  1228
# Tracking the blob, frame number:  1229
# Previous blob disappeared, shift =  -8
# Tracking the blob, frame number:  1231
# Tracking the blob, frame number:  1232
# Tracking the blob, frame number:  1233
# Tracking the blob, frame number:  1234
# Tracking the blob, frame number:  1235
# Tracking the blob, frame number:  1236
# Tracking the blob, frame number:  1237
# Tracking the blob, frame number:  1238
# Tracking the blob, frame number:  1239
# Tracking the blob, frame number:  1240
# Tracking the blob, frame number:  1241
# Tracking the blob, frame number:  1242
# Tracking the blob, frame number:  1243
# Tracking the blob, frame number:  1244
# Tracking the blob, frame number:  1245
# Tracking the blob, frame number:  1246
# Tracking the blob, frame number:  1247
# Tracking the blob, frame number:  1248
# Tracking the blob, frame number:  1249
# Tracking the blob, frame number:  1250
# Tracking the blob, frame number:  1251
# Tracking the blob, frame number:  1252
# Tracking the blob, frame number:  1253
# Tracking the blob, frame number:  1254
# Tracking the blob, frame number:  1255
# Tracking the blob, frame number:  1256
# Tracking the blob, frame number:  1257
# Tracking the blob, frame number:  1258
# Tracking the blob, frame number:  1259
# ...
# Tracking the blob, frame number:  1972
# Tracking the blob, frame number:  1973
# Tracking the blob, frame number:  1974
# Tracking the blob, frame number:  1975
# Tracking the blob, frame number:  1976
# Tracking the blob, frame number:  1977
# Tracking the blob, frame number:  1978
# Tracking the blob, frame number:  1979
# Tracking the blob, frame number:  1980
# Tracking the blob, frame number:  1981
# Tracking the blob, frame number:  1982
# Tracking the blob, frame number:  1983
# Tracking the blob, frame number:  1984
# Tracking the blob, frame number:  1985
# Tracking the blob, frame number:  1986
# Tracking the blob, frame number:  1987
# Tracking the blob, frame number:  1988
# Tracking the blob, frame number:  1989
# Tracking the blob, frame number:  1990
# Tracking the blob, frame number:  1991
# Tracking the blob, frame number:  1992
# Tracking the blob, frame number:  1993
# Tracking the blob, frame number:  1994
# Tracking the blob, frame number:  1995
# Tracking the blob, frame number:  1996
# Tracking the blob, frame number:  1997
# Tracking the blob, frame number:  1998
# Tracking the blob, frame number:  1999
# Tracking the blob, frame number:  2000
# Tracking the blob, frame number:  2001
# Tracking the blob, frame number:  2002
# Tracking the blob, frame number:  2003
# Tracking the blob, frame number:  2004
# Tracking the blob, frame number:  2005
# Tracking the blob, frame number:  2006
# Tracking the blob, frame number:  2007
# Previous blob disappeared, shift =  -18
# Tracking the blob, frame number:  2009
# Tracking the blob, frame number:  2010
# Tracking the blob, frame number:  2011
# Tracking the blob, frame number:  2012
# Tracking the blob, frame number:  2013
# Tracking the blob, frame number:  2014
# Tracking the blob, frame number:  2015
# Tracking the blob, frame number:  2016
# Tracking the blob, frame number:  2017
# Tracking the blob, frame number:  2018
# Tracking the blob, frame number:  2019
# Tracking the blob, frame number:  2020
# Tracking the blob, frame number:  2021
# Tracking the blob, frame number:  2022
# Tracking the blob, frame number:  2023
# Tracking the blob, frame number:  2024
# Tracking the blob, frame number:  2025
# Tracking the blob, frame number:  2026
# Tracking the blob, frame number:  2027
# Tracking the blob, frame number:  2028
# Tracking the blob, frame number:  2029
# Tracking the blob, frame number:  2030
# Tracking the blob, frame number:  2031
# Tracking the blob, frame number:  2032
# Tracking the blob, frame number:  2033
# Tracking the blob, frame number:  2034
# Tracking the blob, frame number:  2035
# Tracking the blob, frame number:  2036
# Tracking the blob, frame number:  2037
# Tracking the blob, frame number:  2038
# Tracking the blob, frame number:  2039
# Tracking the blob, frame number:  2040
# Tracking the blob, frame number:  2041
# Tracking the blob, frame number:  2042
# Tracking the blob, frame number:  2043
# Tracking the blob, frame number:  2044
# Tracking the blob, frame number:  2045
# Tracking the blob, frame number:  2046
# Tracking the blob, frame number:  2047
# Tracking the blob, frame number:  2048
# Tracking the blob, frame number:  2049
# Tracking the blob, frame number:  2050
# Tracking the blob, frame number:  2051
# Tracking the blob, frame number:  2052
# Tracking the blob, frame number:  2053
# Tracking the blob, frame number:  2054
# Tracking the blob, frame number:  2055
# Tracking the blob, frame number:  2056
# Tracking the blob, frame number:  2057
# Tracking the blob, frame number:  2058
# Tracking the blob, frame number:  2059
# Tracking the blob, frame number:  2060
# Tracking the blob, frame number:  2061
# Tracking the blob, frame number:  2062
# Tracking the blob, frame number:  2063
# Tracking the blob, frame number:  2064
# Tracking the blob, frame number:  2065
# Tracking the blob, frame number:  2066
# Tracking the blob, frame number:  2067
# Tracking the blob, frame number:  2068
# Tracking the blob, frame number:  2069
# Tracking the blob, frame number:  2070
# Tracking the blob, frame number:  2071
# Tracking the blob, frame number:  2072
# Tracking the blob, frame number:  2073
# Tracking the blob, frame number:  2074
# Tracking the blob, frame number:  2075
# Tracking the blob, frame number:  2076
# Previous blob disappeared, shift =  -19
# Tracking the blob, frame number:  2078
# Tracking the blob, frame number:  2079
# Tracking the blob, frame number:  2080
# Tracking the blob, frame number:  2081
# Tracking the blob, frame number:  2082
# Tracking the blob, frame number:  2083
# Tracking the blob, frame number:  2084
# Tracking the blob, frame number:  2085
# Tracking the blob, frame number:  2086
# Tracking the blob, frame number:  2087
# Tracking the blob, frame number:  2088
# Tracking the blob, frame number:  2089
# Tracking the blob, frame number:  2090
# Tracking the blob, frame number:  2091
# Tracking the blob, frame number:  2092
# Tracking the blob, frame number:  2093
# Tracking the blob, frame number:  2094
# Tracking the blob, frame number:  2095
# Tracking the blob, frame number:  2096
# Tracking the blob, frame number:  2097
# Tracking the blob, frame number:  2098
# Tracking the blob, frame number:  2099
# Tracking the blob, frame number:  2100
# Tracking the blob, frame number:  2101
# Tracking the blob, frame number:  2102
# Tracking the blob, frame number:  2103
# Tracking the blob, frame number:  2104
# Tracking the blob, frame number:  2105
# Tracking the blob, frame number:  2106
# Tracking the blob, frame number:  2107
# Tracking the blob, frame number:  2108
# Tracking the blob, frame number:  2109
# Tracking the blob, frame number:  2110
# Tracking the blob, frame number:  2111
# Tracking the blob, frame number:  2112
# Tracking the blob, frame number:  2113
# Previous blob disappeared, shift =  -20
# Tracking the blob, frame number:  2115
# Tracking the blob, frame number:  2116
# Tracking the blob, frame number:  2117
# Tracking the blob, frame number:  2118
# Tracking the blob, frame number:  2119
# Tracking the blob, frame number:  2120
# Tracking the blob, frame number:  2121
# Tracking the blob, frame number:  2122
# Tracking the blob, frame number:  2123
# Tracking the blob, frame number:  2124
# Tracking the blob, frame number:  2125
# Tracking the blob, frame number:  2126
# Tracking the blob, frame number:  2127
# Tracking the blob, frame number:  2128
# Tracking the blob, frame number:  2129
# Tracking the blob, frame number:  2130
# Tracking the blob, frame number:  2131
# Tracking the blob, frame number:  2132
# Tracking the blob, frame number:  2133
# Tracking the blob, frame number:  2134
# Tracking the blob, frame number:  2135
# Tracking the blob, frame number:  2136
# Tracking the blob, frame number:  2137
# Tracking the blob, frame number:  2138
# Tracking the blob, frame number:  2139
# Tracking the blob, frame number:  2140
# Tracking the blob, frame number:  2141
# Tracking the blob, frame number:  2142
# Tracking the blob, frame number:  2143
# Tracking the blob, frame number:  2144
# Tracking the blob, frame number:  2145
# Tracking the blob, frame number:  2146
# Tracking the blob, frame number:  2147
# Tracking the blob, frame number:  2148
# Tracking the blob, frame number:  2149
# Tracking the blob, frame number:  2150
# Tracking the blob, frame number:  2151
# Tracking the blob, frame number:  2152
# Tracking the blob, frame number:  2153
# Tracking the blob, frame number:  2154
# Tracking the blob, frame number:  2155
# Tracking the blob, frame number:  2156
# Tracking the blob, frame number:  2157
# Tracking the blob, frame number:  2158
# Tracking the blob, frame number:  2159
# Tracking the blob, frame number:  2160
# Tracking the blob, frame number:  2161
# Tracking the blob, frame number:  2162
# Tracking the blob, frame number:  2163
# Tracking the blob, frame number:  2164
# Tracking the blob, frame number:  2165
# Tracking the blob, frame number:  2166
# Tracking the blob, frame number:  2167
# Tracking the blob, frame number:  2168
# Tracking the blob, frame number:  2169
# Tracking the blob, frame number:  2170
# Tracking the blob, frame number:  2171
# Tracking the blob, frame number:  2172
# Tracking the blob, frame number:  2173
# Tracking the blob, frame number:  2174
# Tracking the blob, frame number:  2175
# Tracking the blob, frame number:  2176
# Tracking the blob, frame number:  2177
# Tracking the blob, frame number:  2178
# Tracking the blob, frame number:  2179
# Tracking the blob, frame number:  2180
# Tracking the blob, frame number:  2181
# Tracking the blob, frame number:  2182
# Tracking the blob, frame number:  2183
# Tracking the blob, frame number:  2184
# Tracking the blob, frame number:  2185
# Tracking the blob, frame number:  2186
# Tracking the blob, frame number:  2187
# Tracking the blob, frame number:  2188
# Tracking the blob, frame number:  2189
# Tracking the blob, frame number:  2190
# Tracking the blob, frame number:  2191
# Previous blob disappeared, shift =  -21
# Tracking the blob, frame number:  2193
# Tracking the blob, frame number:  2194
# Tracking the blob, frame number:  2195
# Tracking the blob, frame number:  2196
# Tracking the blob, frame number:  2197
# Tracking the blob, frame number:  2198
# Tracking the blob, frame number:  2199
# Tracking the blob, frame number:  2200
# Tracking the blob, frame number:  2201
# Tracking the blob, frame number:  2202
# Tracking the blob, frame number:  2203
# Tracking the blob, frame number:  2204
# Tracking the blob, frame number:  2205
# Tracking the blob, frame number:  2206
# Tracking the blob, frame number:  2207
# Tracking the blob, frame number:  2208
# Tracking the blob, frame number:  2209
# Tracking the blob, frame number:  2210
# Tracking the blob, frame number:  2211
# Tracking the blob, frame number:  2212
# Tracking the blob, frame number:  2213
# Tracking the blob, frame number:  2214
# Tracking the blob, frame number:  2215
# Tracking the blob, frame number:  2216
# Tracking the blob, frame number:  2217
# Tracking the blob, frame number:  2218
# Tracking the blob, frame number:  2219
# Tracking the blob, frame number:  2220
# Tracking the blob, frame number:  2221
# Tracking the blob, frame number:  2222
# Previous blob disappeared, shift =  -22
# Tracking the blob, frame number:  2224
# Tracking the blob, frame number:  2225
# Tracking the blob, frame number:  2226
# Tracking the blob, frame number:  2227
# Tracking the blob, frame number:  2228
# Tracking the blob, frame number:  2229
# Tracking the blob, frame number:  2230
# Tracking the blob, frame number:  2231
# Tracking the blob, frame number:  2232
# Tracking the blob, frame number:  2233
# Tracking the blob, frame number:  2234
# Tracking the blob, frame number:  2235
# Tracking the blob, frame number:  2236
# Tracking the blob, frame number:  2237
# Tracking the blob, frame number:  2238
# Tracking the blob, frame number:  2239
# Tracking the blob, frame number:  2240
# Tracking the blob, frame number:  2241
# Tracking the blob, frame number:  2242
# Tracking the blob, frame number:  2243
# Tracking the blob, frame number:  2244
# Tracking the blob, frame number:  2245
# Tracking the blob, frame number:  2246
# Tracking the blob, frame number:  2247
# Tracking the blob, frame number:  2248
# Tracking the blob, frame number:  2249
# Tracking the blob, frame number:  2250
# Tracking the blob, frame number:  2251
# Tracking the blob, frame number:  2252
# Tracking the blob, frame number:  2253
# Tracking the blob, frame number:  2254
# Tracking the blob, frame number:  2255
# Tracking the blob, frame number:  2256
# Tracking the blob, frame number:  2257
# Tracking the blob, frame number:  2258
# Tracking the blob, frame number:  2259
# Tracking the blob, frame number:  2260
# Tracking the blob, frame number:  2261
# Tracking the blob, frame number:  2262
# Tracking the blob, frame number:  2263
# Tracking the blob, frame number:  2264
# Tracking the blob, frame number:  2265
# Tracking the blob, frame number:  2266
# Tracking the blob, frame number:  2267
# Tracking the blob, frame number:  2268
# Tracking the blob, frame number:  2269
# Tracking the blob, frame number:  2270
# Tracking the blob, frame number:  2271
# Tracking the blob, frame number:  2272
# Tracking the blob, frame number:  2273
# Tracking the blob, frame number:  2274
# Tracking the blob, frame number:  2275
# Tracking the blob, frame number:  2276
# Tracking the blob, frame number:  2277
# Tracking the blob, frame number:  2278
# Tracking the blob, frame number:  2279
# Tracking the blob, frame number:  2280
# Tracking the blob, frame number:  2281
# Tracking the blob, frame number:  2282
# Tracking the blob, frame number:  2283
# Tracking the blob, frame number:  2284
# Tracking the blob, frame number:  2285
# Tracking the blob, frame number:  2286
# Tracking the blob, frame number:  2287
# Tracking the blob, frame number:  2288
# Tracking the blob, frame number:  2289
# Tracking the blob, frame number:  2290
# Tracking the blob, frame number:  2291
# Tracking the blob, frame number:  2292
# Tracking the blob, frame number:  2293
# Tracking the blob, frame number:  2294
# Tracking the blob, frame number:  2295
# Tracking the blob, frame number:  2296
# Tracking the blob, frame number:  2297
# Tracking the blob, frame number:  2298
# Tracking the blob, frame number:  2299
# Tracking the blob, frame number:  2300
# Tracking the blob, frame number:  2301
# Tracking the blob, frame number:  2302
# Tracking the blob, frame number:  2303
# Tracking the blob, frame number:  2304
# Tracking the blob, frame number:  2305
# Tracking the blob, frame number:  2306
# Tracking the blob, frame number:  2307
# Tracking the blob, frame number:  2308
# Tracking the blob, frame number:  2309
# Tracking the blob, frame number:  2310
# Tracking the blob, frame number:  2311
# Tracking the blob, frame number:  2312
# Tracking the blob, frame number:  2313
# Tracking the blob, frame number:  2314
# Tracking the blob, frame number:  2315
# Tracking the blob, frame number:  2316
# Tracking the blob, frame number:  2317
# Tracking the blob, frame number:  2318
# Tracking the blob, frame number:  2319
# Tracking the blob, frame number:  2320
# Tracking the blob, frame number:  2321
# Tracking the blob, frame number:  2322
# Tracking the blob, frame number:  2323
# Tracking the blob, frame number:  2324
# Tracking the blob, frame number:  2325
# Tracking the blob, frame number:  2326
# Tracking the blob, frame number:  2327
# Tracking the blob, frame number:  2328
# Tracking the blob, frame number:  2329
# Tracking the blob, frame number:  2330
# Tracking the blob, frame number:  2331
# Tracking the blob, frame number:  2332
# Tracking the blob, frame number:  2333
# Tracking the blob, frame number:  2334
# Tracking the blob, frame number:  2335
# Tracking the blob, frame number:  2336
# Tracking the blob, frame number:  2337
# Tracking the blob, frame number:  2338
# Tracking the blob, frame number:  2339
# Tracking the blob, frame number:  2340
# Tracking the blob, frame number:  2341
# Tracking the blob, frame number:  2342
# Tracking the blob, frame number:  2343
# Tracking the blob, frame number:  2344
# Tracking the blob, frame number:  2345
# Tracking the blob, frame number:  2346
# Tracking the blob, frame number:  2347
# Tracking the blob, frame number:  2348
# Tracking the blob, frame number:  2349
# Tracking the blob, frame number:  2350
# Tracking the blob, frame number:  2351
# Tracking the blob, frame number:  2352
# Tracking the blob, frame number:  2353
# Tracking the blob, frame number:  2354
# Tracking the blob, frame number:  2355
# Tracking the blob, frame number:  2356
# Tracking the blob, frame number:  2357
# Tracking the blob, frame number:  2358
# Tracking the blob, frame number:  2359
# Tracking the blob, frame number:  2360
# Tracking the blob, frame number:  2361
# Tracking the blob, frame number:  2362
# Tracking the blob, frame number:  2363
# Tracking the blob, frame number:  2364
# Tracking the blob, frame number:  2365
# Previous blob disappeared, shift =  -23
# Tracking the blob, frame number:  2367
# Tracking the blob, frame number:  2368
# Tracking the blob, frame number:  2369
# Tracking the blob, frame number:  2370
# Tracking the blob, frame number:  2371
# Tracking the blob, frame number:  2372
# Tracking the blob, frame number:  2373
# Tracking the blob, frame number:  2374
# Tracking the blob, frame number:  2375
# Tracking the blob, frame number:  2376
# Tracking the blob, frame number:  2377
# Tracking the blob, frame number:  2378
# Tracking the blob, frame number:  2379
# Tracking the blob, frame number:  2380
# Tracking the blob, frame number:  2381

# %%
video_path = 'data/Data/kaniula3.avi'

cap = cv2.VideoCapture(video_path)

previous_centroid = (0.0, 0.0)
shift = 0
radius = 10

frame_counter = 0

while True:
    ret, frame = cap.read()

    if not ret:
        break

    frame_counter += 1

    binary_image = create_binary_image(frame)
    masked_image = apply_mask(binary_image, 125)
    filtered_image = filter_blobs(masked_image)
    filled_image = fill_blobs(filtered_image)
    result_image, centroid_positions = detect_rightmost_blobs(filled_image, frame)

    if(in_bounds(previous_centroid, centroid_positions[0])):
        print("Tracking the blob, frame number: ", frame_counter)
    elif(in_bounds(previous_centroid, centroid_positions[1])):
        shift -= 1
        print("Previous blob disappeared, shift = ", shift)
    elif(not in_bounds(previous_centroid, centroid_positions[0]) and euc_distance(centroid_positions[0], previous_centroid) < 100):
        shift += 1
        print("New rightmost blob detected, shift = ", shift)
        
    previous_centroid = centroid_positions[0]

    cv2.imshow("Binary Image", filled_image)
    cv2.imshow("Result Image", frame)
    cv2.waitKey(1)
# Out:
# Tracking the blob, frame number:  2
# Tracking the blob, frame number:  3
# Tracking the blob, frame number:  4
# Tracking the blob, frame number:  5
# Tracking the blob, frame number:  6
# Tracking the blob, frame number:  7
# Tracking the blob, frame number:  8
# Tracking the blob, frame number:  9
# Tracking the blob, frame number:  10
# Tracking the blob, frame number:  11
# Tracking the blob, frame number:  12
# Tracking the blob, frame number:  13
# Tracking the blob, frame number:  14
# Tracking the blob, frame number:  15
# Tracking the blob, frame number:  16
# Tracking the blob, frame number:  17
# Tracking the blob, frame number:  18
# Tracking the blob, frame number:  19
# Tracking the blob, frame number:  20
# Tracking the blob, frame number:  21
# Tracking the blob, frame number:  22
# Tracking the blob, frame number:  23
# Tracking the blob, frame number:  24
# Tracking the blob, frame number:  25
# Tracking the blob, frame number:  26
# Tracking the blob, frame number:  27
# Tracking the blob, frame number:  28
# Tracking the blob, frame number:  29
# Tracking the blob, frame number:  30
# Tracking the blob, frame number:  31
# Tracking the blob, frame number:  32
# Tracking the blob, frame number:  33
# Tracking the blob, frame number:  34
# Tracking the blob, frame number:  35
# Previous blob disappeared, shift =  -1
# Tracking the blob, frame number:  37
# Tracking the blob, frame number:  38
# Tracking the blob, frame number:  39
# Tracking the blob, frame number:  40
# Tracking the blob, frame number:  41
# Tracking the blob, frame number:  42
# Tracking the blob, frame number:  43
# Tracking the blob, frame number:  44
# Tracking the blob, frame number:  45
# Tracking the blob, frame number:  46
# Tracking the blob, frame number:  47
# Tracking the blob, frame number:  48
# Tracking the blob, frame number:  49
# Tracking the blob, frame number:  50
# Tracking the blob, frame number:  51
# Tracking the blob, frame number:  52
# Tracking the blob, frame number:  53
# Tracking the blob, frame number:  54
# Tracking the blob, frame number:  55
# Tracking the blob, frame number:  56
# Tracking the blob, frame number:  57
# Tracking the blob, frame number:  58
# Tracking the blob, frame number:  59
# Tracking the blob, frame number:  60
# Tracking the blob, frame number:  61
# Tracking the blob, frame number:  62
# Tracking the blob, frame number:  63
# Tracking the blob, frame number:  64
# Tracking the blob, frame number:  65
# Tracking the blob, frame number:  66
# Tracking the blob, frame number:  67
# Tracking the blob, frame number:  68
# Tracking the blob, frame number:  69
# Tracking the blob, frame number:  70
# Tracking the blob, frame number:  71
# Tracking the blob, frame number:  72
# Previous blob disappeared, shift =  -2
# Tracking the blob, frame number:  74
# Tracking the blob, frame number:  75
# Tracking the blob, frame number:  76
# Tracking the blob, frame number:  77
# Tracking the blob, frame number:  78
# Tracking the blob, frame number:  79
# Tracking the blob, frame number:  80
# Tracking the blob, frame number:  81
# Tracking the blob, frame number:  82
# Tracking the blob, frame number:  83
# Tracking the blob, frame number:  84
# Tracking the blob, frame number:  85
# Tracking the blob, frame number:  86
# Tracking the blob, frame number:  87
# Tracking the blob, frame number:  88
# Tracking the blob, frame number:  89
# Tracking the blob, frame number:  90
# Tracking the blob, frame number:  91
# Tracking the blob, frame number:  92
# Tracking the blob, frame number:  93
# Tracking the blob, frame number:  94
# Tracking the blob, frame number:  95
# Tracking the blob, frame number:  96
# Tracking the blob, frame number:  97
# Tracking the blob, frame number:  98
# Tracking the blob, frame number:  99
# Tracking the blob, frame number:  100
# Tracking the blob, frame number:  101
# Tracking the blob, frame number:  102
# Tracking the blob, frame number:  103
# Tracking the blob, frame number:  104
# Tracking the blob, frame number:  105
# Tracking the blob, frame number:  106
# Tracking the blob, frame number:  107
# Tracking the blob, frame number:  108
# Tracking the blob, frame number:  109
# Tracking the blob, frame number:  110
# Tracking the blob, frame number:  111
# Tracking the blob, frame number:  112
# Previous blob disappeared, shift =  -3
# Tracking the blob, frame number:  114
# Tracking the blob, frame number:  115
# Tracking the blob, frame number:  116
# Tracking the blob, frame number:  117
# Tracking the blob, frame number:  118
# Tracking the blob, frame number:  119
# Tracking the blob, frame number:  120
# Tracking the blob, frame number:  121
# Tracking the blob, frame number:  122
# Tracking the blob, frame number:  123
# Tracking the blob, frame number:  124
# Tracking the blob, frame number:  125
# Tracking the blob, frame number:  126
# Tracking the blob, frame number:  127
# Tracking the blob, frame number:  128
# Tracking the blob, frame number:  129
# Tracking the blob, frame number:  130
# Tracking the blob, frame number:  131
# Tracking the blob, frame number:  132
# Tracking the blob, frame number:  133
# Tracking the blob, frame number:  134
# Tracking the blob, frame number:  135
# Tracking the blob, frame number:  136
# Tracking the blob, frame number:  137
# Tracking the blob, frame number:  138
# Tracking the blob, frame number:  139
# Previous blob disappeared, shift =  -4
# Tracking the blob, frame number:  141
# Tracking the blob, frame number:  142
# Tracking the blob, frame number:  143
# Tracking the blob, frame number:  144
# Tracking the blob, frame number:  145
# Tracking the blob, frame number:  146
# Tracking the blob, frame number:  147
# Tracking the blob, frame number:  148
# Tracking the blob, frame number:  149
# Tracking the blob, frame number:  150
# Tracking the blob, frame number:  151
# Tracking the blob, frame number:  152
# Tracking the blob, frame number:  153
# Tracking the blob, frame number:  154
# Tracking the blob, frame number:  155
# Tracking the blob, frame number:  156
# Tracking the blob, frame number:  157
# Tracking the blob, frame number:  158
# Tracking the blob, frame number:  159
# Tracking the blob, frame number:  160
# Tracking the blob, frame number:  161
# Tracking the blob, frame number:  162
# Tracking the blob, frame number:  163
# Tracking the blob, frame number:  164
# Tracking the blob, frame number:  165
# Tracking the blob, frame number:  166
# Tracking the blob, frame number:  167
# Tracking the blob, frame number:  168
# Tracking the blob, frame number:  169
# Tracking the blob, frame number:  170
# Tracking the blob, frame number:  171
# Tracking the blob, frame number:  172
# Previous blob disappeared, shift =  -5
# Tracking the blob, frame number:  174
# Tracking the blob, frame number:  175
# Tracking the blob, frame number:  176
# Tracking the blob, frame number:  177
# Tracking the blob, frame number:  178
# Tracking the blob, frame number:  179
# Tracking the blob, frame number:  180
# Tracking the blob, frame number:  181
# Tracking the blob, frame number:  182
# Tracking the blob, frame number:  183
# Tracking the blob, frame number:  184
# Tracking the blob, frame number:  185
# Tracking the blob, frame number:  186
# Tracking the blob, frame number:  187
# Tracking the blob, frame number:  188
# Tracking the blob, frame number:  189
# Tracking the blob, frame number:  190
# Tracking the blob, frame number:  191
# Tracking the blob, frame number:  192
# Tracking the blob, frame number:  193
# Tracking the blob, frame number:  194
# Tracking the blob, frame number:  195
# Tracking the blob, frame number:  196
# Tracking the blob, frame number:  197
# Tracking the blob, frame number:  198
# Tracking the blob, frame number:  199
# Tracking the blob, frame number:  200
# Tracking the blob, frame number:  201
# Tracking the blob, frame number:  202
# Tracking the blob, frame number:  203
# Tracking the blob, frame number:  204
# Tracking the blob, frame number:  205
# Tracking the blob, frame number:  206
# Tracking the blob, frame number:  207
# Tracking the blob, frame number:  208
# Tracking the blob, frame number:  209
# Tracking the blob, frame number:  210
# Tracking the blob, frame number:  211
# Tracking the blob, frame number:  212
# Tracking the blob, frame number:  213
# Tracking the blob, frame number:  214
# Tracking the blob, frame number:  215
# Tracking the blob, frame number:  216
# Tracking the blob, frame number:  217
# Tracking the blob, frame number:  218
# Tracking the blob, frame number:  219
# Tracking the blob, frame number:  220
# Tracking the blob, frame number:  221
# Tracking the blob, frame number:  222
# Tracking the blob, frame number:  223
# Tracking the blob, frame number:  224
# Tracking the blob, frame number:  225
# Tracking the blob, frame number:  226
# Tracking the blob, frame number:  227
# Previous blob disappeared, shift =  -6
# Tracking the blob, frame number:  229
# Tracking the blob, frame number:  230
# Tracking the blob, frame number:  231
# Tracking the blob, frame number:  232
# Tracking the blob, frame number:  233
# Tracking the blob, frame number:  234
# Tracking the blob, frame number:  235
# Tracking the blob, frame number:  236
# Tracking the blob, frame number:  237
# Tracking the blob, frame number:  238
# Tracking the blob, frame number:  239
# Tracking the blob, frame number:  240
# Tracking the blob, frame number:  241
# Tracking the blob, frame number:  242
# Tracking the blob, frame number:  243
# Tracking the blob, frame number:  244
# Previous blob disappeared, shift =  -7
# Tracking the blob, frame number:  246
# Tracking the blob, frame number:  247
# Tracking the blob, frame number:  248
# Tracking the blob, frame number:  249
# Tracking the blob, frame number:  250
# Tracking the blob, frame number:  251
# Tracking the blob, frame number:  252
# Tracking the blob, frame number:  253
# Tracking the blob, frame number:  254
# Tracking the blob, frame number:  255
# Tracking the blob, frame number:  256
# Tracking the blob, frame number:  257
# Tracking the blob, frame number:  258
# Tracking the blob, frame number:  259
# Tracking the blob, frame number:  260
# Tracking the blob, frame number:  261
# Tracking the blob, frame number:  262
# Tracking the blob, frame number:  263
# Tracking the blob, frame number:  264
# Tracking the blob, frame number:  265
# Tracking the blob, frame number:  266
# Tracking the blob, frame number:  267
# Tracking the blob, frame number:  268
# Tracking the blob, frame number:  269
# Tracking the blob, frame number:  270
# Tracking the blob, frame number:  271
# Tracking the blob, frame number:  272
# Previous blob disappeared, shift =  -8
# Tracking the blob, frame number:  274
# Tracking the blob, frame number:  275
# Tracking the blob, frame number:  276
# Tracking the blob, frame number:  277
# Tracking the blob, frame number:  278
# Tracking the blob, frame number:  279
# Tracking the blob, frame number:  280
# Tracking the blob, frame number:  281
# Tracking the blob, frame number:  282
# Tracking the blob, frame number:  283
# Tracking the blob, frame number:  284
# Tracking the blob, frame number:  285
# Tracking the blob, frame number:  286
# Tracking the blob, frame number:  287
# Tracking the blob, frame number:  288
# Tracking the blob, frame number:  289
# Tracking the blob, frame number:  290
# Tracking the blob, frame number:  291
# Tracking the blob, frame number:  292
# Tracking the blob, frame number:  293
# Tracking the blob, frame number:  294
# Tracking the blob, frame number:  295
# Tracking the blob, frame number:  296
# Tracking the blob, frame number:  297
# Tracking the blob, frame number:  298
# Tracking the blob, frame number:  299
# Tracking the blob, frame number:  300
# Previous blob disappeared, shift =  -9
# Tracking the blob, frame number:  302
# Tracking the blob, frame number:  303
# Tracking the blob, frame number:  304
# Tracking the blob, frame number:  305
# Tracking the blob, frame number:  306
# Tracking the blob, frame number:  307
# Tracking the blob, frame number:  308
# Tracking the blob, frame number:  309
# Tracking the blob, frame number:  310
# Tracking the blob, frame number:  311
# Tracking the blob, frame number:  312
# Tracking the blob, frame number:  313
# Tracking the blob, frame number:  314
# Tracking the blob, frame number:  315
# Tracking the blob, frame number:  316
# Tracking the blob, frame number:  317
# Tracking the blob, frame number:  318
# Tracking the blob, frame number:  319
# Tracking the blob, frame number:  320
# Tracking the blob, frame number:  321
# Tracking the blob, frame number:  322
# Tracking the blob, frame number:  323
# Tracking the blob, frame number:  324
# Tracking the blob, frame number:  325
# Tracking the blob, frame number:  326
# Tracking the blob, frame number:  327
# Tracking the blob, frame number:  328
# Tracking the blob, frame number:  329
# Tracking the blob, frame number:  330
# Tracking the blob, frame number:  331
# Tracking the blob, frame number:  332
# Tracking the blob, frame number:  333
# Tracking the blob, frame number:  334
# Previous blob disappeared, shift =  -10
# Tracking the blob, frame number:  336
# Tracking the blob, frame number:  337
# Tracking the blob, frame number:  338
# Tracking the blob, frame number:  339
# Tracking the blob, frame number:  340
# Tracking the blob, frame number:  341
# Tracking the blob, frame number:  342
# Tracking the blob, frame number:  343
# Tracking the blob, frame number:  344
# Tracking the blob, frame number:  345
# Tracking the blob, frame number:  346
# Tracking the blob, frame number:  347
# Tracking the blob, frame number:  348
# Tracking the blob, frame number:  349
# Tracking the blob, frame number:  350
# Tracking the blob, frame number:  351
# Tracking the blob, frame number:  352
# Tracking the blob, frame number:  353
# Tracking the blob, frame number:  354
# Tracking the blob, frame number:  355
# Tracking the blob, frame number:  356
# Tracking the blob, frame number:  357
# Tracking the blob, frame number:  358
# Tracking the blob, frame number:  359
# Tracking the blob, frame number:  360
# Tracking the blob, frame number:  361
# Previous blob disappeared, shift =  -11
# Tracking the blob, frame number:  363
# Tracking the blob, frame number:  364
# Tracking the blob, frame number:  365
# Tracking the blob, frame number:  366
# Tracking the blob, frame number:  367
# Tracking the blob, frame number:  368
# Tracking the blob, frame number:  369
# Tracking the blob, frame number:  370
# Tracking the blob, frame number:  371
# Tracking the blob, frame number:  372
# Tracking the blob, frame number:  373
# Tracking the blob, frame number:  374
# Tracking the blob, frame number:  375
# Tracking the blob, frame number:  376
# Tracking the blob, frame number:  377
# Tracking the blob, frame number:  378
# Tracking the blob, frame number:  379
# Tracking the blob, frame number:  380
# Tracking the blob, frame number:  381
# Tracking the blob, frame number:  382
# Tracking the blob, frame number:  383
# Tracking the blob, frame number:  384
# Tracking the blob, frame number:  385
# Tracking the blob, frame number:  386
# Tracking the blob, frame number:  387
# Tracking the blob, frame number:  388
# Tracking the blob, frame number:  389
# Previous blob disappeared, shift =  -12
# Tracking the blob, frame number:  391
# Tracking the blob, frame number:  392
# Tracking the blob, frame number:  393
# Tracking the blob, frame number:  394
# Tracking the blob, frame number:  395
# Tracking the blob, frame number:  396
# Tracking the blob, frame number:  397
# Tracking the blob, frame number:  398
# Tracking the blob, frame number:  399
# Tracking the blob, frame number:  400
# Tracking the blob, frame number:  401
# Tracking the blob, frame number:  402
# Tracking the blob, frame number:  403
# Tracking the blob, frame number:  404
# Tracking the blob, frame number:  405
# Tracking the blob, frame number:  406
# Tracking the blob, frame number:  407
# Tracking the blob, frame number:  408
# Tracking the blob, frame number:  409
# Tracking the blob, frame number:  410
# Tracking the blob, frame number:  411
# Tracking the blob, frame number:  412
# Tracking the blob, frame number:  413
# Tracking the blob, frame number:  414
# Tracking the blob, frame number:  415
# Tracking the blob, frame number:  416
# Tracking the blob, frame number:  417
# Tracking the blob, frame number:  418
# Tracking the blob, frame number:  419
# Previous blob disappeared, shift =  -13
# Tracking the blob, frame number:  421
# Tracking the blob, frame number:  422
# Tracking the blob, frame number:  423
# Tracking the blob, frame number:  424
# Tracking the blob, frame number:  425
# Tracking the blob, frame number:  426
# Tracking the blob, frame number:  427
# Tracking the blob, frame number:  428
# Tracking the blob, frame number:  429
# Tracking the blob, frame number:  430
# Tracking the blob, frame number:  431
# Tracking the blob, frame number:  432
# Tracking the blob, frame number:  433
# Tracking the blob, frame number:  434
# Tracking the blob, frame number:  435
# Tracking the blob, frame number:  436
# Tracking the blob, frame number:  437
# Tracking the blob, frame number:  438
# Tracking the blob, frame number:  439
# Tracking the blob, frame number:  440
# Tracking the blob, frame number:  441
# Tracking the blob, frame number:  442
# Tracking the blob, frame number:  443
# Tracking the blob, frame number:  444
# Tracking the blob, frame number:  445
# Tracking the blob, frame number:  446
# Previous blob disappeared, shift =  -14
# Tracking the blob, frame number:  448
# Tracking the blob, frame number:  449
# Tracking the blob, frame number:  450
# Tracking the blob, frame number:  451
# Tracking the blob, frame number:  452
# Tracking the blob, frame number:  453
# Tracking the blob, frame number:  454
# Tracking the blob, frame number:  455
# Tracking the blob, frame number:  456
# Tracking the blob, frame number:  457
# Tracking the blob, frame number:  458
# Tracking the blob, frame number:  459
# Tracking the blob, frame number:  460
# Tracking the blob, frame number:  461
# Tracking the blob, frame number:  462
# Tracking the blob, frame number:  463
# Tracking the blob, frame number:  464
# New rightmost blob detected, shift =  -13
# New rightmost blob detected, shift =  -12
# Tracking the blob, frame number:  467
# Tracking the blob, frame number:  468
# Tracking the blob, frame number:  469
# Tracking the blob, frame number:  470
# Tracking the blob, frame number:  471
# Tracking the blob, frame number:  472
# Tracking the blob, frame number:  473
# Tracking the blob, frame number:  474
# Tracking the blob, frame number:  475
# Tracking the blob, frame number:  476
# Tracking the blob, frame number:  477
# Tracking the blob, frame number:  478
# Tracking the blob, frame number:  479
# Tracking the blob, frame number:  480
# Tracking the blob, frame number:  481
# Tracking the blob, frame number:  482
# Tracking the blob, frame number:  483
# Tracking the blob, frame number:  484
# Tracking the blob, frame number:  485
# Tracking the blob, frame number:  486
# Tracking the blob, frame number:  487
# Tracking the blob, frame number:  488
# Tracking the blob, frame number:  489
# Tracking the blob, frame number:  490
# Tracking the blob, frame number:  491
# Tracking the blob, frame number:  492
# Tracking the blob, frame number:  493
# Tracking the blob, frame number:  494
# Tracking the blob, frame number:  495
# Tracking the blob, frame number:  496
# Tracking the blob, frame number:  497
# Tracking the blob, frame number:  498
# Tracking the blob, frame number:  499
# Tracking the blob, frame number:  500
# Tracking the blob, frame number:  501
# Tracking the blob, frame number:  502
# Tracking the blob, frame number:  503
# Tracking the blob, frame number:  504
# Tracking the blob, frame number:  505
# Tracking the blob, frame number:  506
# Tracking the blob, frame number:  507
# Tracking the blob, frame number:  508
# Tracking the blob, frame number:  509
# Tracking the blob, frame number:  510
# Tracking the blob, frame number:  511
# Tracking the blob, frame number:  512
# Tracking the blob, frame number:  513
# Tracking the blob, frame number:  514
# Tracking the blob, frame number:  515
# Tracking the blob, frame number:  516
# Tracking the blob, frame number:  517
# Tracking the blob, frame number:  518
# Tracking the blob, frame number:  519
# Tracking the blob, frame number:  520
# Tracking the blob, frame number:  521
# Tracking the blob, frame number:  522
# Tracking the blob, frame number:  523
# Tracking the blob, frame number:  524
# Tracking the blob, frame number:  525
# Tracking the blob, frame number:  526
# Tracking the blob, frame number:  527
# Tracking the blob, frame number:  528
# Tracking the blob, frame number:  529
# Tracking the blob, frame number:  530
# Tracking the blob, frame number:  531
# New rightmost blob detected, shift =  -11
# Tracking the blob, frame number:  533
# Tracking the blob, frame number:  534
# Tracking the blob, frame number:  535
# Previous blob disappeared, shift =  -12
# Tracking the blob, frame number:  537
# Tracking the blob, frame number:  538
# Tracking the blob, frame number:  539
# Tracking the blob, frame number:  540
# Tracking the blob, frame number:  541
# Tracking the blob, frame number:  542
# New rightmost blob detected, shift =  -11
# Tracking the blob, frame number:  544
# Tracking the blob, frame number:  545
# Tracking the blob, frame number:  546
# Tracking the blob, frame number:  547
# Tracking the blob, frame number:  548
# Tracking the blob, frame number:  549
# Tracking the blob, frame number:  550
# Tracking the blob, frame number:  551
# Tracking the blob, frame number:  552
# Tracking the blob, frame number:  553
# Tracking the blob, frame number:  554
# Tracking the blob, frame number:  555
# Tracking the blob, frame number:  556
# Tracking the blob, frame number:  557
# Tracking the blob, frame number:  558
# Tracking the blob, frame number:  559
# Tracking the blob, frame number:  560
# Tracking the blob, frame number:  561
# Tracking the blob, frame number:  562
# Tracking the blob, frame number:  563
# Tracking the blob, frame number:  564
# Tracking the blob, frame number:  565
# Tracking the blob, frame number:  566
# Tracking the blob, frame number:  567
# Tracking the blob, frame number:  568
# Tracking the blob, frame number:  569
# Tracking the blob, frame number:  570
# Tracking the blob, frame number:  571
# Tracking the blob, frame number:  572
# Tracking the blob, frame number:  573
# Tracking the blob, frame number:  574
# Tracking the blob, frame number:  575
# Tracking the blob, frame number:  576
# New rightmost blob detected, shift =  -10
# Tracking the blob, frame number:  578
# Tracking the blob, frame number:  579
# Tracking the blob, frame number:  580
# Tracking the blob, frame number:  581
# Tracking the blob, frame number:  582
# Tracking the blob, frame number:  583
# Tracking the blob, frame number:  584
# Tracking the blob, frame number:  585
# Tracking the blob, frame number:  586
# Tracking the blob, frame number:  587
# Tracking the blob, frame number:  588
# Tracking the blob, frame number:  589
# Tracking the blob, frame number:  590
# Tracking the blob, frame number:  591
# Tracking the blob, frame number:  592
# Tracking the blob, frame number:  593
# Tracking the blob, frame number:  594
# Tracking the blob, frame number:  595
# New rightmost blob detected, shift =  -9
# Tracking the blob, frame number:  597
# Tracking the blob, frame number:  598
# Tracking the blob, frame number:  599
# Tracking the blob, frame number:  600
# Tracking the blob, frame number:  601
# Tracking the blob, frame number:  602
# Tracking the blob, frame number:  603
# Tracking the blob, frame number:  604
# Tracking the blob, frame number:  605
# Tracking the blob, frame number:  606
# Tracking the blob, frame number:  607
# Tracking the blob, frame number:  608
# Tracking the blob, frame number:  609
# Tracking the blob, frame number:  610
# Tracking the blob, frame number:  611
# Tracking the blob, frame number:  612
# Tracking the blob, frame number:  613
# Tracking the blob, frame number:  614
# Tracking the blob, frame number:  615
# Tracking the blob, frame number:  616
# Tracking the blob, frame number:  617
# Tracking the blob, frame number:  618
# Tracking the blob, frame number:  619
# Tracking the blob, frame number:  620
# New rightmost blob detected, shift =  -8
# Tracking the blob, frame number:  622
# Tracking the blob, frame number:  623
# Tracking the blob, frame number:  624
# Tracking the blob, frame number:  625
# Tracking the blob, frame number:  626
# Tracking the blob, frame number:  627
# Tracking the blob, frame number:  628
# Tracking the blob, frame number:  629
# Tracking the blob, frame number:  630
# Tracking the blob, frame number:  631
# Tracking the blob, frame number:  632
# Tracking the blob, frame number:  633
# Tracking the blob, frame number:  634
# Tracking the blob, frame number:  635
# Tracking the blob, frame number:  636
# Tracking the blob, frame number:  637
# Tracking the blob, frame number:  638
# Tracking the blob, frame number:  639
# Tracking the blob, frame number:  640
# Tracking the blob, frame number:  641
# Tracking the blob, frame number:  642
# Tracking the blob, frame number:  643
# Tracking the blob, frame number:  644
# Tracking the blob, frame number:  645
# Tracking the blob, frame number:  646
# Tracking the blob, frame number:  647
# Tracking the blob, frame number:  648
# Tracking the blob, frame number:  649
# Tracking the blob, frame number:  650
# Tracking the blob, frame number:  651
# Tracking the blob, frame number:  652
# Tracking the blob, frame number:  653
# Tracking the blob, frame number:  654
# Tracking the blob, frame number:  655
# Tracking the blob, frame number:  656
# Tracking the blob, frame number:  657
# New rightmost blob detected, shift =  -7
# Tracking the blob, frame number:  659
# Tracking the blob, frame number:  660
# Tracking the blob, frame number:  661
# Tracking the blob, frame number:  662
# Tracking the blob, frame number:  663
# Tracking the blob, frame number:  664
# Tracking the blob, frame number:  665
# Tracking the blob, frame number:  666
# Tracking the blob, frame number:  667
# Tracking the blob, frame number:  668
# Tracking the blob, frame number:  669
# Tracking the blob, frame number:  670
# Tracking the blob, frame number:  671
# Tracking the blob, frame number:  672
# Tracking the blob, frame number:  673
# Tracking the blob, frame number:  674
# Tracking the blob, frame number:  675
# Tracking the blob, frame number:  676
# Tracking the blob, frame number:  677
# Tracking the blob, frame number:  678
# Tracking the blob, frame number:  679
# Tracking the blob, frame number:  680
# Tracking the blob, frame number:  681
# Tracking the blob, frame number:  682
# Tracking the blob, frame number:  683
# Tracking the blob, frame number:  684
# Tracking the blob, frame number:  685
# Tracking the blob, frame number:  686
# New rightmost blob detected, shift =  -6
# Tracking the blob, frame number:  688
# Tracking the blob, frame number:  689
# Tracking the blob, frame number:  690
# Tracking the blob, frame number:  691
# Tracking the blob, frame number:  692
# Tracking the blob, frame number:  693
# Tracking the blob, frame number:  694
# Tracking the blob, frame number:  695
# Tracking the blob, frame number:  696
# Tracking the blob, frame number:  697
# Tracking the blob, frame number:  698
# Tracking the blob, frame number:  699
# Tracking the blob, frame number:  700
# Tracking the blob, frame number:  701
# Tracking the blob, frame number:  702
# Tracking the blob, frame number:  703
# Tracking the blob, frame number:  704
# Tracking the blob, frame number:  705
# Tracking the blob, frame number:  706
# Tracking the blob, frame number:  707
# Tracking the blob, frame number:  708
# Tracking the blob, frame number:  709
# Tracking the blob, frame number:  710
# Tracking the blob, frame number:  711
# Tracking the blob, frame number:  712
# New rightmost blob detected, shift =  -5
# Tracking the blob, frame number:  714
# Tracking the blob, frame number:  715
# Tracking the blob, frame number:  716
# Tracking the blob, frame number:  717
# Tracking the blob, frame number:  718
# Tracking the blob, frame number:  719
# Tracking the blob, frame number:  720
# Tracking the blob, frame number:  721
# Tracking the blob, frame number:  722
# Tracking the blob, frame number:  723
# Tracking the blob, frame number:  724
# Tracking the blob, frame number:  725
# Tracking the blob, frame number:  726
# Tracking the blob, frame number:  727
# Tracking the blob, frame number:  728
# Tracking the blob, frame number:  729
# Tracking the blob, frame number:  730
# New rightmost blob detected, shift =  -4
# Tracking the blob, frame number:  732
# Tracking the blob, frame number:  733
# Tracking the blob, frame number:  734
# Tracking the blob, frame number:  735
# Tracking the blob, frame number:  736
# Tracking the blob, frame number:  737
# Tracking the blob, frame number:  738
# Tracking the blob, frame number:  739
# Tracking the blob, frame number:  740
# Tracking the blob, frame number:  741
# Tracking the blob, frame number:  742
# Tracking the blob, frame number:  743
# Tracking the blob, frame number:  744
# Tracking the blob, frame number:  745
# Tracking the blob, frame number:  746
# Tracking the blob, frame number:  747
# Tracking the blob, frame number:  748
# Tracking the blob, frame number:  749
# Tracking the blob, frame number:  750
# New rightmost blob detected, shift =  -3
# Tracking the blob, frame number:  752
# Tracking the blob, frame number:  753
# Tracking the blob, frame number:  754
# Tracking the blob, frame number:  755
# Tracking the blob, frame number:  756
# Tracking the blob, frame number:  757
# Tracking the blob, frame number:  758
# Tracking the blob, frame number:  759
# Tracking the blob, frame number:  760
# Tracking the blob, frame number:  761
# Tracking the blob, frame number:  762
# Tracking the blob, frame number:  763
# Tracking the blob, frame number:  764
# Tracking the blob, frame number:  765
# Tracking the blob, frame number:  766
# Tracking the blob, frame number:  767
# Tracking the blob, frame number:  768
# Tracking the blob, frame number:  769
# Tracking the blob, frame number:  770
# Tracking the blob, frame number:  771
# Tracking the blob, frame number:  772
# Tracking the blob, frame number:  773
# Tracking the blob, frame number:  774
# Tracking the blob, frame number:  775
# Tracking the blob, frame number:  776
# Tracking the blob, frame number:  777
# New rightmost blob detected, shift =  -2
# Tracking the blob, frame number:  779
# Tracking the blob, frame number:  780
# Tracking the blob, frame number:  781
# Tracking the blob, frame number:  782
# Tracking the blob, frame number:  783
# Tracking the blob, frame number:  784
# Tracking the blob, frame number:  785
# Tracking the blob, frame number:  786
# Tracking the blob, frame number:  787
# Tracking the blob, frame number:  788
# Tracking the blob, frame number:  789
# Tracking the blob, frame number:  790
# Tracking the blob, frame number:  791
# Tracking the blob, frame number:  792
# Tracking the blob, frame number:  793
# Tracking the blob, frame number:  794
# Tracking the blob, frame number:  795
# Tracking the blob, frame number:  796
# Tracking the blob, frame number:  797
# Tracking the blob, frame number:  798
# New rightmost blob detected, shift =  -1
# Tracking the blob, frame number:  800
# Tracking the blob, frame number:  801
# Tracking the blob, frame number:  802
# Tracking the blob, frame number:  803
# Tracking the blob, frame number:  804
# Tracking the blob, frame number:  805
# Tracking the blob, frame number:  806
# Tracking the blob, frame number:  807
# Tracking the blob, frame number:  808
# Tracking the blob, frame number:  809
# Tracking the blob, frame number:  810
# Tracking the blob, frame number:  811
# Tracking the blob, frame number:  812
# Tracking the blob, frame number:  813
# Tracking the blob, frame number:  814
# Tracking the blob, frame number:  815
# Tracking the blob, frame number:  816
# Tracking the blob, frame number:  817
# Tracking the blob, frame number:  818
# Tracking the blob, frame number:  819
# Tracking the blob, frame number:  820
# Tracking the blob, frame number:  821
# Tracking the blob, frame number:  822
# Tracking the blob, frame number:  823
# Tracking the blob, frame number:  824
# Tracking the blob, frame number:  825
# Tracking the blob, frame number:  826
# Tracking the blob, frame number:  827
# Tracking the blob, frame number:  828
# Tracking the blob, frame number:  829
# Tracking the blob, frame number:  830
# Tracking the blob, frame number:  831
# Tracking the blob, frame number:  832
# Tracking the blob, frame number:  833
# Tracking the blob, frame number:  834
# Tracking the blob, frame number:  835
# Tracking the blob, frame number:  836
# Tracking the blob, frame number:  837
# Tracking the blob, frame number:  838
# Tracking the blob, frame number:  839
# Tracking the blob, frame number:  840
# Tracking the blob, frame number:  841
# Tracking the blob, frame number:  842
# Tracking the blob, frame number:  843
# Tracking the blob, frame number:  844
# Tracking the blob, frame number:  845
# Tracking the blob, frame number:  846
# Tracking the blob, frame number:  847
# Tracking the blob, frame number:  848
# Tracking the blob, frame number:  849
# Tracking the blob, frame number:  850
# Tracking the blob, frame number:  851
# Tracking the blob, frame number:  852
# Tracking the blob, frame number:  853
# New rightmost blob detected, shift =  0
# Tracking the blob, frame number:  855
# Tracking the blob, frame number:  856
# Tracking the blob, frame number:  857
# Tracking the blob, frame number:  858
# Tracking the blob, frame number:  859
# Tracking the blob, frame number:  860
# Tracking the blob, frame number:  861
# Tracking the blob, frame number:  862
# Tracking the blob, frame number:  863
# Tracking the blob, frame number:  864
# Tracking the blob, frame number:  865
# Tracking the blob, frame number:  866
# Tracking the blob, frame number:  867
# Tracking the blob, frame number:  868
# Tracking the blob, frame number:  869
# Tracking the blob, frame number:  870
# Tracking the blob, frame number:  871
# Tracking the blob, frame number:  872
# Tracking the blob, frame number:  873
# Tracking the blob, frame number:  874
# Tracking the blob, frame number:  875
# Tracking the blob, frame number:  876
# Tracking the blob, frame number:  877
# Tracking the blob, frame number:  878
# Tracking the blob, frame number:  879
# New rightmost blob detected, shift =  1
# Tracking the blob, frame number:  881
# Tracking the blob, frame number:  882
# Tracking the blob, frame number:  883
# Tracking the blob, frame number:  884
# Tracking the blob, frame number:  885
# Tracking the blob, frame number:  886
# Tracking the blob, frame number:  887
# Tracking the blob, frame number:  888
# Tracking the blob, frame number:  889
# Tracking the blob, frame number:  890
# Tracking the blob, frame number:  891
# Tracking the blob, frame number:  892
# Tracking the blob, frame number:  893
# Tracking the blob, frame number:  894
# Tracking the blob, frame number:  895
# Tracking the blob, frame number:  896
# Tracking the blob, frame number:  897
# Tracking the blob, frame number:  898
# Tracking the blob, frame number:  899
# Tracking the blob, frame number:  900
# Tracking the blob, frame number:  901
# Tracking the blob, frame number:  902
# Tracking the blob, frame number:  903
# Tracking the blob, frame number:  904
# Tracking the blob, frame number:  905
# New rightmost blob detected, shift =  2
# Tracking the blob, frame number:  907
# Tracking the blob, frame number:  908
# Tracking the blob, frame number:  909
# Tracking the blob, frame number:  910
# Tracking the blob, frame number:  911
# Tracking the blob, frame number:  912
# Tracking the blob, frame number:  913
# Tracking the blob, frame number:  914
# Tracking the blob, frame number:  915
# Tracking the blob, frame number:  916
# Tracking the blob, frame number:  917
# Tracking the blob, frame number:  918
# Tracking the blob, frame number:  919
# Tracking the blob, frame number:  920
# Tracking the blob, frame number:  921
# Tracking the blob, frame number:  922
# Tracking the blob, frame number:  923
# Tracking the blob, frame number:  924
# Tracking the blob, frame number:  925
# Tracking the blob, frame number:  926
# Tracking the blob, frame number:  927
# Tracking the blob, frame number:  928
# Tracking the blob, frame number:  929
# Tracking the blob, frame number:  930
# Tracking the blob, frame number:  931
# Tracking the blob, frame number:  932
# Tracking the blob, frame number:  933
# Tracking the blob, frame number:  934
# Tracking the blob, frame number:  935
# New rightmost blob detected, shift =  3
# Tracking the blob, frame number:  937
# Tracking the blob, frame number:  938
# Tracking the blob, frame number:  939
# Tracking the blob, frame number:  940
# Tracking the blob, frame number:  941
# Tracking the blob, frame number:  942
# Tracking the blob, frame number:  943
# Tracking the blob, frame number:  944
# Tracking the blob, frame number:  945
# Tracking the blob, frame number:  946
# Tracking the blob, frame number:  947
# Tracking the blob, frame number:  948
# Tracking the blob, frame number:  949
# Tracking the blob, frame number:  950
# Tracking the blob, frame number:  951
# Tracking the blob, frame number:  952
# Tracking the blob, frame number:  953
# Tracking the blob, frame number:  954
# Tracking the blob, frame number:  955
# Tracking the blob, frame number:  956
# Tracking the blob, frame number:  957
# Tracking the blob, frame number:  958
# Tracking the blob, frame number:  959
# Tracking the blob, frame number:  960
# Tracking the blob, frame number:  961
# Tracking the blob, frame number:  962
# Tracking the blob, frame number:  963
# New rightmost blob detected, shift =  4
# Tracking the blob, frame number:  965
# Tracking the blob, frame number:  966
# Tracking the blob, frame number:  967
# Tracking the blob, frame number:  968
# Tracking the blob, frame number:  969
# Tracking the blob, frame number:  970
# Tracking the blob, frame number:  971
# Tracking the blob, frame number:  972
# Tracking the blob, frame number:  973
# Tracking the blob, frame number:  974
# Tracking the blob, frame number:  975
# Tracking the blob, frame number:  976
# Tracking the blob, frame number:  977
# Tracking the blob, frame number:  978
# Tracking the blob, frame number:  979
# Tracking the blob, frame number:  980
# Tracking the blob, frame number:  981
# Tracking the blob, frame number:  982
# Tracking the blob, frame number:  983
# Tracking the blob, frame number:  984
# Tracking the blob, frame number:  985
# Tracking the blob, frame number:  986
# Tracking the blob, frame number:  987
# Tracking the blob, frame number:  988
# Tracking the blob, frame number:  989
# New rightmost blob detected, shift =  5
# Tracking the blob, frame number:  991
# Tracking the blob, frame number:  992
# Tracking the blob, frame number:  993
# Tracking the blob, frame number:  994
# Tracking the blob, frame number:  995
# Tracking the blob, frame number:  996
# Tracking the blob, frame number:  997
# Tracking the blob, frame number:  998
# Tracking the blob, frame number:  999
# Tracking the blob, frame number:  1000
# Tracking the blob, frame number:  1001
# Tracking the blob, frame number:  1002
# Tracking the blob, frame number:  1003
# Tracking the blob, frame number:  1004
# Tracking the blob, frame number:  1005
# Tracking the blob, frame number:  1006
# Tracking the blob, frame number:  1007
# Tracking the blob, frame number:  1008
# Tracking the blob, frame number:  1009
# New rightmost blob detected, shift =  6
# Tracking the blob, frame number:  1011
# Tracking the blob, frame number:  1012
# Tracking the blob, frame number:  1013
# Tracking the blob, frame number:  1014
# Tracking the blob, frame number:  1015
# Tracking the blob, frame number:  1016
# Tracking the blob, frame number:  1017
# Tracking the blob, frame number:  1018
# Tracking the blob, frame number:  1019
# Tracking the blob, frame number:  1020
# Tracking the blob, frame number:  1021
# Tracking the blob, frame number:  1022
# Tracking the blob, frame number:  1023
# Tracking the blob, frame number:  1024
# Tracking the blob, frame number:  1025
# Tracking the blob, frame number:  1026
# Tracking the blob, frame number:  1027
# Tracking the blob, frame number:  1028
# Tracking the blob, frame number:  1029
# New rightmost blob detected, shift =  7
# Tracking the blob, frame number:  1031
# Tracking the blob, frame number:  1032
# Tracking the blob, frame number:  1033
# Tracking the blob, frame number:  1034
# Tracking the blob, frame number:  1035
# Tracking the blob, frame number:  1036
# Tracking the blob, frame number:  1037
# Tracking the blob, frame number:  1038
# Tracking the blob, frame number:  1039
# Tracking the blob, frame number:  1040
# Tracking the blob, frame number:  1041
# Tracking the blob, frame number:  1042
# Tracking the blob, frame number:  1043
# Tracking the blob, frame number:  1044
# Tracking the blob, frame number:  1045
# Tracking the blob, frame number:  1046
# Tracking the blob, frame number:  1047
# Tracking the blob, frame number:  1048
# Tracking the blob, frame number:  1049
# Tracking the blob, frame number:  1050
# Tracking the blob, frame number:  1051
# Tracking the blob, frame number:  1052
# New rightmost blob detected, shift =  8
# Tracking the blob, frame number:  1054
# Tracking the blob, frame number:  1055
# Tracking the blob, frame number:  1056
# Tracking the blob, frame number:  1057
# Tracking the blob, frame number:  1058
# Tracking the blob, frame number:  1059
# Tracking the blob, frame number:  1060
# Tracking the blob, frame number:  1061
# Tracking the blob, frame number:  1062
# Tracking the blob, frame number:  1063
# Tracking the blob, frame number:  1064
# Tracking the blob, frame number:  1065
# Tracking the blob, frame number:  1066
# Tracking the blob, frame number:  1067
# Tracking the blob, frame number:  1068
# Tracking the blob, frame number:  1069
# Tracking the blob, frame number:  1070
# Tracking the blob, frame number:  1071
# Tracking the blob, frame number:  1072
# Tracking the blob, frame number:  1073
# Tracking the blob, frame number:  1074
# Tracking the blob, frame number:  1075
# Tracking the blob, frame number:  1076
# New rightmost blob detected, shift =  9
# Tracking the blob, frame number:  1078
# Tracking the blob, frame number:  1079
# Tracking the blob, frame number:  1080
# Tracking the blob, frame number:  1081
# Tracking the blob, frame number:  1082
# Tracking the blob, frame number:  1083
# Tracking the blob, frame number:  1084
# Tracking the blob, frame number:  1085
# Tracking the blob, frame number:  1086
# Tracking the blob, frame number:  1087
# Tracking the blob, frame number:  1088
# Tracking the blob, frame number:  1089
# Tracking the blob, frame number:  1090
# Tracking the blob, frame number:  1091
# Tracking the blob, frame number:  1092
# Tracking the blob, frame number:  1093
# Tracking the blob, frame number:  1094
# Tracking the blob, frame number:  1095
# Tracking the blob, frame number:  1096
# Tracking the blob, frame number:  1097
# Tracking the blob, frame number:  1098
# New rightmost blob detected, shift =  10
# Tracking the blob, frame number:  1100
# Tracking the blob, frame number:  1101
# Tracking the blob, frame number:  1102
# Tracking the blob, frame number:  1103
# Tracking the blob, frame number:  1104
# Tracking the blob, frame number:  1105
# Tracking the blob, frame number:  1106
# Tracking the blob, frame number:  1107
# Tracking the blob, frame number:  1108
# Tracking the blob, frame number:  1109
# Tracking the blob, frame number:  1110
# New rightmost blob detected, shift =  11
# Tracking the blob, frame number:  1112
# Tracking the blob, frame number:  1113
# Tracking the blob, frame number:  1114
# Tracking the blob, frame number:  1115
# Tracking the blob, frame number:  1116
# Tracking the blob, frame number:  1117
# Tracking the blob, frame number:  1118
# Tracking the blob, frame number:  1119
# Tracking the blob, frame number:  1120
# Tracking the blob, frame number:  1121
# Tracking the blob, frame number:  1122
# Tracking the blob, frame number:  1123
# Tracking the blob, frame number:  1124
# Tracking the blob, frame number:  1125
# Tracking the blob, frame number:  1126
# Tracking the blob, frame number:  1127
# Tracking the blob, frame number:  1128
# Tracking the blob, frame number:  1129
# Tracking the blob, frame number:  1130
# Tracking the blob, frame number:  1131
# Tracking the blob, frame number:  1132
# New rightmost blob detected, shift =  12
# Tracking the blob, frame number:  1134
# Tracking the blob, frame number:  1135
# Tracking the blob, frame number:  1136
# Tracking the blob, frame number:  1137
# Tracking the blob, frame number:  1138
# Tracking the blob, frame number:  1139
# Tracking the blob, frame number:  1140
# Tracking the blob, frame number:  1141
# Tracking the blob, frame number:  1142
# Tracking the blob, frame number:  1143
# Tracking the blob, frame number:  1144
# Tracking the blob, frame number:  1145
# Tracking the blob, frame number:  1146
# Tracking the blob, frame number:  1147
# Tracking the blob, frame number:  1148
# Tracking the blob, frame number:  1149
# Tracking the blob, frame number:  1150
# Tracking the blob, frame number:  1151
# Tracking the blob, frame number:  1152
# Tracking the blob, frame number:  1153
# Tracking the blob, frame number:  1154
# Tracking the blob, frame number:  1155
# Tracking the blob, frame number:  1156
# Tracking the blob, frame number:  1157
# Tracking the blob, frame number:  1158
# Tracking the blob, frame number:  1159
# Tracking the blob, frame number:  1160
# Tracking the blob, frame number:  1161
# Tracking the blob, frame number:  1162
# Tracking the blob, frame number:  1163
# Tracking the blob, frame number:  1164
# Tracking the blob, frame number:  1165
# Tracking the blob, frame number:  1166
# New rightmost blob detected, shift =  13
# Tracking the blob, frame number:  1168
# Tracking the blob, frame number:  1169
# Tracking the blob, frame number:  1170
# Tracking the blob, frame number:  1171
# Tracking the blob, frame number:  1172
# Tracking the blob, frame number:  1173
# Tracking the blob, frame number:  1174
# Tracking the blob, frame number:  1175
# Tracking the blob, frame number:  1176
# Tracking the blob, frame number:  1177
# Tracking the blob, frame number:  1178
# Tracking the blob, frame number:  1179
# Tracking the blob, frame number:  1180
# Tracking the blob, frame number:  1181
# Tracking the blob, frame number:  1182
# Tracking the blob, frame number:  1183
# Tracking the blob, frame number:  1184
# Tracking the blob, frame number:  1185
# Tracking the blob, frame number:  1186
# Tracking the blob, frame number:  1187
# Tracking the blob, frame number:  1188
# Tracking the blob, frame number:  1189
# Tracking the blob, frame number:  1190
# Tracking the blob, frame number:  1191
# Tracking the blob, frame number:  1192
# Tracking the blob, frame number:  1193
# Tracking the blob, frame number:  1194
# Tracking the blob, frame number:  1195
# Tracking the blob, frame number:  1196
# Tracking the blob, frame number:  1197
# Tracking the blob, frame number:  1198
# Tracking the blob, frame number:  1199
# Tracking the blob, frame number:  1200
# Tracking the blob, frame number:  1201
# Tracking the blob, frame number:  1202
# Tracking the blob, frame number:  1203
# Tracking the blob, frame number:  1204
# Tracking the blob, frame number:  1205
# Tracking the blob, frame number:  1206
# Tracking the blob, frame number:  1207
# Tracking the blob, frame number:  1208
# Tracking the blob, frame number:  1209
# Tracking the blob, frame number:  1210
# Tracking the blob, frame number:  1211
# Tracking the blob, frame number:  1212
# Tracking the blob, frame number:  1213
# Tracking the blob, frame number:  1214
# Tracking the blob, frame number:  1215
# Tracking the blob, frame number:  1216
# Tracking the blob, frame number:  1217
# Tracking the blob, frame number:  1218
# Tracking the blob, frame number:  1219
# Tracking the blob, frame number:  1220
# Tracking the blob, frame number:  1221
# Tracking the blob, frame number:  1222
# New rightmost blob detected, shift =  14
# Tracking the blob, frame number:  1224
# Tracking the blob, frame number:  1225
# Tracking the blob, frame number:  1226
# Tracking the blob, frame number:  1227
# Tracking the blob, frame number:  1228
# Tracking the blob, frame number:  1229
# Tracking the blob, frame number:  1230
# Tracking the blob, frame number:  1231
# Tracking the blob, frame number:  1232
# Tracking the blob, frame number:  1233
# Tracking the blob, frame number:  1234
# Tracking the blob, frame number:  1235
# Tracking the blob, frame number:  1236
# Tracking the blob, frame number:  1237
# Tracking the blob, frame number:  1238
# Tracking the blob, frame number:  1239
# Tracking the blob, frame number:  1240
# Tracking the blob, frame number:  1241
# Tracking the blob, frame number:  1242
# Tracking the blob, frame number:  1243
# Tracking the blob, frame number:  1244
# Tracking the blob, frame number:  1245
# Tracking the blob, frame number:  1246
# Tracking the blob, frame number:  1247
# Tracking the blob, frame number:  1248
# Tracking the blob, frame number:  1249
# Tracking the blob, frame number:  1250
# Tracking the blob, frame number:  1251
# Tracking the blob, frame number:  1252
# Tracking the blob, frame number:  1253
# Tracking the blob, frame number:  1254
# New rightmost blob detected, shift =  15
# Tracking the blob, frame number:  1256
# Tracking the blob, frame number:  1257
# ...
# Tracking the blob, frame number:  2272
# Tracking the blob, frame number:  2273
# Tracking the blob, frame number:  2274
# Tracking the blob, frame number:  2275
# Tracking the blob, frame number:  2276
# Tracking the blob, frame number:  2277
# Tracking the blob, frame number:  2278
# Tracking the blob, frame number:  2279
# Tracking the blob, frame number:  2280
# Tracking the blob, frame number:  2281
# Tracking the blob, frame number:  2282
# Tracking the blob, frame number:  2283
# Tracking the blob, frame number:  2284
# Tracking the blob, frame number:  2285
# Tracking the blob, frame number:  2286
# Tracking the blob, frame number:  2287
# Tracking the blob, frame number:  2288
# Tracking the blob, frame number:  2289
# Tracking the blob, frame number:  2290
# Tracking the blob, frame number:  2291
# Previous blob disappeared, shift =  0
# Tracking the blob, frame number:  2293
# Tracking the blob, frame number:  2294
# Tracking the blob, frame number:  2295
# Tracking the blob, frame number:  2296
# Tracking the blob, frame number:  2297
# Tracking the blob, frame number:  2298
# Tracking the blob, frame number:  2299
# Tracking the blob, frame number:  2300
# Tracking the blob, frame number:  2301
# Tracking the blob, frame number:  2302
# Tracking the blob, frame number:  2303
# Tracking the blob, frame number:  2304
# Tracking the blob, frame number:  2305
# Tracking the blob, frame number:  2306
# Tracking the blob, frame number:  2307
# Tracking the blob, frame number:  2308
# Tracking the blob, frame number:  2309
# Tracking the blob, frame number:  2310
# Tracking the blob, frame number:  2311
# Tracking the blob, frame number:  2312
# Tracking the blob, frame number:  2313
# Tracking the blob, frame number:  2314
# Tracking the blob, frame number:  2315
# Tracking the blob, frame number:  2316
# Tracking the blob, frame number:  2317
# Tracking the blob, frame number:  2318
# Tracking the blob, frame number:  2319
# Tracking the blob, frame number:  2320
# Tracking the blob, frame number:  2321
# Tracking the blob, frame number:  2322
# Previous blob disappeared, shift =  -1
# Tracking the blob, frame number:  2324
# Tracking the blob, frame number:  2325
# Tracking the blob, frame number:  2326
# Tracking the blob, frame number:  2327
# Tracking the blob, frame number:  2328
# Tracking the blob, frame number:  2329
# Tracking the blob, frame number:  2330
# Tracking the blob, frame number:  2331
# Tracking the blob, frame number:  2332
# Tracking the blob, frame number:  2333
# Tracking the blob, frame number:  2334
# Tracking the blob, frame number:  2335
# Tracking the blob, frame number:  2336
# Tracking the blob, frame number:  2337
# Tracking the blob, frame number:  2338
# Tracking the blob, frame number:  2339
# Tracking the blob, frame number:  2340
# Tracking the blob, frame number:  2341
# Tracking the blob, frame number:  2342
# Previous blob disappeared, shift =  -2
# Tracking the blob, frame number:  2344
# Tracking the blob, frame number:  2345
# Tracking the blob, frame number:  2346
# Tracking the blob, frame number:  2347
# Tracking the blob, frame number:  2348
# Tracking the blob, frame number:  2349
# Tracking the blob, frame number:  2350
# Tracking the blob, frame number:  2351
# Tracking the blob, frame number:  2352
# Tracking the blob, frame number:  2353
# Tracking the blob, frame number:  2354
# Tracking the blob, frame number:  2355
# Tracking the blob, frame number:  2356
# Tracking the blob, frame number:  2357
# Previous blob disappeared, shift =  -3
# Tracking the blob, frame number:  2359
# Tracking the blob, frame number:  2360
# Tracking the blob, frame number:  2361
# Tracking the blob, frame number:  2362
# Tracking the blob, frame number:  2363
# Tracking the blob, frame number:  2364
# Tracking the blob, frame number:  2365
# Tracking the blob, frame number:  2366
# Tracking the blob, frame number:  2367
# Tracking the blob, frame number:  2368
# Tracking the blob, frame number:  2369
# Tracking the blob, frame number:  2370
# Tracking the blob, frame number:  2371
# Tracking the blob, frame number:  2372
# Tracking the blob, frame number:  2373
# Tracking the blob, frame number:  2374
# Tracking the blob, frame number:  2375
# Tracking the blob, frame number:  2376
# Previous blob disappeared, shift =  -4
# Tracking the blob, frame number:  2378
# Tracking the blob, frame number:  2379
# Tracking the blob, frame number:  2380
# Tracking the blob, frame number:  2381
# Tracking the blob, frame number:  2382
# Tracking the blob, frame number:  2383
# Tracking the blob, frame number:  2384
# Tracking the blob, frame number:  2385
# Tracking the blob, frame number:  2386
# Tracking the blob, frame number:  2387
# Tracking the blob, frame number:  2388
# Tracking the blob, frame number:  2389
# Tracking the blob, frame number:  2390
# Tracking the blob, frame number:  2391
# Tracking the blob, frame number:  2392
# Tracking the blob, frame number:  2393
# Tracking the blob, frame number:  2394
# Tracking the blob, frame number:  2395
# Tracking the blob, frame number:  2396
# Tracking the blob, frame number:  2397
# Tracking the blob, frame number:  2398
# Tracking the blob, frame number:  2399
# Tracking the blob, frame number:  2400
# Tracking the blob, frame number:  2401
# Tracking the blob, frame number:  2402
# Previous blob disappeared, shift =  -5
# Tracking the blob, frame number:  2404
# Tracking the blob, frame number:  2405
# Tracking the blob, frame number:  2406
# Tracking the blob, frame number:  2407
# Tracking the blob, frame number:  2408
# Tracking the blob, frame number:  2409
# Tracking the blob, frame number:  2410
# Tracking the blob, frame number:  2411
# Tracking the blob, frame number:  2412
# Tracking the blob, frame number:  2413
# Tracking the blob, frame number:  2414
# Tracking the blob, frame number:  2415
# Tracking the blob, frame number:  2416
# Tracking the blob, frame number:  2417
# Tracking the blob, frame number:  2418
# Tracking the blob, frame number:  2419
# Tracking the blob, frame number:  2420
# Tracking the blob, frame number:  2421
# Previous blob disappeared, shift =  -6
# Tracking the blob, frame number:  2423
# Tracking the blob, frame number:  2424
# Tracking the blob, frame number:  2425
# Tracking the blob, frame number:  2426
# Tracking the blob, frame number:  2427
# Tracking the blob, frame number:  2428
# Tracking the blob, frame number:  2429
# Tracking the blob, frame number:  2430
# Tracking the blob, frame number:  2431
# Tracking the blob, frame number:  2432
# Previous blob disappeared, shift =  -7
# Tracking the blob, frame number:  2434
# Tracking the blob, frame number:  2435
# Tracking the blob, frame number:  2436
# Tracking the blob, frame number:  2437
# Tracking the blob, frame number:  2438
# Tracking the blob, frame number:  2439
# Tracking the blob, frame number:  2440
# Tracking the blob, frame number:  2441
# Tracking the blob, frame number:  2442
# Tracking the blob, frame number:  2443
# Tracking the blob, frame number:  2444
# Tracking the blob, frame number:  2445
# Tracking the blob, frame number:  2446
# Previous blob disappeared, shift =  -8
# Tracking the blob, frame number:  2448
# Tracking the blob, frame number:  2449
# Tracking the blob, frame number:  2450
# Tracking the blob, frame number:  2451
# Tracking the blob, frame number:  2452
# Tracking the blob, frame number:  2453
# Tracking the blob, frame number:  2454
# Tracking the blob, frame number:  2455
# Tracking the blob, frame number:  2456
# Tracking the blob, frame number:  2457
# Tracking the blob, frame number:  2458
# Tracking the blob, frame number:  2459
# Tracking the blob, frame number:  2460
# Tracking the blob, frame number:  2461
# Tracking the blob, frame number:  2462
# Tracking the blob, frame number:  2463
# Tracking the blob, frame number:  2464
# Tracking the blob, frame number:  2465
# Tracking the blob, frame number:  2466
# Tracking the blob, frame number:  2467
# Tracking the blob, frame number:  2468
# Tracking the blob, frame number:  2469
# Tracking the blob, frame number:  2470
# Tracking the blob, frame number:  2471
# Tracking the blob, frame number:  2472
# Tracking the blob, frame number:  2473
# Previous blob disappeared, shift =  -9
# Tracking the blob, frame number:  2475
# Tracking the blob, frame number:  2476
# Tracking the blob, frame number:  2477
# Tracking the blob, frame number:  2478
# Tracking the blob, frame number:  2479
# Tracking the blob, frame number:  2480
# Tracking the blob, frame number:  2481
# Tracking the blob, frame number:  2482
# Tracking the blob, frame number:  2483
# Tracking the blob, frame number:  2484
# Tracking the blob, frame number:  2485
# Previous blob disappeared, shift =  -10
# Tracking the blob, frame number:  2487
# Tracking the blob, frame number:  2488
# Tracking the blob, frame number:  2489
# Tracking the blob, frame number:  2490
# Tracking the blob, frame number:  2491
# Tracking the blob, frame number:  2492
# Tracking the blob, frame number:  2493
# Tracking the blob, frame number:  2494
# Tracking the blob, frame number:  2495
# Tracking the blob, frame number:  2496
# Tracking the blob, frame number:  2497
# Tracking the blob, frame number:  2498
# Tracking the blob, frame number:  2499
# Tracking the blob, frame number:  2500
# Previous blob disappeared, shift =  -11
# Tracking the blob, frame number:  2502
# Tracking the blob, frame number:  2503
# Tracking the blob, frame number:  2504
# Tracking the blob, frame number:  2505
# Tracking the blob, frame number:  2506
# Tracking the blob, frame number:  2507
# Tracking the blob, frame number:  2508
# Tracking the blob, frame number:  2509
# Tracking the blob, frame number:  2510
# Tracking the blob, frame number:  2511
# Tracking the blob, frame number:  2512
# Tracking the blob, frame number:  2513
# Tracking the blob, frame number:  2514
# Tracking the blob, frame number:  2515
# Tracking the blob, frame number:  2516
# Tracking the blob, frame number:  2517
# Previous blob disappeared, shift =  -12
# Tracking the blob, frame number:  2519
# Tracking the blob, frame number:  2520
# Tracking the blob, frame number:  2521
# Tracking the blob, frame number:  2522
# Tracking the blob, frame number:  2523
# Tracking the blob, frame number:  2524
# Tracking the blob, frame number:  2525
# Tracking the blob, frame number:  2526
# Tracking the blob, frame number:  2527
# Tracking the blob, frame number:  2528
# Tracking the blob, frame number:  2529
# Tracking the blob, frame number:  2530
# Tracking the blob, frame number:  2531
# Tracking the blob, frame number:  2532
# Tracking the blob, frame number:  2533
# Tracking the blob, frame number:  2534
# Tracking the blob, frame number:  2535
# Tracking the blob, frame number:  2536
# Tracking the blob, frame number:  2537
# Previous blob disappeared, shift =  -13
# New rightmost blob detected, shift =  -12
# Previous blob disappeared, shift =  -13
# Tracking the blob, frame number:  2541
# Tracking the blob, frame number:  2542
# Tracking the blob, frame number:  2543
# Tracking the blob, frame number:  2544
# Tracking the blob, frame number:  2545
# Tracking the blob, frame number:  2546
# Tracking the blob, frame number:  2547
# Tracking the blob, frame number:  2548
# Tracking the blob, frame number:  2549
# Previous blob disappeared, shift =  -14
# Tracking the blob, frame number:  2551
# Tracking the blob, frame number:  2552
# Tracking the blob, frame number:  2553
# Tracking the blob, frame number:  2554
# Tracking the blob, frame number:  2555
# Tracking the blob, frame number:  2556
# Tracking the blob, frame number:  2557
# Tracking the blob, frame number:  2558
# Tracking the blob, frame number:  2559
# Tracking the blob, frame number:  2560
# Tracking the blob, frame number:  2561
# Tracking the blob, frame number:  2562
# Tracking the blob, frame number:  2563
# Tracking the blob, frame number:  2564
# Tracking the blob, frame number:  2565
# Tracking the blob, frame number:  2566
# Tracking the blob, frame number:  2567
# Tracking the blob, frame number:  2568
# Previous blob disappeared, shift =  -15
# Tracking the blob, frame number:  2570
# Tracking the blob, frame number:  2571
# Tracking the blob, frame number:  2572
# Tracking the blob, frame number:  2573
# Tracking the blob, frame number:  2574
# Tracking the blob, frame number:  2575
# Tracking the blob, frame number:  2576
# Tracking the blob, frame number:  2577
# Tracking the blob, frame number:  2578
# Tracking the blob, frame number:  2579
# Tracking the blob, frame number:  2580
# Tracking the blob, frame number:  2581
# Tracking the blob, frame number:  2582
# Tracking the blob, frame number:  2583
# Tracking the blob, frame number:  2584
# Tracking the blob, frame number:  2585
# Tracking the blob, frame number:  2586
# Tracking the blob, frame number:  2587
# Tracking the blob, frame number:  2588
# Tracking the blob, frame number:  2589
# Tracking the blob, frame number:  2590
# Previous blob disappeared, shift =  -16
# Tracking the blob, frame number:  2592
# Tracking the blob, frame number:  2593
# Tracking the blob, frame number:  2594
# Tracking the blob, frame number:  2595
# Tracking the blob, frame number:  2596
# Tracking the blob, frame number:  2597
# Tracking the blob, frame number:  2598
# Tracking the blob, frame number:  2599
# Tracking the blob, frame number:  2600
# Tracking the blob, frame number:  2601
# Tracking the blob, frame number:  2602
# Tracking the blob, frame number:  2603
# New rightmost blob detected, shift =  -15
# New rightmost blob detected, shift =  -14
# Tracking the blob, frame number:  2606
# Tracking the blob, frame number:  2607
# New rightmost blob detected, shift =  -13
# Previous blob disappeared, shift =  -14
# Tracking the blob, frame number:  2610
# Tracking the blob, frame number:  2611
# Tracking the blob, frame number:  2612
# Tracking the blob, frame number:  2613
# Tracking the blob, frame number:  2614
# Tracking the blob, frame number:  2615
# Tracking the blob, frame number:  2616
# Tracking the blob, frame number:  2617
# Tracking the blob, frame number:  2618
# Tracking the blob, frame number:  2619
# Tracking the blob, frame number:  2620
# Tracking the blob, frame number:  2621
# Tracking the blob, frame number:  2622
# Tracking the blob, frame number:  2623
# Tracking the blob, frame number:  2624
# Tracking the blob, frame number:  2625
# Tracking the blob, frame number:  2626
# Tracking the blob, frame number:  2627
# Tracking the blob, frame number:  2628
# Tracking the blob, frame number:  2629
# Tracking the blob, frame number:  2630
# Tracking the blob, frame number:  2631
# Previous blob disappeared, shift =  -15
# Tracking the blob, frame number:  2633
# Tracking the blob, frame number:  2634
# Tracking the blob, frame number:  2635
# Tracking the blob, frame number:  2636
# Tracking the blob, frame number:  2637
# Tracking the blob, frame number:  2638
# Tracking the blob, frame number:  2639
# Tracking the blob, frame number:  2640
# Tracking the blob, frame number:  2641
# Tracking the blob, frame number:  2642
# Tracking the blob, frame number:  2643
# Tracking the blob, frame number:  2644
# Tracking the blob, frame number:  2645
# Tracking the blob, frame number:  2646
# Tracking the blob, frame number:  2647
# Tracking the blob, frame number:  2648
# Tracking the blob, frame number:  2649
# Tracking the blob, frame number:  2650
# Tracking the blob, frame number:  2651
# Tracking the blob, frame number:  2652
# Tracking the blob, frame number:  2653
# Previous blob disappeared, shift =  -16
# Tracking the blob, frame number:  2655
# Tracking the blob, frame number:  2656
# Tracking the blob, frame number:  2657
# Tracking the blob, frame number:  2658
# Tracking the blob, frame number:  2659
# Tracking the blob, frame number:  2660
# Tracking the blob, frame number:  2661
# Tracking the blob, frame number:  2662
# Tracking the blob, frame number:  2663
# Tracking the blob, frame number:  2664
# Tracking the blob, frame number:  2665
# Tracking the blob, frame number:  2666
# Tracking the blob, frame number:  2667
# Tracking the blob, frame number:  2668
# Tracking the blob, frame number:  2669
# Tracking the blob, frame number:  2670
# Tracking the blob, frame number:  2671
# Tracking the blob, frame number:  2672
# Tracking the blob, frame number:  2673
# Tracking the blob, frame number:  2674
# Tracking the blob, frame number:  2675
# Tracking the blob, frame number:  2676
# Tracking the blob, frame number:  2677
# Tracking the blob, frame number:  2678
# Tracking the blob, frame number:  2679
# Tracking the blob, frame number:  2680

# %%
def calculate_difference(real_shift, calculated_shift):
    return abs(real_shift - calculated_shift)

data = [
    {"movie": 1, "real_shift": 61, "calculated_shift": 92},
    {"movie": 2, "real_shift": 7, "calculated_shift": -23},
    {"movie": 3, "real_shift": 38, "calculated_shift": -16},
]

print("movie | real shift | calculated shift | DIFF")

for row in data:
    movie = row["movie"]
    real_shift = row["real_shift"]
    calculated_shift = row["calculated_shift"]
    diff = calculate_difference(real_shift, calculated_shift)
    
    # Print the row values
    print(f"{movie}\t|\t{real_shift} - {calculated_shift} = {real_shift + calculated_shift}\t|\t{calculated_shift}\t|\t{diff}")
# Out:
# movie | real shift | calculated shift | DIFF
# 1	|	61 - 92 = 153	|	92	|	31
# 2	|	7 - -23 = -16	|	-23	|	30
# 3	|	38 - -16 = 22	|	-16	|	54

# %%
#pip install prettytable
# Out:
# Collecting prettytable
#   Downloading prettytable-3.9.0-py3-none-any.whl (27 kB)
# Requirement already satisfied: wcwidth in d:\programs\anaconda\envs\opencvai\lib\site-packages (from prettytable) (0.2.8)
# Installing collected packages: prettytable
# Successfully installed prettytable-3.9.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from prettytable import PrettyTable

data = [
    {"movie": 1, "real_shift": 61, "calculated_shift": 92},
    {"movie": 2, "real_shift": -27, "calculated_shift": -23},
    {"movie": 3, "real_shift": -21, "calculated_shift": -16},
]

table = PrettyTable()
table.field_names = ["movie", "real shift", "calculated shift", "DIFF"]

for row in data:
    movie = row["movie"]
    real_shift = row["real_shift"]
    calculated_shift = row["calculated_shift"]
    diff = abs(real_shift - calculated_shift)
    
    table.add_row([movie, f"{real_shift}", calculated_shift, diff])

print(table)
# Out:
# +-------+------------+------------------+------+
# | movie | real shift | calculated shift | DIFF |
# +-------+------------+------------------+------+
# |   1   |     61     |        92        |  31  |
# |   2   |    -27     |       -23        |  4   |
# |   3   |    -21     |       -16        |  5   |
# +-------+------------+------------------+------+
